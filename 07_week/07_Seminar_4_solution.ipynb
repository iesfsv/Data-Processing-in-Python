# %% [markdown]
# # Seminar 4: Data Formats and APIs
#
# November 11, 2025
#
# ______________________________

# %% [markdown]
# ## What are we going to learn
#
# - What are the most popular data formats and how to work with them
# - Databases, SQL and data manipulation
# - HTTP requests
# - How to scrape websites

# %% [markdown]
# ## 1. Data formats
#
# ### Data Serialization and Formats
# Serialization is the process of converting data structures or objects into a format that can be easily stored and shared. Common data formats in Python include:
# - **JSON**: Lightweight and commonly used for APIs.
# - **CSV**: Ideal for tabular data, especially in spreadsheets.
# - **Excel**: Classic data storage everyone is aware of.

# %% [markdown]
# #### JSON

# %%
import json
import pandas as pd
import os
    
data = {
    "name": "Alice",
    "age": 30,
    "is_member": True,
    "hobbies": ["reading", "biking", "coding"]
}

# %%
filepath = os.path.join('Data', 'sample.json')

with open(filepath, 'w') as f:
    json.dump(data, f)

# %%
pd.read_json(filepath)
# Out:
#     name  age  is_member  hobbies
# 0  Alice   30       True  reading
# 1  Alice   30       True   biking
# 2  Alice   30       True   coding

# %% [markdown]
# #### CSV

# %%
import csv

data = [
    ["Name", "Age", "Occupation"],
    ["Alice", 30, "Engineer"],
    ["Bob", 25, "Designer"],
    ["Charlie", 35, "Teacher"]
]

# %%
filepath = os.path.join('Data', 'sample.csv')

with open(filepath, 'w') as f:
    writer = csv.writer(f)
    writer.writerows(data)

# %%
pd.read_csv(filepath)
# Out:
#       Name  Age Occupation
# 0    Alice   30   Engineer
# 1      Bob   25   Designer
# 2  Charlie   35    Teacher

# %% [markdown]
# #### Excel

# %%
data = {
    "name": "Thomas",
    "age": 30,
    "is_member": True,
    "hobbies": "reading, biking, coding"
}

# %%
filepath = os.path.join('Data', 'sample.xlsx')
df = pd.DataFrame([data])
df.to_excel(filepath, index=False)

# %%
pd.read_excel(filepath)
# Out:
#      name  age  is_member                  hobbies
# 0  Thomas   30       True  reading, biking, coding

# %% [markdown]
# ## 2. Requests and web scraping

# %%
import requests # for making HTTP requests
import pandas as pd 
import time
import re # Regex = Regular Expressions

# %% [markdown]
# Time package small things:

# %%
# %%time
print("Hello, World!")
# Out:
# Hello, World!
# CPU times: user 491 μs, sys: 490 μs, total: 981 μs
# Wall time: 619 μs

# %%
t0 = time.time()
time.sleep(1)
t1 = time.time()
print("Time elapsed: ", t1-t0, " seconds")
# Out:
# Time elapsed:  1.0053067207336426  seconds

# %%
# %%time 
time.sleep(2)
# Out:
# CPU times: user 853 μs, sys: 1.35 ms, total: 2.2 ms
# Wall time: 2 s

# %%
import random

# %%
# %%time
r_time = random.uniform(0.5, 1.2)
print("Sleeping for ", r_time, " seconds")
time.sleep(r_time)
# Out:
# Sleeping for  0.5280115277270837  seconds
# CPU times: user 2.7 ms, sys: 2.46 ms, total: 5.16 ms
# Wall time: 530 ms

# %% [markdown]
# #### Task 1: Requesting API
#
# Let us work with data of sreality.cz which we can access via their api. An intuition is that the api is limited for a number of requests (but not verified).

# %% [markdown]
# ##### 1a. Create a function requesting data from sreality
#
# ```python
# base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page60&page={}'.format(i)
#
# r = requests.get(base_url)
# d = r.json()
# ```
#
# 0) function should parametrize:
#     * `category_main_cb` - `{'flat':1, 'house':2, 'land':3 }`
#     * `category_type_cb` - `{'sell':1,'rent':2}`
#     * `locality_region_id` - use 10 as default value
#     * `page` parameter
# 1) use string inputs for `category_main_cb` and `category_type_cb`
# 2) include `try/except` clause to handle errors
# 3) function should return JSON data in python types
# 4) do not forget to sleep each request at least 0.5s

# %%
def request_sreality(page, category_main_str, category_type_str, locality_region_id=10):
    """
    Request data from sreality.cz API
    :param page: page number
    :param category_main_str: category of the property
    :param category_type_str: type of the offer
    :param locality_region_id: region id
    :return json: json response
    """
    template_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main}&category_type_cb={category_type}&locality_region_id={locality_region_id}&per_page60&page={page}'
    category_main_cb = {'flat':1, 'house':2, 'land':3 }
    category_type_cb = {'sell':1,'rent':2}
    url_path = template_url.format(category_main=category_main_cb[category_main_str],
                                   category_type=category_type_cb[category_type_str],
                                   locality_region_id=locality_region_id,
                                   page=page)
    time.sleep(random.uniform(0.5, 1.2))
    try:
        r = requests.get(url_path)
    except Exception as e:
        print(e)
        return None
    return r.json()

# %%
d = request_sreality(page=0, category_main_str='flat', category_type_str='sell', locality_region_id=10)

# %% [markdown]
# Inspect the element `d`:

# %%
d.keys()
# Out:
# dict_keys(['meta_description', 'result_size', '_embedded', 'filterLabels', 'title', 'filter', '_links', 'locality', 'locality_dativ', 'logged_in', 'per_page', 'category_instrumental', 'page', 'filterLabels2'])

# %%
d['meta_description']
# Out:
# 21

# %%
d['result_size']

# %%
d['_embedded']

# %%
d['_embedded'].keys()

# %%
d['_embedded']['estates']
# Out:
# [{'labelsReleased': [['balcony', 'garage', 'furnished'], []],
#   'has_panorama': 0,
#   'labels': ['Balkon', 'Garáž', 'Vybavený'],
#   'is_auction': False,
#   'labelsAll': [['personal',
#     'balcony',
#     'terrace',
#     'cellar',
#     'elevator',
#     'parking_lots',
#     'garage',
#     'furnished'],
#    ['small_shop',
#     'theater',
#     'vet',
#     'candy_shop',
#     'movies',
#     'tavern',
#     'playground',
#     'sightseeing',
#     'natural_attraction',
#     'restaurant',
#     'sports',
#     'shop',
#     'school',
#     'drugstore',
#     'metro',
#     'medic',
#     'kindergarten',
#     'train',
#     'post_office',
#     'bus_public_transport',
#     'tram',
#     'atm']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 8,
#    'category_type_cb': 1,
#    'locality': 'praha-zizkov-prokopova'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/1318314828',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/1318314828',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'www': '',
#     'phones': [{'code': '420', 'type': 'TEL', 'number': '608311448'}],
#     'poi_logo': '',
#     'logo': '',
#     'company_subject_id': 2612254,
#     'id': 8765,
#     'ico': 13052918,
#     'locality': {'lat': 50.0860189148, 'lon': 14.45352615},
#     'company_id': 4887,
#     'allow_calculator': 1,
#     'logo_small': '',
#     'seznam_naplno': 0,
#     '_links': {'self': {'profile': '/companies/1/doc',
#       'href': '/cs/v2/companies/8765?category_main_cb=1&per_page60=&locality_region_id=10&page=0&category_type_cb=1'}},
#     'retargeting_id': 0,
#     'email': 'sittinger@home4people.cz',
#     'description': 'Poskytujeme zprostředkovatelskou činnost v oblasti realit - prodej, koupě, pronájem, daňový, finanční a právní servis, znalecké posudky a konzultace. Hovoříme anglicky, německy a rusky.',
#     'address': 'Prokopova 2856/10, 13000 Praha - Žižkov',
#     'ask': {'addr_city': 'Praha, Žižkov',
#      'description': 'Poskytujeme zprostředkovatelskou činnost v oblasti realit - prodej, koupě, pronájem, daňový, finanční a právní servis, znalecké posudky a konzultace. Hovoříme anglicky, německy a rusky.',
#      'firmy_review_url': 'https://www.firmy.cz/detail/2384292-mgr-jolana-sittinger-praha-zizkov.html#pridat-hodnoceni',
#      'phones': [{'role': 'Telefon',
#        'number': '608311448',
#        'country_code': '420'}],
#      'is_paid': False,
#      'emails': [{'role': 'E-mail', 'email': 'sittinger@home4people.cz'}],
#      'email': 'cs.realestate@seznam.cz',
#      'addr_zip': '13000',
#      'address': 'Prokopova 2856/10, 130 00  Praha, Žižkov',
#      'addr_street': 'Prokopova',
#      'addr_house_num': '2856/10'},
#     'name': 'Mgr. Jolana Sittinger',
#     'url': 'Mgr-Jolana-Sittinger-Praha-Zizkov',
#     'ask_id': 2384292,
#     'company_paid_firmy': 0,
#     'www_visible': ''}},
#   'paid_logo': 0,
#   'locality': 'Praha 3 - Žižkov',
#   'has_video': False,
#   'advert_images_count': 30,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 1318314828,
#   'attractive_offer': 0,
#   'price': 42769000,
#   'price_czk': {'value_raw': 42769000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlCon8is0E1D2Fs/2947.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlCon8is0E1D2Fs/2947.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-20?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/1318314828?region_tip=3419754'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlCon8is0E1D2Fs/2947.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlC6aNAxVE1D2eM/ca31.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlBWHnvBB9E1V4Sv/c73d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlTJ3VvEE1D2g0/7e03.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlBWHnv1rE1D2iS/c43b.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlEAMYF3HE1D2jf/a256.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlCon8is0E1D2Fs/2947.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 4+kk 317\xa0m²',
#   'region_tip': 3419754,
#   'gps': {'lat': 50.07261362854839, 'lon': 14.466933371451614},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], []],
#   'has_panorama': 0,
#   'labels': [],
#   'is_auction': False,
#   'labelsAll': [['new_building', 'personal', 'brick', 'elevator'],
#    ['small_shop',
#     'theater',
#     'vet',
#     'candy_shop',
#     'tavern',
#     'movies',
#     'playground',
#     'sightseeing',
#     'kindergarten',
#     'shop',
#     'drugstore',
#     'medic',
#     'bus_public_transport',
#     'train',
#     'atm',
#     'sports',
#     'school',
#     'restaurant',
#     'metro',
#     'tram',
#     'post_office']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-vinohrady-polska'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/3481568076',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/3481568076',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'SATPO-SATPO-management-s-r-o-Praha-Smichov',
#     'id': 14817,
#     'name': 'SATPO - SATPO management, s.r.o.',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_D/sZfBoen.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 2 - Vinohrady',
#   'has_video': False,
#   'advert_images_count': 14,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 3481568076,
#   'attractive_offer': 0,
#   'price': 36990000,
#   'price_czk': {'value_raw': 36990000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlB5hiy2VE1UHJv/7cc5.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlB5hiy2VE1UHJv/7cc5.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-19?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/3481568076'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlB5hiy2VE1UHJv/7cc5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlBWHnvBBQE1UHKa/1a38.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlTJ3V2OE1UHLN/19f1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlBY4Bl6uE1UHMN/fa2f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlEAMYFBCGE1UHNN/df32.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlCHwcexlE1UHN9/2c78.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlB5hiy2VE1UHJv/7cc5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 130\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.06533562854839, 'lon': 14.459462371451613},
#   'has_matterport_url': False},
#  {'labelsReleased': [['not_furnished'], []],
#   'has_panorama': 0,
#   'labels': ['Nevybavený'],
#   'is_auction': False,
#   'labelsAll': [['new_building',
#     'personal',
#     'terrace',
#     'cellar',
#     'parking_lots',
#     'not_furnished'],
#    ['small_shop',
#     'tavern',
#     'candy_shop',
#     'playground',
#     'vet',
#     'theater',
#     'movies',
#     'restaurant',
#     'drugstore',
#     'school',
#     'kindergarten',
#     'metro',
#     'train',
#     'medic',
#     'sports',
#     'tram',
#     'atm',
#     'post_office',
#     'shop',
#     'bus_public_transport']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 8,
#    'category_type_cb': 1,
#    'locality': 'praha-suchdol-pod-rybnickem'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/2106786380',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/2106786380',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'LUXENT-Exclusive-Properties-Praha-Josefov',
#     'id': 3628,
#     'name': 'LUXENT - Exclusive Properties',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gQ_o/4ZQB5.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 6 - Suchdol',
#   'has_video': False,
#   'advert_images_count': 33,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 2106786380,
#   'attractive_offer': 0,
#   'price': 33505000,
#   'price_czk': {'value_raw': 33505000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/kOzmiQlmfoKFXEErnEwH2PZ/d245.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/kOzmiQlmfoKFXEErnEwH2PZ/d245.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-18?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/2106786380'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/kOzmiQlmfoKFXEErnEwH2PZ/d245.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/kOzmiQlmfoDdPdoFpuEwH2QU/35e6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/kOzmiQlmfoDuFBcFl1EwH2RO/b2d0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/nO1Ur3YPjB17k9HFcEwH2SP/f7e2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/kOzmiQlmfoBSGGoFnTEwH2TI/bf91.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/nO1Ur3YPjBBGDkbHG5EwH2T8/b316.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/kOzmiQlmfoKFXEErnEwH2PZ/d245.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 4+kk 379\xa0m² (Mezonet)',
#   'region_tip': 0,
#   'gps': {'lat': 50.12693562854839, 'lon': 14.390640371451614},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], []],
#   'has_panorama': 0,
#   'labels': [],
#   'is_auction': False,
#   'labelsAll': [['new_building',
#     'personal',
#     'terrace',
#     'brick',
#     'cellar',
#     'parking_lots'],
#    ['small_shop',
#     'tavern',
#     'candy_shop',
#     'vet',
#     'playground',
#     'theater',
#     'movies',
#     'sports',
#     'bus_public_transport',
#     'kindergarten',
#     'school',
#     'medic',
#     'atm',
#     'tram',
#     'train',
#     'shop',
#     'drugstore',
#     'restaurant',
#     'post_office',
#     'metro']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-ujezd-u-pruhonic-formanska'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/1245102924',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/1245102924',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'LUXENT-Exclusive-Properties-Praha-Josefov',
#     'id': 3628,
#     'name': 'LUXENT - Exclusive Properties',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gQ_o/4ZQB5.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 4 - Újezd u Průhonic',
#   'has_video': False,
#   'advert_images_count': 16,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 1245102924,
#   'attractive_offer': 0,
#   'price': 13300000,
#   'price_czk': {'value_raw': 13300000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/nO1Ur3YPjBNlDMF4jEtwa3X/d6a1.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/nO1Ur3YPjBNlDMF4jEtwa3X/d6a1.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-17?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/1245102924'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/nO1Ur3YPjBNlDMF4jEtwa3X/d6a1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/kOzmiQlmfoBSGGoEuNEtwa4G/3a64.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/kOzmiQlmfoKFXEDyXEtwa48/dbc4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/nO1Ur3YPjBBGDkbF27Etwa5i/ef2f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/nO1Ur3YPjBD7Q0hF3nEtwa6N/178c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/kOzmiQlmfoChS4kEsCEtwa7S/03ac.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_D/nO1Ur3YPjBNlDMF4jEtwa3X/d6a1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 75\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.004075628548385, 'lon': 14.538689371451614},
#   'has_matterport_url': False},
#  {'labelsReleased': [['loggia'], []],
#   'has_panorama': 0,
#   'labels': ['Lodžie'],
#   'is_auction': False,
#   'labelsAll': [['new_building',
#     'personal',
#     'loggia',
#     'brick',
#     'cellar',
#     'elevator',
#     'partly_furnished'],
#    ['tavern',
#     'candy_shop',
#     'theater',
#     'vet',
#     'movies',
#     'small_shop',
#     'playground',
#     'natural_attraction',
#     'sports',
#     'atm',
#     'metro',
#     'train',
#     'tram',
#     'restaurant',
#     'shop',
#     'kindergarten',
#     'medic',
#     'bus_public_transport',
#     'post_office',
#     'school',
#     'drugstore']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-malesice-univerzitni'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/2240992076',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/2240992076',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 10 - Malešice',
#   'has_video': False,
#   'advert_images_count': 18,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 2240992076,
#   'attractive_offer': 0,
#   'price': 12026000,
#   'price_czk': {'value_raw': 12026000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_od_E/nPSV1TXV2nCJGajDu3EfCSX6/9f35.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_od_E/nPSV1TXV2nCJGajDu3EfCSX6/9f35.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-16?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/2240992076'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_od_E/nPSV1TXV2nCJGajDu3EfCSX6/9f35.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_E/nPSV1TXV2nUv1hDshEfCSXi/d2ee.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_E/nPSV1TXV2nCJGajDutEfCSVS/6bdd.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_E/nPSV1TXV2nCJGajDvCEfCSTG/ec62.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_E/kBlLbSfl8B9O11CqoEfCSUR/e8ca.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_E/kBlLbSfl8zSZiCnFEfCSTc/902e.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_od_E/nPSV1TXV2nCJGajDu3EfCSX6/9f35.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': True,
#   'name': 'Prodej bytu 2+kk 67\xa0m² (Jednopodlažní)',
#   'region_tip': 0,
#   'gps': {'lat': 50.073510628548384, 'lon': 14.515421371451614},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], []],
#   'has_panorama': 0,
#   'labels': [],
#   'is_auction': False,
#   'labelsAll': [['personal',
#     'brick',
#     'cellar',
#     'elevator',
#     'partly_furnished'],
#    []],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 5,
#    'category_type_cb': 1,
#    'locality': 'praha-nove-mesto-lannova'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/3119788876',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/3119788876',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'NESTERA-Praha-Mala-Strana',
#     'id': 23602,
#     'name': 'NESTERA',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_oa_A/nPXNrUcajvEBy8snlDcyYpX/9ddf.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 1 - Nové Město',
#   'has_video': False,
#   'advert_images_count': 14,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 3119788876,
#   'attractive_offer': 0,
#   'price': 20781000,
#   'price_czk': {'value_raw': 20781000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlB5hiyBznE3paca/c44f.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlB5hiyBznE3paca/c44f.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-15?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/3119788876'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlB5hiyBznE3paca/c44f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/nOztZkD4ZlC2Y2ECSrE3padR/e662.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlCHwceBq9E3paeD/f168.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlQSx2BvaE3pae6/65a6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlQSx2BvbE3pafy/54f7.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/nOztZkD4ZlDgbxFCUEE3pag7/f6ce.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlB5hiyBznE3paca/c44f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+1\xa0130\xa0m² (Jednopodlažní)',
#   'region_tip': 0,
#   'gps': {'lat': 50.07916762854838, 'lon': 14.445585371451614},
#   'has_matterport_url': False},
#  {'labelsReleased': [['after_reconstruction', 'garage', 'not_furnished'], []],
#   'has_panorama': 0,
#   'labels': ['Po rekonstrukci', 'Garáž', 'Nevybavený'],
#   'is_auction': False,
#   'labelsAll': [['personal',
#     'after_reconstruction',
#     'terrace',
#     'brick',
#     'parking_lots',
#     'garage',
#     'not_furnished'],
#    ['small_shop',
#     'tavern',
#     'movies',
#     'candy_shop',
#     'theater',
#     'vet',
#     'playground',
#     'sightseeing',
#     'natural_attraction',
#     'kindergarten',
#     'medic',
#     'metro',
#     'atm',
#     'drugstore',
#     'shop',
#     'tram',
#     'train',
#     'restaurant',
#     'post_office',
#     'school',
#     'sports',
#     'bus_public_transport']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 9,
#    'category_type_cb': 1,
#    'locality': 'praha-ruzyne-duchcovska'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/1245131596',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/1245131596',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 6 - Ruzyně',
#   'has_video': False,
#   'advert_images_count': 13,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 1245131596,
#   'attractive_offer': 0,
#   'price': 0,
#   'price_czk': {'value_raw': 0, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlDN44anqE08VDV/dde3.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlDN44anqE08VDV/dde3.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-14?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/1245131596'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlDN44anqE08VDV/dde3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlC0jCJnuE08VEN/9934.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlDgPvvwWE08VFD/0e58.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlDgPvvvxE08VFs/049e.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlBWHnvzkE08VGX/42af.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlCHwcepQE08VHL/75d7.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlDN44anqE08VDV/dde3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 4+1\xa0107\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.066052628548384, 'lon': 14.336941371451614},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], []],
#   'has_panorama': 0,
#   'labels': [],
#   'is_auction': False,
#   'labelsAll': [['personal',
#     'terrace',
#     'brick',
#     'cellar',
#     'elevator',
#     'parking_lots',
#     'partly_furnished'],
#    ['small_shop',
#     'theater',
#     'vet',
#     'movies',
#     'candy_shop',
#     'tavern',
#     'playground',
#     'sightseeing',
#     'medic',
#     'school',
#     'kindergarten',
#     'drugstore',
#     'atm',
#     'bus_public_transport',
#     'train',
#     'restaurant',
#     'tram',
#     'shop',
#     'metro',
#     'sports',
#     'post_office']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-holesovice-na-maninach'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/1634022220',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/1634022220',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 7 - Holešovice',
#   'has_video': False,
#   'advert_images_count': 30,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 1634022220,
#   'attractive_offer': 0,
#   'price': 16759000,
#   'price_czk': {'value_raw': 16759000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlQSx2BV9E2n9Sh/6e11.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlQSx2BV9E2n9Sh/6e11.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-13?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/1634022220'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlQSx2BV9E2n9Sh/6e11.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlB5hiyBXiE2n9TQ/8933.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/nOztZkD4ZlDgbxFBunE2n9UM/82de.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlCHwceBTjE2n9U5/68c7.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/nOztZkD4ZlDrUk0BtBE2n9Vm/e2aa.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlB5hiyBXhE2n9WT/7a90.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlQSx2BV9E2n9Sh/6e11.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 57\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.091805628548386, 'lon': 14.465823371451613},
#   'has_matterport_url': False},
#  {'labelsReleased': [['collective'], ['post_office']],
#   'has_panorama': 0,
#   'labels': ['Družstevní', 'Pošta 5 min. pěšky'],
#   'is_auction': False,
#   'labelsAll': [['collective', 'brick', 'partly_furnished'],
#    ['small_shop',
#     'theater',
#     'tavern',
#     'vet',
#     'candy_shop',
#     'movies',
#     'playground',
#     'natural_attraction',
#     'sightseeing',
#     'metro',
#     'tram',
#     'restaurant',
#     'kindergarten',
#     'bus_public_transport',
#     'drugstore',
#     'sports',
#     'atm',
#     'medic',
#     'shop',
#     'school',
#     'train',
#     'post_office']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 5,
#    'category_type_cb': 1,
#    'locality': 'praha-strasnice-kratka'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/4202115916',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/4202115916',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 10 - Strašnice',
#   'has_video': False,
#   'advert_images_count': 22,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 4202115916,
#   'attractive_offer': 0,
#   'price': 12066000,
#   'price_czk': {'value_raw': 12066000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlCon8iBEFE16Rli/a34f.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlCon8iBEFE16Rli/a34f.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-12?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/4202115916'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlCon8iBEFE16Rli/a34f.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/nOztZkD4ZlBY4BlBRiE16Rms/3ab5.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/nOztZkD4ZlB2dleBSVE16Rn3/1a88.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/nOztZkD4ZlC2Y2EBTZE16RpK/2bef.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/nOztZkD4ZlDgbxFBWaE16RqS/a6a3.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/nOztZkD4ZlEAMYFBXKE16Rrd/fe18.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_B/kPRtHkVQLlCon8iBEFE16Rli/a34f.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+1\xa080\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.06210462854839, 'lon': 14.502127371451614},
#   'has_matterport_url': False},
#  {'labelsReleased': [['furnished'], ['shop', 'post_office']],
#   'has_panorama': 0,
#   'labels': ['Vybavený', 'Obchod 6 min. pěšky', 'Pošta 1 min. pěšky'],
#   'is_auction': False,
#   'labelsAll': [['personal', 'brick', 'elevator', 'furnished'],
#    ['theater',
#     'small_shop',
#     'vet',
#     'movies',
#     'candy_shop',
#     'tavern',
#     'playground',
#     'sightseeing',
#     'tram',
#     'medic',
#     'restaurant',
#     'drugstore',
#     'atm',
#     'bus_public_transport',
#     'post_office',
#     'kindergarten',
#     'sports',
#     'school',
#     'metro',
#     'train',
#     'shop']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 5,
#    'category_type_cb': 1,
#    'locality': 'praha-stare-mesto-rybna'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/203657804',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/203657804',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'HOME-4-PEOPLE-H4P-ProfiReal-Praha-Smichov',
#     'id': 27573,
#     'name': 'HOME 4 PEOPLE - H4P ProfiReal',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QQ_M/TAlCCz.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 1 - Staré Město',
#   'has_video': False,
#   'advert_images_count': 23,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 203657804,
#   'attractive_offer': 0,
#   'price': 16759000,
#   'price_czk': {'value_raw': 16759000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_od_D/kBlLbSfl8CDPLmBzIEcsfov/6628.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_od_D/kBlLbSfl8CDPLmBzIEcsfov/6628.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-11?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/203657804'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_od_D/kBlLbSfl8CDPLmBzIEcsfov/6628.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_gV_6/6HHj0o.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_D/nPSV1TXV2nBusAfCmTEcsfpR/df64.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oa_D/kPxAuWMbDHNOfYmtDh9rs2/efcd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oa_D/nO7kYQIzllCcIbPBEkDh9rtU/4001.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oa_D/nO7kYQIzllCpKXPBEIDh9rvu/10ed.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_od_D/kBlLbSfl8CDPLmBzIEcsfov/6628.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+1\xa085\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.076707628548384, 'lon': 14.439386371451613},
#   'has_matterport_url': False},
#  {'labelsReleased': [['after_reconstruction'], []],
#   'has_panorama': 0,
#   'labels': ['Po rekonstrukci'],
#   'is_auction': False,
#   'labelsAll': [['personal',
#     'after_reconstruction',
#     'terrace',
#     'brick',
#     'cellar',
#     'elevator',
#     'parking_lots',
#     'partly_furnished'],
#    ['theater',
#     'small_shop',
#     'vet',
#     'candy_shop',
#     'tavern',
#     'movies',
#     'playground',
#     'sightseeing',
#     'drugstore',
#     'medic',
#     'restaurant',
#     'post_office',
#     'tram',
#     'kindergarten',
#     'school',
#     'metro',
#     'train',
#     'atm',
#     'shop',
#     'sports',
#     'bus_public_transport']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 6,
#    'category_type_cb': 1,
#    'locality': 'praha-vinohrady-rimska'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/3014079308',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/3014079308',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 2 - Vinohrady',
#   'has_video': False,
#   'advert_images_count': 18,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 3014079308,
#   'attractive_offer': 0,
#   'price': 26801000,
#   'price_czk': {'value_raw': 26801000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlCIYXk4TE1dbk5/f540.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlCIYXk4TE1dbk5/f540.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-10?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/3014079308'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlCIYXk4TE1dbk5/f540.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlC2Y2EBDCE1dbnc/b3cf.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlEAMYFBIBE1dbgK/acbf.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlB5hiy55E1dbfz/f6fa.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlCon8i2sE1dbdP/f082.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlBWHnvBGHE1dbgx/a83a.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlCIYXk4TE1dbk5/f540.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 3+kk 197\xa0m² (Jednopodlažní)',
#   'region_tip': 0,
#   'gps': {'lat': 50.06387862854839, 'lon': 14.448098371451614},
#   'has_matterport_url': False},
#  {'labelsReleased': [['garage'], []],
#   'has_panorama': 0,
#   'labels': ['Garáž'],
#   'is_auction': False,
#   'labelsAll': [['new_building',
#     'personal',
#     'terrace',
#     'brick',
#     'parking_lots',
#     'garage'],
#    ['sports',
#     'school',
#     'small_shop',
#     'restaurant',
#     'medic',
#     'kindergarten',
#     'movies',
#     'vet',
#     'atm',
#     'theater',
#     'shop',
#     'tavern',
#     'candy_shop',
#     'drugstore',
#     'post_office',
#     'bus_public_transport',
#     'tram',
#     'playground',
#     'metro',
#     'train',
#     'sightseeing']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-michle-kapitulska'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/3364631372',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/3364631372',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'CENTURY-21-AZ-Reality-Praha-Nusle',
#     'id': 8033,
#     'name': 'CENTURY 21 AZ Reality',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_oY_A/nPw2pRkMOeDxAUcwKCwm6zQ/3369.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 4 - Michle',
#   'has_video': True,
#   'advert_images_count': 15,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 3364631372,
#   'attractive_offer': 0,
#   'price': 14077000,
#   'price_czk': {'value_raw': 14077000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nO1Ur3YPjBCgEhIBoJEyqxxW/379c.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nO1Ur3YPjBCgEhIBoJEyqxxW/379c.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-9?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/3364631372'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nO1Ur3YPjBCgEhIBoJEyqxxW/379c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kOzmiQlmfoBSGGoG3XEyqxyU/f432.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kOzmiQlmfoBuCN3F4MEyqxzM/bae8.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nO1Ur3YPjBBN9bPB6yEyqx0O/fec2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nO1Ur3YPjBCgEhIBoAEyqx1G/12af.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nO1Ur3YPjBCPcZJBo5Eyqx2b/a67c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nO1Ur3YPjBCgEhIBoJEyqxxW/379c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 93\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.04535462854839, 'lon': 14.466575371451613},
#   'has_matterport_url': False},
#  {'labelsReleased': [['after_reconstruction', 'furnished'], ['train']],
#   'has_panorama': 0,
#   'labels': ['Po rekonstrukci', 'Vybavený', 'Vlak 8 min. pěšky'],
#   'is_auction': False,
#   'labelsAll': [['personal',
#     'after_reconstruction',
#     'brick',
#     'elevator',
#     'furnished'],
#    ['theater',
#     'small_shop',
#     'candy_shop',
#     'vet',
#     'movies',
#     'tavern',
#     'playground',
#     'sightseeing',
#     'kindergarten',
#     'drugstore',
#     'sports',
#     'medic',
#     'shop',
#     'post_office',
#     'school',
#     'metro',
#     'restaurant',
#     'train',
#     'bus_public_transport',
#     'tram',
#     'atm']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-holesovice-simackova'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/406422348',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/406422348',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 7 - Holešovice',
#   'has_video': False,
#   'advert_images_count': 14,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 406422348,
#   'attractive_offer': 0,
#   'price': 11932000,
#   'price_czk': {'value_raw': 11932000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_od_C/kOy0N9usHcCZypMBO6EW7LyM/fd8a.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_od_C/kOy0N9usHcCZypMBO6EW7LyM/fd8a.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-8?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/406422348'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_od_C/kOy0N9usHcCZypMBO6EW7LyM/fd8a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_C/kOy0N9usHcBTCYHBRnEW7Lyz/6436.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_C/nPXN5fAIwLCp4dgBtPEW7Lzd/6fa3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_C/kOy0N9usHcEELFJBXGEW7L0G/4c78.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_C/kOy0N9usHcCaEknBTQEW7L0z/d6a8.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_C/kOy0N9usHcCZypMBNSEW7L1f/606c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_od_C/kOy0N9usHcCZypMBO6EW7LyM/fd8a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 61\xa0m² (Loft)',
#   'region_tip': 0,
#   'gps': {'lat': 50.09027562854838, 'lon': 14.449549371451614},
#   'has_matterport_url': True},
#  {'labelsReleased': [[], ['post_office']],
#   'has_panorama': 0,
#   'labels': ['Pošta 1 min. pěšky'],
#   'is_auction': False,
#   'labelsAll': [['personal', 'brick', 'cellar', 'partly_furnished'],
#    ['theater',
#     'small_shop',
#     'candy_shop',
#     'tavern',
#     'vet',
#     'playground',
#     'natural_attraction',
#     'sightseeing',
#     'movies',
#     'post_office',
#     'drugstore',
#     'school',
#     'metro',
#     'kindergarten',
#     'medic',
#     'atm',
#     'shop',
#     'sports',
#     'bus_public_transport',
#     'train',
#     'tram',
#     'restaurant']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-strasnice-saratovska'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/2543927884',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/2543927884',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 10 - Strašnice',
#   'has_video': True,
#   'advert_images_count': 17,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 2543927884,
#   'attractive_offer': 0,
#   'price': 9318000,
#   'price_czk': {'value_raw': 9318000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_ob_B/nPvP7Dwxi2txZrB5BDswEKn/3e21.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_ob_B/nPvP7Dwxi2txZrB5BDswEKn/3e21.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-7?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/2543927884'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_ob_B/nPvP7Dwxi2txZrB5BDswEKn/3e21.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oZ_C/nsLxLojIIE33ImmDO6oEw/962c.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oZ_C/kBkJRwehYBO1ofC6eDO6oSR/3548.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oZ_C/kBkJRwehYBO1ofC6nDO6oMG/6256.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oZ_C/kBkJRwehYB3ZBZC8WDO6oJq/b9e5.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oZ_C/kBkJRwehYDlimkC2hDO6mrW/812a.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_ob_B/nPvP7Dwxi2txZrB5BDswEKn/3e21.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 72\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.06278362854839, 'lon': 14.505654371451614},
#   'has_matterport_url': False},
#  {'labelsReleased': [['loggia', 'panel'], []],
#   'has_panorama': 0,
#   'labels': ['Lodžie', 'Panelová'],
#   'is_auction': False,
#   'labelsAll': [['personal',
#     'loggia',
#     'panel',
#     'cellar',
#     'elevator',
#     'partly_furnished'],
#    ['playground',
#     'natural_attraction',
#     'train',
#     'bus_public_transport',
#     'tram',
#     'sports',
#     'metro']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 7,
#    'category_type_cb': 1,
#    'locality': 'praha-hodkovicky-pod-lysinami'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/4132430668',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/4132430668',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 4 - Hodkovičky',
#   'has_video': True,
#   'advert_images_count': 24,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 4132430668,
#   'attractive_offer': 0,
#   'price': 11999000,
#   'price_czk': {'value_raw': 11999000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_B/kOzmiQlmfoDuFBcjuElGb7X/c0f5.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_B/kOzmiQlmfoDuFBcjuElGb7X/c0f5.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-6?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/4132430668'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_B/kOzmiQlmfoDuFBcjuElGb7X/c0f5.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_A/kOes7N5Ni6PHDRDO1EP9RVy/7537.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_A/nO0bgvR9rXDo1QgEqTEP9QQg/dfbd.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_A/nO0bgvR9rXuvoHEq1EP9POD/f1bb.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_A/kOes7N5Ni64SGEDHlEP9PoX/670e.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_od_A/kOes7N5Ni6DuE0oDDtEP9QR3/2660.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_B/kOzmiQlmfoDuFBcjuElGb7X/c0f5.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 3+1\xa0107\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.00814962854839, 'lon': 14.425926371451613},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], ['shop']],
#   'has_panorama': 0,
# ...
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_B/kOzmiQlmfoChS4kBJLEm6pMh/8bbe.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_B/kOzmiQlmfoChS4kBJLEm6onQ/216e.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_B/nO1Ur3YPjB17k9BecEm6oPQ/11cc.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_B/nO1Ur3YPjB17k9BeCEm6oRz/bbc4.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_B/kOzmiQlmfoBEqdwBLCEm6os5/f64e.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 1+kk 45\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.06607562854839, 'lon': 14.430434371451613},
#   'has_matterport_url': False},
#  {'labelsReleased': [['loggia', 'panel'], []],
#   'has_panorama': 0,
#   'labels': ['Lodžie', 'Panelová'],
#   'is_auction': False,
#   'labelsAll': [['personal', 'loggia', 'panel', 'cellar', 'elevator'],
#    ['small_shop',
#     'tavern',
#     'candy_shop',
#     'vet',
#     'theater',
#     'movies',
#     'playground',
#     'natural_attraction',
#     'sports',
#     'atm',
#     'shop',
#     'kindergarten',
#     'tram',
#     'drugstore',
#     'school',
#     'medic',
#     'post_office',
#     'restaurant',
#     'bus_public_transport',
#     'train',
#     'metro']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-prosek-kytlicka'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/3757101900',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/3757101900',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 9 - Prosek',
#   'has_video': False,
#   'advert_images_count': 16,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 3757101900,
#   'attractive_offer': 0,
#   'price': 9371000,
#   'price_czk': {'value_raw': 9371000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/nPSV1TXV2nUv1hEE2Efvyl6/0a0b.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/nPSV1TXV2nUv1hEE2Efvyl6/0a0b.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-4?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/3757101900'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/nPSV1TXV2nUv1hEE2Efvyl6/0a0b.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/kBlLbSfl8B9O11C6rEfvzHo/0db2.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/nPSV1TXV2nD0mTJEEbEfvzKQ/842b.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/nPSV1TXV2nD0izvEC1EfvzYp/5cf5.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/kBlLbSfl8BOkUvCyEEfvzh7/27c2.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/kBlLbSfl8C2TnDC3sEfvzj0/0638.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/nPSV1TXV2nUv1hEE2Efvyl6/0a0b.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 58\xa0m² (Jednopodlažní)',
#   'region_tip': 0,
#   'gps': {'lat': 50.11316462854839, 'lon': 14.517314371451613},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], []],
#   'has_panorama': 0,
#   'labels': [],
#   'is_auction': False,
#   'labelsAll': [['personal', 'brick', 'cellar'],
#    ['small_shop',
#     'theater',
#     'vet',
#     'candy_shop',
#     'movies',
#     'tavern',
#     'playground',
#     'sightseeing',
#     'sports',
#     'kindergarten',
#     'medic',
#     'tram',
#     'bus_public_transport',
#     'shop',
#     'metro',
#     'atm',
#     'school',
#     'train',
#     'drugstore',
#     'restaurant',
#     'post_office']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 5,
#    'category_type_cb': 1,
#    'locality': 'praha--krizikova'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 0,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/1915958092',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/1915958092',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 8',
#   'has_video': False,
#   'advert_images_count': 18,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 1915958092,
#   'attractive_offer': 0,
#   'price': 13380000,
#   'price_czk': {'value_raw': 13380000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kOzmiQlmfoDuFBcHA9EzBIPi/b217.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kOzmiQlmfoDuFBcHA9EzBIPi/b217.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-3?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/1915958092'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kOzmiQlmfoDuFBcHA9EzBIPi/b217.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nO1Ur3YPjBCeQCqB99EzBGVz/3d32.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nO1Ur3YPjBDq6KHB25EzBIMW/b9ee.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kOzmiQlmfoBSGGoHBwEzBHUG/d920.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kOzmiQlmfoChS4kG79EzBIaX/2f23.png?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kOzmiQlmfoBSGGoHBwEzBIzS/6ab0.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kOzmiQlmfoDuFBcHA9EzBIPi/b217.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+1\xa080\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.078480628548384, 'lon': 14.461719371451613},
#   'has_matterport_url': True},
#  {'labelsReleased': [['not_furnished'], []],
#   'has_panorama': 0,
#   'labels': ['Nevybavený'],
#   'is_auction': False,
#   'labelsAll': [['new_building',
#     'personal',
#     'cellar',
#     'elevator',
#     'not_furnished'],
#    ['small_shop',
#     'tavern',
#     'theater',
#     'movies',
#     'candy_shop',
#     'vet',
#     'playground',
#     'sightseeing',
#     'natural_attraction',
#     'medic',
#     'atm',
#     'post_office',
#     'restaurant',
#     'kindergarten',
#     'bus_public_transport',
#     'school',
#     'sports',
#     'metro',
#     'drugstore',
#     'train',
#     'tram',
#     'shop']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 2,
#    'category_type_cb': 1,
#    'locality': 'praha-praha-5-'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/129491788',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/129491788',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'Sekyra-Group-Praha-Karlin',
#     'id': 3360,
#     'name': 'Sekyra Group',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_g/RYpNU.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 5',
#   'has_video': False,
#   'advert_images_count': 5,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 129491788,
#   'attractive_offer': 0,
#   'price': 10728000,
#   'price_czk': {'value_raw': 10728000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/kBlLbSfl8CDPLmCwIEfpU4t/d512.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/kBlLbSfl8CDPLmCwIEfpU4t/d512.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-2?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/129491788'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/kBlLbSfl8CDPLmCwIEfpU4t/d512.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/nPSV1TXV2nBaI13D9PEfpU5S/8951.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/kBlLbSfl8B9O11C3JEfpU6B/82d1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/kBlLbSfl8zSZiCyQEfpU7G/183b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/kBlLbSfl8CDPLmCv0EfpU75/c10e.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_A/kBlLbSfl8CDPLmCwIEfpU4t/d512.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 1+kk 44\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.04188662854839, 'lon': 14.393097371451613},
#   'has_matterport_url': False},
#  {'labelsReleased': [[], []],
#   'has_panorama': 0,
#   'labels': [],
#   'is_auction': False,
#   'labelsAll': [['new_building', 'personal', 'brick', 'cellar', 'elevator'],
#    ['small_shop',
#     'theater',
#     'vet',
#     'candy_shop',
#     'tavern',
#     'movies',
#     'playground',
#     'sightseeing',
#     'tram',
#     'school',
#     'sports',
#     'bus_public_transport',
#     'shop',
#     'kindergarten',
#     'medic',
#     'atm',
#     'metro',
#     'post_office',
#     'restaurant',
#     'drugstore',
#     'train']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 4,
#    'category_type_cb': 1,
#    'locality': 'praha-vinohrady-polska'},
#   'exclusively_at_rk': 0,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/2581779276',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/2581779276',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False},
#    'company': {'url': 'SATPO-SATPO-management-s-r-o-Praha-Smichov',
#     'id': 14817,
#     'name': 'SATPO - SATPO management, s.r.o.',
#     'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_D/sZfBoen.png?fl=res,140,140,3,ffffff'}},
#   'paid_logo': 1,
#   'locality': 'Praha 2 - Vinohrady',
#   'has_video': False,
#   'advert_images_count': 8,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 2581779276,
#   'attractive_offer': 0,
#   'price': 21840000,
#   'price_czk': {'value_raw': 21840000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlEAMYFBCbE1UGgq/cd97.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlEAMYFBCbE1UGgq/cd97.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/-1?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/2581779276'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlEAMYFBCbE1UGgq/cd97.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlCAK9gBBXE1UGhr/66c3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlDrUk09WE1UGiu/20a3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlD9vAdx8E1UGju/c5da.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlB2dle8HE1UGkm/18dd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/kPRtHkVQLlD9vAdx8E1UGlh/f992.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_of_A/nOztZkD4ZlEAMYFBCbE1UGgq/cd97.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 2+kk 75\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.06533562854839, 'lon': 14.459462371451613},
#   'has_matterport_url': False},
#  {'labelsReleased': [['balcony', 'garage', 'furnished'], []],
#   'has_panorama': 0,
#   'labels': ['Balkon', 'Garáž', 'Vybavený'],
#   'is_auction': False,
#   'labelsAll': [['personal',
#     'balcony',
#     'terrace',
#     'cellar',
#     'elevator',
#     'garage',
#     'furnished'],
#    ['candy_shop',
#     'tavern',
#     'small_shop',
#     'theater',
#     'vet',
#     'playground',
#     'natural_attraction',
#     'sightseeing',
#     'movies',
#     'atm',
#     'drugstore',
#     'school',
#     'post_office',
#     'shop',
#     'sports',
#     'medic',
#     'tram',
#     'bus_public_transport',
#     'train',
#     'kindergarten',
#     'restaurant',
#     'metro']],
#   'seo': {'category_main_cb': 1,
#    'category_sub_cb': 8,
#    'category_type_cb': 1,
#    'locality': 'praha-brevnov-nad-zaverkou'},
#   'exclusively_at_rk': 1,
#   'category': 1,
#   'has_floor_plan': 1,
#   '_embedded': {'favourite': {'is_favourite': False,
#     '_links': {'self': {'profile': '/favourite/doc',
#       'href': '/cs/v2/favourite/250016588',
#       'title': 'Oblibene inzeraty'}}},
#    'note': {'note': '',
#     '_links': {'self': {'profile': '/note/doc',
#       'href': '/cs/v2/note/250016588',
#       'title': 'Poznamky inzeratu'}},
#     'has_note': False}},
#   'paid_logo': 0,
#   'locality': 'Praha 6 - Břevnov',
#   'has_video': False,
#   'advert_images_count': 32,
#   'new': False,
#   'auctionPrice': 0.0,
#   'type': 1,
#   'hash_id': 250016588,
#   'attractive_offer': 0,
#   'price': 30823000,
#   'price_czk': {'value_raw': 30823000, 'unit': '', 'name': 'Celková cena'},
#   '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_C/nO1Ur3YPjBNaf8B6PEn3XsX/ae48.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#    'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_C/nO1Ur3YPjBNaf8B6PEn3XsX/ae48.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#    'iterator': {'href': '/cs/v2/estate-iterator/0?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#    'self': {'href': '/cs/v2/estates/250016588'},
#    'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_C/nO1Ur3YPjBNaf8B6PEn3XsX/ae48.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_C/nO1Ur3YPjBsRXRB9SEn3Xta/3dbe.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_C/kOzmiQlmfoBuCN3gUEn3Xub/efe5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_C/nO1Ur3YPjBNlDMB58En3XvR/bc16.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_C/nO1Ur3YPjBCBv9BB9cEn3XwM/ced6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#     {'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_C/nO1Ur3YPjBNlDMB5hEn3XxK/53f9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#    'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oe_C/nO1Ur3YPjBNaf8B6PEn3XsX/ae48.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#   'rus': False,
#   'name': 'Prodej bytu 4+kk 144\xa0m²',
#   'region_tip': 0,
#   'gps': {'lat': 50.069344628548386, 'lon': 14.393555371451614},
#   'has_matterport_url': False}]

# %% [markdown]
# ### 1b. Create a function converting sreality json data into pandas dataframe

# %%
len(d['_embedded']['estates']) # number of estates
# Out:
#                                        labelsReleased  has_panorama  \
# 0                  [[balcony, garage, furnished], []]             0
# 1                                            [[], []]             0
# 2                               [[not_furnished], []]             0
# 3                                            [[], []]             0
# 4                                      [[loggia], []]             0
# 5                                            [[], []]             0
# 6   [[after_reconstruction, garage, not_furnished]...             0
# 7                                            [[], []]             0
# 8                       [[collective], [post_office]]             0
# 9                  [[furnished], [shop, post_office]]             0
# 10                       [[after_reconstruction], []]             0
# 11                                     [[garage], []]             0
# 12       [[after_reconstruction, furnished], [train]]             0
# 13                                [[], [post_office]]             0
# 14                              [[loggia, panel], []]             0
# 15                                       [[], [shop]]             0
# 16                              [[loggia, panel], []]             0
# 17                                           [[], []]             0
# 18                              [[not_furnished], []]             0
# 19                                           [[], []]             0
# 20                 [[balcony, garage, furnished], []]             0
#
#                                                labels  is_auction  \
# 0                           [Balkon, Garáž, Vybavený]       False
# 1                                                  []       False
# 2                                        [Nevybavený]       False
# 3                                                  []       False
# 4                                            [Lodžie]       False
# 5                                                  []       False
# 6                [Po rekonstrukci, Garáž, Nevybavený]       False
# 7                                                  []       False
# 8                    [Družstevní, Pošta 5 min. pěšky]       False
# 9   [Vybavený, Obchod 6 min. pěšky, Pošta 1 min. p...       False
# 10                                  [Po rekonstrukci]       False
# 11                                            [Garáž]       False
# 12     [Po rekonstrukci, Vybavený, Vlak 8 min. pěšky]       False
# 13                               [Pošta 1 min. pěšky]       False
# 14                                 [Lodžie, Panelová]       False
# 15                              [Obchod 6 min. pěšky]       False
# 16                                 [Lodžie, Panelová]       False
# 17                                                 []       False
# 18                                       [Nevybavený]       False
# 19                                                 []       False
# 20                          [Balkon, Garáž, Vybavený]       False
#
#                                             labelsAll  \
# 0   [[personal, balcony, terrace, cellar, elevator...
# 1   [[new_building, personal, brick, elevator], [s...
# 2   [[new_building, personal, terrace, cellar, par...
# 3   [[new_building, personal, terrace, brick, cell...
# 4   [[new_building, personal, loggia, brick, cella...
# 5   [[personal, brick, cellar, elevator, partly_fu...
# 6   [[personal, after_reconstruction, terrace, bri...
# 7   [[personal, terrace, brick, cellar, elevator, ...
# 8   [[collective, brick, partly_furnished], [small...
# 9   [[personal, brick, elevator, furnished], [thea...
# 10  [[personal, after_reconstruction, terrace, bri...
# 11  [[new_building, personal, terrace, brick, park...
# 12  [[personal, after_reconstruction, brick, eleva...
# 13  [[personal, brick, cellar, partly_furnished], ...
# 14  [[personal, loggia, panel, cellar, elevator, p...
# 15  [[personal, brick, cellar, elevator, partly_fu...
# 16  [[personal, loggia, panel, cellar, elevator], ...
# 17  [[personal, brick, cellar], [small_shop, theat...
# 18  [[new_building, personal, cellar, elevator, no...
# 19  [[new_building, personal, brick, cellar, eleva...
# 20  [[personal, balcony, terrace, cellar, elevator...
#
#                                                   seo  exclusively_at_rk  \
# 0   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 1   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 2   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 3   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 4   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 5   {'category_main_cb': 1, 'category_sub_cb': 5, ...                  1
# 6   {'category_main_cb': 1, 'category_sub_cb': 9, ...                  0
# 7   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 8   {'category_main_cb': 1, 'category_sub_cb': 5, ...                  0
# 9   {'category_main_cb': 1, 'category_sub_cb': 5, ...                  1
# 10  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 11  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 12  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 13  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 14  {'category_main_cb': 1, 'category_sub_cb': 7, ...                  1
# 15  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 16  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 17  {'category_main_cb': 1, 'category_sub_cb': 5, ...                  0
# 18  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 19  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 20  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
#
#     category  has_floor_plan  \
# 0          1               0
# 1          1               1
# 2          1               1
# 3          1               0
# 4          1               1
# 5          1               0
# 6          1               1
# 7          1               0
# 8          1               1
# 9          1               0
# 10         1               1
# 11         1               0
# 12         1               0
# 13         1               0
# 14         1               0
# 15         1               0
# 16         1               0
# 17         1               0
# 18         1               1
# 19         1               1
# 20         1               1
#
#                                             _embedded  ...     hash_id  \
# 0   {'favourite': {'is_favourite': False, '_links'...  ...  1318314828
# 1   {'favourite': {'is_favourite': False, '_links'...  ...  3481568076
# 2   {'favourite': {'is_favourite': False, '_links'...  ...  2106786380
# 3   {'favourite': {'is_favourite': False, '_links'...  ...  1245102924
# 4   {'favourite': {'is_favourite': False, '_links'...  ...  2240992076
# 5   {'favourite': {'is_favourite': False, '_links'...  ...  3119788876
# 6   {'favourite': {'is_favourite': False, '_links'...  ...  1245131596
# 7   {'favourite': {'is_favourite': False, '_links'...  ...  1634022220
# 8   {'favourite': {'is_favourite': False, '_links'...  ...  4202115916
# 9   {'favourite': {'is_favourite': False, '_links'...  ...   203657804
# 10  {'favourite': {'is_favourite': False, '_links'...  ...  3014079308
# 11  {'favourite': {'is_favourite': False, '_links'...  ...  3364631372
# 12  {'favourite': {'is_favourite': False, '_links'...  ...   406422348
# 13  {'favourite': {'is_favourite': False, '_links'...  ...  2543927884
# 14  {'favourite': {'is_favourite': False, '_links'...  ...  4132430668
# 15  {'favourite': {'is_favourite': False, '_links'...  ...  3699229516
# 16  {'favourite': {'is_favourite': False, '_links'...  ...  3757101900
# 17  {'favourite': {'is_favourite': False, '_links'...  ...  1915958092
# 18  {'favourite': {'is_favourite': False, '_links'...  ...   129491788
# 19  {'favourite': {'is_favourite': False, '_links'...  ...  2581779276
# 20  {'favourite': {'is_favourite': False, '_links'...  ...   250016588
#
#    attractive_offer     price  \
# 0                 0  42769000
# 1                 0  36990000
# 2                 0  33505000
# 3                 0  13300000
# 4                 0  12026000
# 5                 0  20781000
# 6                 0         0
# 7                 0  16759000
# 8                 0  12066000
# 9                 0  16759000
# 10                0  26801000
# 11                0  14077000
# 12                0  11932000
# 13                0   9318000
# 14                0  11999000
# 15                0  10323000
# 16                0   9371000
# 17                0  13380000
# 18                0  10728000
# 19                0  21840000
# 20                0  30823000
#
#                                             price_czk  \
# 0   {'value_raw': 42769000, 'unit': '', 'name': 'C...
# 1   {'value_raw': 36990000, 'unit': '', 'name': 'C...
# 2   {'value_raw': 33505000, 'unit': '', 'name': 'C...
# 3   {'value_raw': 13300000, 'unit': '', 'name': 'C...
# 4   {'value_raw': 12026000, 'unit': '', 'name': 'C...
# 5   {'value_raw': 20781000, 'unit': '', 'name': 'C...
# 6   {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 7   {'value_raw': 16759000, 'unit': '', 'name': 'C...
# 8   {'value_raw': 12066000, 'unit': '', 'name': 'C...
# 9   {'value_raw': 16759000, 'unit': '', 'name': 'C...
# 10  {'value_raw': 26801000, 'unit': '', 'name': 'C...
# 11  {'value_raw': 14077000, 'unit': '', 'name': 'C...
# 12  {'value_raw': 11932000, 'unit': '', 'name': 'C...
# 13  {'value_raw': 9318000, 'unit': '', 'name': 'Ce...
# 14  {'value_raw': 11999000, 'unit': '', 'name': 'C...
# 15  {'value_raw': 10323000, 'unit': '', 'name': 'C...
# 16  {'value_raw': 9371000, 'unit': '', 'name': 'Ce...
# 17  {'value_raw': 13380000, 'unit': '', 'name': 'C...
# 18  {'value_raw': 10728000, 'unit': '', 'name': 'C...
# 19  {'value_raw': 21840000, 'unit': '', 'name': 'C...
# 20  {'value_raw': 30823000, 'unit': '', 'name': 'C...
#
#                                                _links    rus  \
# 0   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...   True
# 5   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 6   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 7   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 8   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 9   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 10  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 11  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 12  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 13  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 14  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 15  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 16  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 17  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 18  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 19  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 20  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                        name  region_tip  \
# 0                   Prodej bytu 4+kk 317 m²     3419754
# 1                   Prodej bytu 2+kk 130 m²           0
# 2         Prodej bytu 4+kk 379 m² (Mezonet)           0
# 3                    Prodej bytu 2+kk 75 m²           0
# 4    Prodej bytu 2+kk 67 m² (Jednopodlažní)           0
# 5    Prodej bytu 2+1 130 m² (Jednopodlažní)           0
# 6                    Prodej bytu 4+1 107 m²           0
# 7                    Prodej bytu 2+kk 57 m²           0
# 8                     Prodej bytu 2+1 80 m²           0
# 9                     Prodej bytu 2+1 85 m²           0
# 10  Prodej bytu 3+kk 197 m² (Jednopodlažní)           0
# 11                   Prodej bytu 2+kk 93 m²           0
# 12            Prodej bytu 2+kk 61 m² (Loft)           0
# 13                   Prodej bytu 2+kk 72 m²           0
# 14                   Prodej bytu 3+1 107 m²           0
# 15                   Prodej bytu 1+kk 45 m²           0
# 16   Prodej bytu 2+kk 58 m² (Jednopodlažní)           0
# 17                    Prodej bytu 2+1 80 m²           0
# 18                   Prodej bytu 1+kk 44 m²           0
# 19                   Prodej bytu 2+kk 75 m²           0
# 20                  Prodej bytu 4+kk 144 m²           0
#
#                                                   gps  has_matterport_url
# 0   {'lat': 50.07261362854839, 'lon': 14.466933371...               False
# 1   {'lat': 50.06533562854839, 'lon': 14.459462371...               False
# 2   {'lat': 50.12693562854839, 'lon': 14.390640371...               False
# 3   {'lat': 50.004075628548385, 'lon': 14.53868937...               False
# 4   {'lat': 50.073510628548384, 'lon': 14.51542137...               False
# 5   {'lat': 50.07916762854838, 'lon': 14.445585371...               False
# 6   {'lat': 50.066052628548384, 'lon': 14.33694137...               False
# 7   {'lat': 50.091805628548386, 'lon': 14.46582337...               False
# 8   {'lat': 50.06210462854839, 'lon': 14.502127371...               False
# 9   {'lat': 50.076707628548384, 'lon': 14.43938637...               False
# 10  {'lat': 50.06387862854839, 'lon': 14.448098371...               False
# 11  {'lat': 50.04535462854839, 'lon': 14.466575371...               False
# 12  {'lat': 50.09027562854838, 'lon': 14.449549371...                True
# 13  {'lat': 50.06278362854839, 'lon': 14.505654371...               False
# 14  {'lat': 50.00814962854839, 'lon': 14.425926371...               False
# 15  {'lat': 50.06607562854839, 'lon': 14.430434371...               False
# 16  {'lat': 50.11316462854839, 'lon': 14.517314371...               False
# 17  {'lat': 50.078480628548384, 'lon': 14.46171937...                True
# 18  {'lat': 50.04188662854839, 'lon': 14.393097371...               False
# 19  {'lat': 50.06533562854839, 'lon': 14.459462371...               False
# 20  {'lat': 50.069344628548386, 'lon': 14.39355537...               False
#
# [21 rows x 27 columns]

# %%
pd.DataFrame(d['_embedded']['estates'])

# %%
def convert_sreality_data_to_df(sreality_data):
    data = sreality_data['_embedded']['estates']
    return pd.DataFrame(data)

raw = convert_sreality_data_to_df(d)

# %%
raw
# Out:
#                                        labelsReleased  has_panorama  \
# 0                  [[balcony, garage, furnished], []]             0
# 1                                            [[], []]             0
# 2                               [[not_furnished], []]             0
# 3                                            [[], []]             0
# 4                                      [[loggia], []]             0
# 5                                            [[], []]             0
# 6   [[after_reconstruction, garage, not_furnished]...             0
# 7                                            [[], []]             0
# 8                       [[collective], [post_office]]             0
# 9                  [[furnished], [shop, post_office]]             0
# 10                       [[after_reconstruction], []]             0
# 11                                     [[garage], []]             0
# 12       [[after_reconstruction, furnished], [train]]             0
# 13                                [[], [post_office]]             0
# 14                              [[loggia, panel], []]             0
# 15                                       [[], [shop]]             0
# 16                              [[loggia, panel], []]             0
# 17                                           [[], []]             0
# 18                              [[not_furnished], []]             0
# 19                                           [[], []]             0
# 20                 [[balcony, garage, furnished], []]             0
#
#                                                labels  is_auction  \
# 0                           [Balkon, Garáž, Vybavený]       False
# 1                                                  []       False
# 2                                        [Nevybavený]       False
# 3                                                  []       False
# 4                                            [Lodžie]       False
# 5                                                  []       False
# 6                [Po rekonstrukci, Garáž, Nevybavený]       False
# 7                                                  []       False
# 8                    [Družstevní, Pošta 5 min. pěšky]       False
# 9   [Vybavený, Obchod 6 min. pěšky, Pošta 1 min. p...       False
# 10                                  [Po rekonstrukci]       False
# 11                                            [Garáž]       False
# 12     [Po rekonstrukci, Vybavený, Vlak 8 min. pěšky]       False
# 13                               [Pošta 1 min. pěšky]       False
# 14                                 [Lodžie, Panelová]       False
# 15                              [Obchod 6 min. pěšky]       False
# 16                                 [Lodžie, Panelová]       False
# 17                                                 []       False
# 18                                       [Nevybavený]       False
# 19                                                 []       False
# 20                          [Balkon, Garáž, Vybavený]       False
#
#                                             labelsAll  \
# 0   [[personal, balcony, terrace, cellar, elevator...
# 1   [[new_building, personal, brick, elevator], [s...
# 2   [[new_building, personal, terrace, cellar, par...
# 3   [[new_building, personal, terrace, brick, cell...
# 4   [[new_building, personal, loggia, brick, cella...
# 5   [[personal, brick, cellar, elevator, partly_fu...
# 6   [[personal, after_reconstruction, terrace, bri...
# 7   [[personal, terrace, brick, cellar, elevator, ...
# 8   [[collective, brick, partly_furnished], [small...
# 9   [[personal, brick, elevator, furnished], [thea...
# 10  [[personal, after_reconstruction, terrace, bri...
# 11  [[new_building, personal, terrace, brick, park...
# 12  [[personal, after_reconstruction, brick, eleva...
# 13  [[personal, brick, cellar, partly_furnished], ...
# 14  [[personal, loggia, panel, cellar, elevator, p...
# 15  [[personal, brick, cellar, elevator, partly_fu...
# 16  [[personal, loggia, panel, cellar, elevator], ...
# 17  [[personal, brick, cellar], [small_shop, theat...
# 18  [[new_building, personal, cellar, elevator, no...
# 19  [[new_building, personal, brick, cellar, eleva...
# 20  [[personal, balcony, terrace, cellar, elevator...
#
#                                                   seo  exclusively_at_rk  \
# 0   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 1   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 2   {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 3   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 4   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 5   {'category_main_cb': 1, 'category_sub_cb': 5, ...                  1
# 6   {'category_main_cb': 1, 'category_sub_cb': 9, ...                  0
# 7   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 8   {'category_main_cb': 1, 'category_sub_cb': 5, ...                  0
# 9   {'category_main_cb': 1, 'category_sub_cb': 5, ...                  1
# 10  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 11  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 12  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 13  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 14  {'category_main_cb': 1, 'category_sub_cb': 7, ...                  1
# 15  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 16  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 17  {'category_main_cb': 1, 'category_sub_cb': 5, ...                  0
# 18  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 19  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 20  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
#
#     category  has_floor_plan  \
# 0          1               0
# 1          1               1
# 2          1               1
# 3          1               0
# 4          1               1
# 5          1               0
# 6          1               1
# 7          1               0
# 8          1               1
# 9          1               0
# 10         1               1
# 11         1               0
# 12         1               0
# 13         1               0
# 14         1               0
# 15         1               0
# 16         1               0
# 17         1               0
# 18         1               1
# 19         1               1
# 20         1               1
#
#                                             _embedded  ...     hash_id  \
# 0   {'favourite': {'is_favourite': False, '_links'...  ...  1318314828
# 1   {'favourite': {'is_favourite': False, '_links'...  ...  3481568076
# 2   {'favourite': {'is_favourite': False, '_links'...  ...  2106786380
# 3   {'favourite': {'is_favourite': False, '_links'...  ...  1245102924
# 4   {'favourite': {'is_favourite': False, '_links'...  ...  2240992076
# 5   {'favourite': {'is_favourite': False, '_links'...  ...  3119788876
# 6   {'favourite': {'is_favourite': False, '_links'...  ...  1245131596
# 7   {'favourite': {'is_favourite': False, '_links'...  ...  1634022220
# 8   {'favourite': {'is_favourite': False, '_links'...  ...  4202115916
# 9   {'favourite': {'is_favourite': False, '_links'...  ...   203657804
# 10  {'favourite': {'is_favourite': False, '_links'...  ...  3014079308
# 11  {'favourite': {'is_favourite': False, '_links'...  ...  3364631372
# 12  {'favourite': {'is_favourite': False, '_links'...  ...   406422348
# 13  {'favourite': {'is_favourite': False, '_links'...  ...  2543927884
# 14  {'favourite': {'is_favourite': False, '_links'...  ...  4132430668
# 15  {'favourite': {'is_favourite': False, '_links'...  ...  3699229516
# 16  {'favourite': {'is_favourite': False, '_links'...  ...  3757101900
# 17  {'favourite': {'is_favourite': False, '_links'...  ...  1915958092
# 18  {'favourite': {'is_favourite': False, '_links'...  ...   129491788
# 19  {'favourite': {'is_favourite': False, '_links'...  ...  2581779276
# 20  {'favourite': {'is_favourite': False, '_links'...  ...   250016588
#
#    attractive_offer     price  \
# 0                 0  42769000
# 1                 0  36990000
# 2                 0  33505000
# 3                 0  13300000
# 4                 0  12026000
# 5                 0  20781000
# 6                 0         0
# 7                 0  16759000
# 8                 0  12066000
# 9                 0  16759000
# 10                0  26801000
# 11                0  14077000
# 12                0  11932000
# 13                0   9318000
# 14                0  11999000
# 15                0  10323000
# 16                0   9371000
# 17                0  13380000
# 18                0  10728000
# 19                0  21840000
# 20                0  30823000
#
#                                             price_czk  \
# 0   {'value_raw': 42769000, 'unit': '', 'name': 'C...
# 1   {'value_raw': 36990000, 'unit': '', 'name': 'C...
# 2   {'value_raw': 33505000, 'unit': '', 'name': 'C...
# 3   {'value_raw': 13300000, 'unit': '', 'name': 'C...
# 4   {'value_raw': 12026000, 'unit': '', 'name': 'C...
# 5   {'value_raw': 20781000, 'unit': '', 'name': 'C...
# 6   {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 7   {'value_raw': 16759000, 'unit': '', 'name': 'C...
# 8   {'value_raw': 12066000, 'unit': '', 'name': 'C...
# 9   {'value_raw': 16759000, 'unit': '', 'name': 'C...
# 10  {'value_raw': 26801000, 'unit': '', 'name': 'C...
# 11  {'value_raw': 14077000, 'unit': '', 'name': 'C...
# 12  {'value_raw': 11932000, 'unit': '', 'name': 'C...
# 13  {'value_raw': 9318000, 'unit': '', 'name': 'Ce...
# 14  {'value_raw': 11999000, 'unit': '', 'name': 'C...
# 15  {'value_raw': 10323000, 'unit': '', 'name': 'C...
# 16  {'value_raw': 9371000, 'unit': '', 'name': 'Ce...
# 17  {'value_raw': 13380000, 'unit': '', 'name': 'C...
# 18  {'value_raw': 10728000, 'unit': '', 'name': 'C...
# 19  {'value_raw': 21840000, 'unit': '', 'name': 'C...
# 20  {'value_raw': 30823000, 'unit': '', 'name': 'C...
#
#                                                _links    rus  \
# 0   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...   True
# 5   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 6   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 7   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 8   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 9   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 10  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 11  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 12  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 13  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 14  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 15  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 16  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 17  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 18  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 19  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 20  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                        name  region_tip  \
# 0                   Prodej bytu 4+kk 317 m²     3419754
# 1                   Prodej bytu 2+kk 130 m²           0
# 2         Prodej bytu 4+kk 379 m² (Mezonet)           0
# 3                    Prodej bytu 2+kk 75 m²           0
# 4    Prodej bytu 2+kk 67 m² (Jednopodlažní)           0
# 5    Prodej bytu 2+1 130 m² (Jednopodlažní)           0
# 6                    Prodej bytu 4+1 107 m²           0
# 7                    Prodej bytu 2+kk 57 m²           0
# 8                     Prodej bytu 2+1 80 m²           0
# 9                     Prodej bytu 2+1 85 m²           0
# 10  Prodej bytu 3+kk 197 m² (Jednopodlažní)           0
# 11                   Prodej bytu 2+kk 93 m²           0
# 12            Prodej bytu 2+kk 61 m² (Loft)           0
# 13                   Prodej bytu 2+kk 72 m²           0
# 14                   Prodej bytu 3+1 107 m²           0
# 15                   Prodej bytu 1+kk 45 m²           0
# 16   Prodej bytu 2+kk 58 m² (Jednopodlažní)           0
# 17                    Prodej bytu 2+1 80 m²           0
# 18                   Prodej bytu 1+kk 44 m²           0
# 19                   Prodej bytu 2+kk 75 m²           0
# 20                  Prodej bytu 4+kk 144 m²           0
#
#                                                   gps  has_matterport_url
# 0   {'lat': 50.07261362854839, 'lon': 14.466933371...               False
# 1   {'lat': 50.06533562854839, 'lon': 14.459462371...               False
# 2   {'lat': 50.12693562854839, 'lon': 14.390640371...               False
# 3   {'lat': 50.004075628548385, 'lon': 14.53868937...               False
# 4   {'lat': 50.073510628548384, 'lon': 14.51542137...               False
# 5   {'lat': 50.07916762854838, 'lon': 14.445585371...               False
# 6   {'lat': 50.066052628548384, 'lon': 14.33694137...               False
# 7   {'lat': 50.091805628548386, 'lon': 14.46582337...               False
# 8   {'lat': 50.06210462854839, 'lon': 14.502127371...               False
# 9   {'lat': 50.076707628548384, 'lon': 14.43938637...               False
# 10  {'lat': 50.06387862854839, 'lon': 14.448098371...               False
# 11  {'lat': 50.04535462854839, 'lon': 14.466575371...               False
# 12  {'lat': 50.09027562854838, 'lon': 14.449549371...                True
# 13  {'lat': 50.06278362854839, 'lon': 14.505654371...               False
# 14  {'lat': 50.00814962854839, 'lon': 14.425926371...               False
# 15  {'lat': 50.06607562854839, 'lon': 14.430434371...               False
# 16  {'lat': 50.11316462854839, 'lon': 14.517314371...               False
# 17  {'lat': 50.078480628548384, 'lon': 14.46171937...                True
# 18  {'lat': 50.04188662854839, 'lon': 14.393097371...               False
# 19  {'lat': 50.06533562854839, 'lon': 14.459462371...               False
# 20  {'lat': 50.069344628548386, 'lon': 14.39355537...               False
#
# [21 rows x 27 columns]

# %% [markdown]
# ### 1c. link function `1b` into function `1a`

# %%
df = convert_sreality_data_to_df(request_sreality(0, 'flat', 'sell', 10))
df.head()
# Out:
#                                    labelsReleased  has_panorama  \
# 0                 [[parking_lots, furnished], []]             0
# 1          [[new_building, parking_lots], [shop]]             0
# 2   [[new_building, terrace, furnished], [metro]]             0
# 3                [[in_construction, terrace], []]             0
# 4  [[after_reconstruction, partly_furnished], []]             0
#
#                                               labels  is_auction  \
# 0                              [Parkování, Vybavený]       False
# 1       [Novostavba, Parkování, Obchod 6 min. pěšky]       False
# 2  [Novostavba, Terasa, Vybavený, Metro 5 min. pě...       False
# 3                              [Ve výstavbě, Terasa]       False
# 4               [Po rekonstrukci, Částečně vybavený]       False
#
#                                            labelsAll  \
# 0  [[personal, balcony, brick, cellar, elevator, ...
# 1  [[new_building, personal, balcony, cellar, ele...
# 2  [[new_building, personal, balcony, terrace, br...
# 3  [[in_construction, personal, terrace], [candy_...
# 4  [[personal, after_reconstruction, balcony, bri...
#
#                                                  seo  exclusively_at_rk  \
# 0  {'category_main_cb': 1, 'category_sub_cb': 3, ...                  0
# 1  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 2  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 3  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 4  {'category_main_cb': 1, 'category_sub_cb': 9, ...                  0
#
#    category  has_floor_plan  \
# 0         1               0
# 1         1               1
# 2         1               1
# 3         1               1
# 4         1               1
#
#                                            _embedded  ...     hash_id  \
# 0  {'favourite': {'is_favourite': False, '_links'...  ...   722592588
# 1  {'favourite': {'is_favourite': False, '_links'...  ...  4070581580
# 2  {'favourite': {'is_favourite': False, '_links'...  ...   687641420
# 3  {'favourite': {'is_favourite': False, '_links'...  ...  3349996364
# 4  {'favourite': {'is_favourite': False, '_links'...  ...   887763788
#
#   attractive_offer     price  \
# 0                0   9787000
# 1                0  16366000
# 2                0  42863000
# 3                0  19360000
# 4                0  38699000
#
#                                            price_czk  \
# 0  {'value_raw': 9787000, 'unit': '', 'name': 'Ce...
# 1  {'value_raw': 16366000, 'unit': '', 'name': 'C...
# 2  {'value_raw': 42863000, 'unit': '', 'name': 'C...
# 3  {'value_raw': 19360000, 'unit': '', 'name': 'C...
# 4  {'value_raw': 38699000, 'unit': '', 'name': 'C...
#
#                                               _links    rus  \
# 0  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                 name  region_tip  \
# 0              Prodej bytu 1+1 60 m²     3418491
# 1            Prodej bytu 3+kk 103 m²           0
# 2  Prodej bytu 3+kk 160 m² (Mezonet)           0
# 3   Prodej bytu 2+kk 97 m² (Mezonet)           0
# 4             Prodej bytu 4+1 189 m²           0
#
#                                                  gps  has_matterport_url
# 0  {'lat': 50.12930762854839, 'lon': 14.588600371...               False
# 1  {'lat': 50.14428862854839, 'lon': 14.532566371...               False
# 2  {'lat': 50.06318362854839, 'lon': 14.448837371...               False
# 3  {'lat': 50.024453628548386, 'lon': 14.39995737...               False
# 4  {'lat': 50.05999162854839, 'lon': 14.421697371...               False
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (21, 27)

# %% [markdown]
# ### 1c. Combining multiple requests into single df
#
# * Function should parametrize:
#     * `start_page` and `end_page`
#     * request parameters
# * construct a list of individual request dfs
# * then feed it into `pd.concat` function

# %%
raw.shape

# %%
def request_multiple_sreality(start_page, end_page, category_main_str, category_type_str, locality_region_id=10):
    visit_pages = range(start_page, end_page)
    list_of_dfs = []
    for page in visit_pages:
        df = convert_sreality_data_to_df(request_sreality(page, category_main_str, category_type_str, locality_region_id))
        list_of_dfs.append(df)
    return pd.concat(list_of_dfs)

# %%
df = request_multiple_sreality(1, 5, 'flat', 'sell', locality_region_id=10)

# %%
df.shape
# Out:
# (84, 27)

# %%
df.head()
# Out:
#                                    labelsReleased  has_panorama  \
# 0                 [[parking_lots, furnished], []]             0
# 1          [[new_building, parking_lots], [shop]]             0
# 2   [[new_building, terrace, furnished], [metro]]             0
# 3                [[in_construction, terrace], []]             0
# 4  [[after_reconstruction, partly_furnished], []]             0
#
#                                               labels  is_auction  \
# 0                              [Parkování, Vybavený]       False
# 1       [Novostavba, Parkování, Obchod 6 min. pěšky]       False
# 2  [Novostavba, Terasa, Vybavený, Metro 5 min. pě...       False
# 3                              [Ve výstavbě, Terasa]       False
# 4               [Po rekonstrukci, Částečně vybavený]       False
#
#                                            labelsAll  \
# 0  [[personal, balcony, brick, cellar, elevator, ...
# 1  [[new_building, personal, balcony, cellar, ele...
# 2  [[new_building, personal, balcony, terrace, br...
# 3  [[in_construction, personal, terrace], [candy_...
# 4  [[personal, after_reconstruction, balcony, bri...
#
#                                                  seo  exclusively_at_rk  \
# 0  {'category_main_cb': 1, 'category_sub_cb': 3, ...                  0
# 1  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 2  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 3  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 4  {'category_main_cb': 1, 'category_sub_cb': 9, ...                  0
#
#    category  has_floor_plan  \
# 0         1               0
# 1         1               1
# 2         1               1
# 3         1               1
# 4         1               1
#
#                                            _embedded  ...     hash_id  \
# 0  {'favourite': {'is_favourite': False, '_links'...  ...   722592588
# 1  {'favourite': {'is_favourite': False, '_links'...  ...  4070581580
# 2  {'favourite': {'is_favourite': False, '_links'...  ...   687641420
# 3  {'favourite': {'is_favourite': False, '_links'...  ...  3349996364
# 4  {'favourite': {'is_favourite': False, '_links'...  ...   887763788
#
#   attractive_offer     price  \
# 0                0   9787000
# 1                0  16366000
# 2                0  42863000
# 3                0  19360000
# 4                0  38699000
#
#                                            price_czk  \
# 0  {'value_raw': 9787000, 'unit': '', 'name': 'Ce...
# 1  {'value_raw': 16366000, 'unit': '', 'name': 'C...
# 2  {'value_raw': 42863000, 'unit': '', 'name': 'C...
# 3  {'value_raw': 19360000, 'unit': '', 'name': 'C...
# 4  {'value_raw': 38699000, 'unit': '', 'name': 'C...
#
#                                               _links    rus  \
# 0  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                 name  region_tip  \
# 0              Prodej bytu 1+1 60 m²     3418491
# 1            Prodej bytu 3+kk 103 m²           0
# 2  Prodej bytu 3+kk 160 m² (Mezonet)           0
# 3   Prodej bytu 2+kk 97 m² (Mezonet)           0
# 4             Prodej bytu 4+1 189 m²           0
#
#                                                  gps  has_matterport_url
# 0  {'lat': 50.12930762854839, 'lon': 14.588600371...               False
# 1  {'lat': 50.14428862854839, 'lon': 14.532566371...               False
# 2  {'lat': 50.06318362854839, 'lon': 14.448837371...               False
# 3  {'lat': 50.024453628548386, 'lon': 14.39995737...               False
# 4  {'lat': 50.05999162854839, 'lon': 14.421697371...               False
#
# [5 rows x 27 columns]

# %%
# reset the index
df.reset_index(drop=True, inplace=True)

# %%
df.index

# %% [markdown]
# #### Task 2: Cleaning data
#
# __2a. Filter columns__
# * filter only columns: `['locality', 'price', 'name', 'gps','hash_id','exclusively_at_rk']`
# * use `.copy()` to avoid `SettingWithCopyWarning` later

# %%
# display the columns
df.columns
# Out:
# Index(['labelsReleased', 'has_panorama', 'labels', 'is_auction', 'labelsAll',
#        'seo', 'exclusively_at_rk', 'category', 'has_floor_plan', '_embedded',
#        'paid_logo', 'locality', 'has_video', 'advert_images_count', 'new',
#        'auctionPrice', 'type', 'hash_id', 'attractive_offer', 'price',
#        'price_czk', '_links', 'rus', 'name', 'region_tip', 'gps',
#        'has_matterport_url'],
#       dtype='object')

# %% [markdown]
# Copy selection into new one

# %%
columns_to_keep = ['locality', 'price', 'name', 'gps','hash_id','exclusively_at_rk']
df_clean = df[columns_to_keep].copy()
df_clean.head()
# Out:
#               locality     price                               name  \
# 0      Praha 9 - Vinoř   9787000              Prodej bytu 1+1 60 m²
# 1   Praha 9 - Čakovice  16366000            Prodej bytu 3+kk 103 m²
# 2  Praha 2 - Vinohrady  42863000  Prodej bytu 3+kk 160 m² (Mezonet)
# 3  Praha 5 - Hlubočepy  19360000   Prodej bytu 2+kk 97 m² (Mezonet)
# 4    Praha 5 - Smíchov  38699000             Prodej bytu 4+1 189 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.12930762854839, 'lon': 14.588600371...   722592588
# 1  {'lat': 50.14428862854839, 'lon': 14.532566371...  4070581580
# 2  {'lat': 50.06318362854839, 'lon': 14.448837371...   687641420
# 3  {'lat': 50.024453628548386, 'lon': 14.39995737...  3349996364
# 4  {'lat': 50.05999162854839, 'lon': 14.421697371...   887763788
#
#    exclusively_at_rk
# 0                  0
# 1                  1
# 2                  1
# 3                  1
# 4                  0

# %% [markdown]
# ### 2b: GPS
# * Convert dictionary in `gps` column into two columns - `lat` and `lon`
# * use apply function on gps column
# * Note apply can return multiple columns

# %%
df_clean.loc[1:2, 'gps']

# %%
df_clean[['lat', 'lon']] = df_clean.gps.apply(lambda x: pd.Series({'lat': x['lat'], 'lon': x['lon']}))
# Out:
#               locality     price                               name  \
# 0      Praha 9 - Vinoř   9787000              Prodej bytu 1+1 60 m²
# 1   Praha 9 - Čakovice  16366000            Prodej bytu 3+kk 103 m²
# 2  Praha 2 - Vinohrady  42863000  Prodej bytu 3+kk 160 m² (Mezonet)
# 3  Praha 5 - Hlubočepy  19360000   Prodej bytu 2+kk 97 m² (Mezonet)
# 4    Praha 5 - Smíchov  38699000             Prodej bytu 4+1 189 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.12930762854839, 'lon': 14.588600371...   722592588
# 1  {'lat': 50.14428862854839, 'lon': 14.532566371...  4070581580
# 2  {'lat': 50.06318362854839, 'lon': 14.448837371...   687641420
# 3  {'lat': 50.024453628548386, 'lon': 14.39995737...  3349996364
# 4  {'lat': 50.05999162854839, 'lon': 14.421697371...   887763788
#
#    exclusively_at_rk        lon        lat
# 0                  0  14.588600  50.129308
# 1                  1  14.532566  50.144289
# 2                  1  14.448837  50.063184
# 3                  1  14.399957  50.024454
# 4                  0  14.421697  50.059992

# %%
df_clean.head()

# %% [markdown]
# ### 2c. Get flat type from name
#
# * Name is always represented by string `Prodej bytu [type of flat] [Area] m^2`
# * Try picking third word in string
# * Check meaningfulness using `.value_counts()`

# %%
df_clean.name[0]
# Out:
# 'Prodej bytu 1+1\xa060\xa0m²'

# %%
df_clean.name[0].split(' ')
# Out:
# ['Prodej', 'bytu', '1+1\xa060\xa0m²']

# %%
# type of flat (' ')
df_clean['type_of_flat'] = df_clean.name.apply(lambda x: x.split(' ')[2])

# %%
# flat_type ()
df_clean['flat_type'] = df_clean.name.apply(lambda x: x.split()[2])

# %%
df_clean['flat_type'].value_counts()
# Out:
# flat_type
# 2+kk        27
# 3+kk        16
# 4+kk        10
# 2+1          9
# 4+1          7
# 3+1          5
# 1+1          4
# 1+kk         4
# atypické     1
# 5+1          1
# Name: count, dtype: int64

# %%
df_clean['type_of_flat'].value_counts()
# Out:
# type_of_flat
# 2+kk          27
# 3+kk          16
# 4+kk          10
# 1+kk           4
# 1+1 60 m²      2
# 2+1 111 m²     2
# 4+1 107 m²     2
# 2+1 80 m²      2
# 3+1 103 m²     1
# atypické       1
# 4+1 189 m²     1
# 2+1 95 m²      1
# 3+1 117 m²     1
# 3+1 96 m²      1
# 3+1 130 m²     1
# 2+1 96 m²      1
# 4+1 290 m²     1
# 1+1 73 m²      1
# 4+1 160 m²     1
# 1+1 50 m²      1
# 4+1 117 m²     1
# 4+1 130 m²     1
# 2+1 130 m²     1
# 2+1 85 m²      1
# 3+1 107 m²     1
# 5+1 214 m²     1
# 2+1 72 m²      1
# Name: count, dtype: int64

# %% [markdown]
# ### 2d. Get the area of a flat from name
#
# * Naive: select the word before last word - save as `area1`
# * Then try navigating using the index of `'m²'` in the splitted string - save as `area2`
# * If this also fail, then you will need to use regex - `import re` - save as `area3`

# %%
df_clean['area1'] = df_clean.name.apply(lambda x: int(x.split()[3]))
df_clean.head()
# Out:
#               locality     price                               name  \
# 0      Praha 9 - Vinoř   9787000              Prodej bytu 1+1 60 m²
# 1   Praha 9 - Čakovice  16366000            Prodej bytu 3+kk 103 m²
# 2  Praha 2 - Vinohrady  42863000  Prodej bytu 3+kk 160 m² (Mezonet)
# 3  Praha 5 - Hlubočepy  19360000   Prodej bytu 2+kk 97 m² (Mezonet)
# 4    Praha 5 - Smíchov  38699000             Prodej bytu 4+1 189 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.12930762854839, 'lon': 14.588600371...   722592588
# 1  {'lat': 50.14428862854839, 'lon': 14.532566371...  4070581580
# 2  {'lat': 50.06318362854839, 'lon': 14.448837371...   687641420
# 3  {'lat': 50.024453628548386, 'lon': 14.39995737...  3349996364
# 4  {'lat': 50.05999162854839, 'lon': 14.421697371...   887763788
#
#    exclusively_at_rk        lon        lat type_of_flat flat_type  area1  \
# 0                  0  14.588600  50.129308    1+1 60 m²       1+1     60
# 1                  1  14.532566  50.144289         3+kk      3+kk    103
# 2                  1  14.448837  50.063184         3+kk      3+kk    160
# 3                  1  14.399957  50.024454         2+kk      2+kk     97
# 4                  0  14.421697  50.059992   4+1 189 m²       4+1    189
#
#    area2  area3
# 0     60     60
# 1    103    103
# 2    160    160
# 3     97     97
# 4    189    189

# %%
def name_to_area(nm):
    splitted_str = nm.split()
    m2_idx = splitted_str.index('m²')
    return int(splitted_str[m2_idx - 1])

df_clean['area2'] = df_clean.name.apply(name_to_area)
df_clean.head()
# Out:
#               locality     price                               name  \
# 0      Praha 9 - Vinoř   9787000              Prodej bytu 1+1 60 m²
# 1   Praha 9 - Čakovice  16366000            Prodej bytu 3+kk 103 m²
# 2  Praha 2 - Vinohrady  42863000  Prodej bytu 3+kk 160 m² (Mezonet)
# 3  Praha 5 - Hlubočepy  19360000   Prodej bytu 2+kk 97 m² (Mezonet)
# 4    Praha 5 - Smíchov  38699000             Prodej bytu 4+1 189 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.12930762854839, 'lon': 14.588600371...   722592588
# 1  {'lat': 50.14428862854839, 'lon': 14.532566371...  4070581580
# 2  {'lat': 50.06318362854839, 'lon': 14.448837371...   687641420
# 3  {'lat': 50.024453628548386, 'lon': 14.39995737...  3349996364
# 4  {'lat': 50.05999162854839, 'lon': 14.421697371...   887763788
#
#    exclusively_at_rk        lon        lat type_of_flat flat_type  area1  \
# 0                  0  14.588600  50.129308    1+1 60 m²       1+1     60
# 1                  1  14.532566  50.144289         3+kk      3+kk    103
# 2                  1  14.448837  50.063184         3+kk      3+kk    160
# 3                  1  14.399957  50.024454         2+kk      2+kk     97
# 4                  0  14.421697  50.059992   4+1 189 m²       4+1    189
#
#    area2  area3
# 0     60     60
# 1    103    103
# 2    160    160
# 3     97     97
# 4    189    189

# %%
# regular expression to find characters before '+' and behind '+'
def flat_type(x:str):
    # \d+ represents one or more digit(s)
    # \s is a space character
    # \w+ is one or more word character(s)
    # * represents 0 or more
    ft = re.findall(r'(\d+)\s*\+\s*(\w+)', x)
    return ft

# %%
sample_text = 'Prodej bytu 3+kk 71 m²'
print(f"Initial text: {sample_text}")
print(f"Processed text: {flat_type(sample_text)}")
# Out:
# Initial text: Prodej bytu 3+kk 71 m²
# Processed text: [('3', 'kk')]

# %%
df_clean['area3'] = df_clean.name.apply(lambda x: int(re.findall(r'(\d+)\s*m²', x)[0]))
df_clean.head()
# Out:
#               locality     price                               name  \
# 0      Praha 9 - Vinoř   9787000              Prodej bytu 1+1 60 m²
# 1   Praha 9 - Čakovice  16366000            Prodej bytu 3+kk 103 m²
# 2  Praha 2 - Vinohrady  42863000  Prodej bytu 3+kk 160 m² (Mezonet)
# 3  Praha 5 - Hlubočepy  19360000   Prodej bytu 2+kk 97 m² (Mezonet)
# 4    Praha 5 - Smíchov  38699000             Prodej bytu 4+1 189 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.12930762854839, 'lon': 14.588600371...   722592588
# 1  {'lat': 50.14428862854839, 'lon': 14.532566371...  4070581580
# 2  {'lat': 50.06318362854839, 'lon': 14.448837371...   687641420
# 3  {'lat': 50.024453628548386, 'lon': 14.39995737...  3349996364
# 4  {'lat': 50.05999162854839, 'lon': 14.421697371...   887763788
#
#    exclusively_at_rk        lon        lat type_of_flat flat_type  area1  \
# 0                  0  14.588600  50.129308    1+1 60 m²       1+1     60
# 1                  1  14.532566  50.144289         3+kk      3+kk    103
# 2                  1  14.448837  50.063184         3+kk      3+kk    160
# 3                  1  14.399957  50.024454         2+kk      2+kk     97
# 4                  0  14.421697  50.059992   4+1 189 m²       4+1    189
#
#    area2  area3
# 0     60     60
# 1    103    103
# 2    160    160
# 3     97     97
# 4    189    189

# %% [markdown]
# __Check if the three areas are equal__

# %%
(df_clean['area1'] == df_clean['area2']).all()
# Out:
# np.True_
