# %% [markdown]
# # Seminar 3: Data Formats and APIs
#
# March 25, 2025
# - Vilém Krejcar
#
# ______________________________

# %% [markdown]
# ## What are we going to learn
#
# - What are the most popular data formats and how to work with them
# - HTTP requests
# - How to scrape websites

# %% [markdown]
# ## 1. Data formats
#
# ### Data Serialization and Formats
# Serialization is the process of converting data structures or objects into a format that can be easily stored and shared. Common data formats in Python include:
# - **JSON**: Lightweight and commonly used for APIs.
# - **CSV**: Ideal for tabular data, especially in spreadsheets.
# - **Excel**: Classic data storage everyone is aware of.

# %% [markdown]
# #### JSON

# %%
import json
import pandas as pd
import os
    
data = {
    "name": "Alice",
    "age": 30,
    "is_member": True,
    "hobbies": ["reading", "biking", "coding"]
}

# Define the directory and file path
directory = 'Data'
file_path = os.path.join(directory, 'json_sample.json')


# Create the directory if it doesn't exist
os.makedirs(directory, exist_ok=True)

# Serialize to JSON -> file
with open(file_path, 'w') as f:
    json.dump(data, f)

# %%
# Deserialize JSON from file -> Python
with open(file_path, 'r') as f:
    data_loaded = json.load(f)

print("Loaded JSON data:", data_loaded)
# Out:
# Loaded JSON data: {'name': 'Alice', 'age': 30, 'is_member': True, 'hobbies': ['reading', 'biking', 'coding']}

# %%
pd.DataFrame(data_loaded)
# Out:
#     name  age  is_member  hobbies
# 0  Alice   30       True  reading
# 1  Alice   30       True   biking
# 2  Alice   30       True   coding

# %%
pd.DataFrame(data_loaded)
# Out:
#     name  age  is_member  hobbies
# 0  Alice   30       True  reading
# 1  Alice   30       True   biking
# 2  Alice   30       True   coding

# %% [markdown]
# #### CSV

# %%
import csv

data = [
    ["Name", "Age", "Occupation"],
    ["Alice", 30, "Engineer"],
    ["Bob", 25, "Designer"],
    ["Charlie", 35, "Teacher"]
]

# Again define the directory and create new file path
directory = 'Data'
file_path = os.path.join(directory, 'csv_sample.csv')

# Check if the directory exists
os.makedirs(directory, exist_ok=True)

# Write to CSV
with open(file_path, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(data)

# %%
# Read CSV
csv_data = []
with open(file_path, 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        #print(row)
        csv_data.append(row)
csv_data
# Out:
# [['Name', 'Age', 'Occupation'],
#  ['Alice', '30', 'Engineer'],
#  ['Bob', '25', 'Designer'],
#  ['Charlie', '35', 'Teacher']]

# %%
pd.DataFrame(csv_data)
# Out:
#          0    1           2
# 0     Name  Age  Occupation
# 1    Alice   30    Engineer
# 2      Bob   25    Designer
# 3  Charlie   35     Teacher

# %% [markdown]
# #### Excel

# %%
data = {
    "name": "Thomas",
    "age": 30,
    "is_member": True,
    "hobbies": "reading, biking, coding"
}

# Create a DataFrame from the dictionary.
# Wrapping data in a list makes each key a column with one row.
df = pd.DataFrame([data])

# Define the directory and file path for the Excel file.
directory = 'Data'
file_path = os.path.join(directory, 'excel_sample.xlsx')

# Create the directory if it doesn't exist.
os.makedirs(directory, exist_ok=True)

df
# Out:
#      name  age  is_member                  hobbies
# 0  Thomas   30       True  reading, biking, coding

# %%
# Write the DataFrame to an Excel file.
df.to_excel(file_path, index=False)

# %%
file_path
# Out:
# 'Data/excel_sample.xlsx'

# %%
# Read the Excel file back into a DataFrame.
df_loaded = pd.read_excel(file_path)
df_loaded
# Out:
#      name  age  is_member                  hobbies
# 0  Thomas   30       True  reading, biking, coding

# %% [markdown]
# ## 2. Requests and web scraping

# %%
import requests # for making HTTP requests
import pandas as pd 
import time
import re # Regex = Regular Expressions

# %% [markdown]
# Time package small things:

# %%
# %%time
print("Hello, World!")
# Out:
# Hello, World!
# CPU times: user 46 μs, sys: 4 μs, total: 50 μs
# Wall time: 53.9 μs

# %%
time.sleep(1)

# %%
t0 = time.time()
time.sleep(1)
t1 = time.time()
print("Time elapsed: ", t1-t0, " seconds")
# Out:
# Time elapsed:  1.0054819583892822  seconds

# %%
# %%time 
time.sleep(2)
# Out:
# CPU times: user 1.07 ms, sys: 2.73 ms, total: 3.8 ms
# Wall time: 2 s

# %%
import random

# %%
# %%time
r_time = random.uniform(0.5, 1.2)
print("Sleeping for ", r_time, " seconds")
time.sleep(r_time)
# Out:
# Sleeping for  0.8794302997972834  seconds
# CPU times: user 1.82 ms, sys: 3.33 ms, total: 5.16 ms
# Wall time: 884 ms

# %% [markdown]
# #### Task 1: Requesting API
#
# Let us work with data of sreality.cz which we can access via their api. An intuition is that the api is limited for a number of requests (but not verified).

# %% [markdown]
# ##### 1a. Create a function requesting data from sreality
#
# ```python
# base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page60&page={}'.format(i)
#
# r = requests.get(base_url)
# d = r.json()
# ```
#
# 0) function should parametrize:
#     * `category_main_cb` - `{'flat':1, 'house':2, 'land':3 }`
#     * `category_type_cb` - `{'sell':1,'rent':2}`
#     * `locality_region_id` - use 10 as default value
#     * `page` parameter
# 1) use string inputs for `category_main_cb` and `category_type_cb`
# 2) include `try/except` clause to handle errors
# 3) function should return JSON data in python types
# 4) do not forget to sleep each request at least 0.5s

# %%
import requests
base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page60&page=0'
r = requests.get(base_url)
r.json()
# Out:
# {'meta_description': '4033 realit v nabídce prodej bytů Praha. Vyberte si novou nemovitost na sreality.cz s hledáním na mapě a velkými náhledy fotografií nabízených bytů.',
#  'result_size': 4033,
#  '_embedded': {'estates': [{'labelsReleased': [['in_construction', 'garage'],
#      ['train']],
#     'has_panorama': 0,
#     'labels': ['Ve výstavbě', 'Garáž', 'Vlak 1 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['in_construction',
#       'personal',
#       'terrace',
#       'cellar',
#       'elevator',
#       'parking_lots',
#       'garage'],
#      ['vet',
#       'small_shop',
#       'tavern',
#       'candy_shop',
#       'playground',
#       'theater',
#       'movies',
#       'atm',
#       'drugstore',
#       'medic',
#       'restaurant',
#       'kindergarten',
#       'bus_public_transport',
#       'train',
#       'sports',
#       'post_office',
#       'school',
#       'tram',
#       'metro',
#       'shop']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-uhrineves-'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/181654092',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/181654092',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Wadia-Praha-Stare-Mesto',
#       'id': 4292,
#       'name': 'Wadia',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_B/Bz8Rkq.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 10 - Uhříněves',
#     'has_video': False,
#     'advert_images_count': 7,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 181654092,
#     'attractive_offer': 0,
#     'price': 16298000,
#     'price_czk': {'value_raw': 16298000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-20?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/181654092?region_tip=3191081'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBdBZXWeBeCNvq/ee9b.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBbkNYZxBeCOFI/ae91.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBVme3a1BeCOYW/4357.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/kcuj4damOBNB0fWuBeCOqV/dc46.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBdBZXWcBeCPBj/446d.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 112\xa0m²',
#     'region_tip': 3191081,
#     'gps': {'lat': 50.021845912870795, 'lon': 14.603064087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['atm']],
#     'has_panorama': 0,
#     'labels': ['Bankomat 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick'],
#      ['small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'theater',
#       'playground',
#       'movies',
#       'natural_attraction',
#       'post_office',
#       'medic',
#       'drugstore',
#       'bus_public_transport',
#       'atm',
#       'shop',
#       'school',
#       'train',
#       'restaurant',
#       'tram',
#       'metro',
#       'sports',
#       'kindergarten']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-malesice-u-tvrze'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2314089036',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2314089036',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'HX-reality-Praha-Stare-Mesto',
#       'id': 14953,
#       'name': 'HX reality',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_D/ZAlBqQq.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 10 - Malešice',
#     'has_video': False,
#     'advert_images_count': 9,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2314089036,
#     'attractive_offer': 0,
#     'price': 8782000,
#     'price_czk': {'value_raw': 8782000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBIuqInJB6P314/be35.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBIuqInJB6P314/be35.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-19?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2314089036'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBIuqInJB6P314/be35.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1C2jWPqjB6P33p/bf77.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBWQSrpRB6P34y/28ee.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1CgWWKrJB6P4Zf/bca3.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1bMIzofB6P4X5/ce7d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tcD8ZnAB6P4Z3/71a3.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBIuqInJB6P314/be35.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 71\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.072325912870795, 'lon': 14.523835087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'cellar',
#       'elevator',
#       'parking_lots'],
#      ['tavern',
#       'small_shop',
#       'vet',
#       'candy_shop',
#       'theater',
#       'playground',
#       'movies',
#       'sports',
#       'atm',
#       'bus_public_transport',
#       'metro',
#       'restaurant',
#       'post_office',
#       'medic',
#       'school',
#       'train',
#       'shop',
#       'kindergarten',
#       'drugstore',
#       'tram']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-praha-cakovice-belomlynska'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/547366220',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/547366220',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Sekyra-Group-Praha-Karlin',
#       'id': 3360,
#       'name': 'Sekyra Group',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_g/RYpNU.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 9 - Praha-Čakovice',
#     'has_video': False,
#     'advert_images_count': 5,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 547366220,
#     'attractive_offer': 0,
#     'price': 9104000,
#     'price_czk': {'value_raw': 9104000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0k9CUJYX7/75a5.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0k9CUJYX7/75a5.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-18?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/547366220'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0k9CUJYX7/75a5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/kObgaqJNMnzSiAnXCUJYYg/b8c8.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiyaoUqqCUJYZU/e72e.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiBJE31pFCUJYaG/abe9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/kObgaqJNMnVbj2l1CUJYaj/9559.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0k9CUJYX7/75a5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 60\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.145339912870796, 'lon': 14.539332087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction'], ['atm']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci', 'Bankomat 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'brick',
#       'elevator',
#       'parking_lots'],
#      ['candy_shop',
#       'small_shop',
#       'vet',
#       'theater',
#       'tavern',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'sports',
#       'restaurant',
#       'bus_public_transport',
#       'metro',
#       'shop',
#       'post_office',
#       'kindergarten',
#       'train',
#       'tram',
#       'school',
#       'drugstore',
#       'atm',
#       'medic']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-hostavice-piscita'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1202987596',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1202987596',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 9 - Hostavice',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1202987596,
#     'attractive_offer': 0,
#     'price': 18695000,
#     'price_czk': {'value_raw': 18695000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluis55qg9CQAwpw/0cac.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluis55qg9CQAwpw/0cac.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-17?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1202987596'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluis55qg9CQAwpw/0cac.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluiD9J7zfjCQAwqq/d656.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/kObgaqJNMnKEQFfdCQAwre/53f1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluiD9J7zfmCQAwsN/af96.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluiD9J7zfnCQAws9/a57b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/kObgaqJNMnKEQFfaCQAwtr/2b05.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluis55qg9CQAwpw/0cac.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 146\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.073031912870796, 'lon': 14.572681087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['metro', 'shop']],
#     'has_panorama': 0,
#     'labels': ['Metro 5 min. pěšky', 'Obchod 4 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'elevator'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'tavern',
#       'movies',
#       'candy_shop',
#       'playground',
#       'sightseeing',
#       'post_office',
#       'medic',
#       'school',
#       'metro',
#       'drugstore',
#       'kindergarten',
#       'shop',
#       'restaurant',
#       'train',
#       'atm',
#       'bus_public_transport',
#       'sports',
#       'tram']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-nove-mesto-truhlarska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/239473996',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/239473996',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'ENGEL-VOLKERS-Praha-Smichov',
#       'id': 10628,
#       'name': 'ENGEL & VÖLKERS',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_y/DbiKP5.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 1 - Nové Město',
#     'has_video': False,
#     'advert_images_count': 9,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 239473996,
#     'attractive_offer': 0,
#     'price': 16311000,
#     'price_czk': {'value_raw': 16311000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrZ5CNrEpH/a5f4.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrZ5CNrEpH/a5f4.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-16?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/239473996'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrZ5CNrEpH/a5f4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUZ7CNrEpu/1d99.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiCodW3cnCNrEqY/5970.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluis55qaICNrEq8/95b2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGZ4CNrEr0/bd22.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiBtfltaECNrEsa/f276.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrZ5CNrEpH/a5f4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 77\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.078154912870794, 'lon': 14.442881087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['collective', 'garage'], []],
#     'has_panorama': 0,
#     'labels': ['Družstevní', 'Garáž'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'collective',
#       'balcony',
#       'brick',
#       'elevator',
#       'parking_lots',
#       'garage'],
#      ['small_shop',
#       'candy_shop',
#       'vet',
#       'tavern',
#       'theater',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'shop',
#       'restaurant',
#       'drugstore',
#       'post_office',
#       'atm',
#       'school',
#       'bus_public_transport',
#       'train',
#       'kindergarten',
#       'metro',
#       'sports',
#       'tram',
#       'medic']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-dolni-mecholupy-kardausova'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1768084044',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1768084044',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'SOUKUP-PARTNERS-s-r-o-Praha-Zabehlice',
#       'id': 4744,
#       'name': 'SOUKUP & PARTNERS s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QO_S/0C8I57.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 10 - Dolní Měcholupy',
#     'has_video': False,
#     'advert_images_count': 21,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1768084044,
#     'attractive_offer': 0,
#     'price': 3638000,
#     'price_czk': {'value_raw': 3638000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D103URqnB7iOc5/e5ed.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D103URqnB7iOc5/e5ed.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-15?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1768084044'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D103URqnB7iOc5/e5ed.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBh4bTujB7iOar/57f5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1bMIzqHB7iOg2/e867.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tt1PFrHB7iOfJ/79eb.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1CgWWKsvB7iOiq/e42b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1C1iQvuZB7iOkw/cba3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D103URqnB7iOc5/e5ed.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 121\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.05379791287079, 'lon': 14.566796087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction'], ['train', 'atm']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci',
#      'Vlak 7 min. pěšky',
#      'Bankomat 2 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'brick',
#       'cellar',
#       'parking_lots'],
#      ['small_shop',
#       'vet',
#       'candy_shop',
#       'tavern',
#       'theater',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'sports',
#       'post_office',
#       'drugstore',
#       'atm',
#       'train',
#       'tram',
#       'school',
#       'shop',
#       'medic',
#       'bus_public_transport',
#       'restaurant',
#       'kindergarten',
#       'metro']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-modrany-k-vltave'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3333608012',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3333608012',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'ENGEL-VOLKERS-Praha-Smichov',
#       'id': 10628,
#       'name': 'ENGEL & VÖLKERS',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_y/DbiKP5.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 4 - Modřany',
#     'has_video': False,
#     'advert_images_count': 6,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3333608012,
#     'attractive_offer': 0,
#     'price': 8826000,
#     'price_czk': {'value_raw': 8826000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_D/kPWmeC9soBDLwnhVECc7hfM/d4c1.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_D/kPWmeC9soBDLwnhVECc7hfM/d4c1.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-14?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3333608012'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_D/kPWmeC9soBDLwnhVECc7hfM/d4c1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_D/nOzqs9nZOdDoRMeT2Cc7hgh/e407.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_D/nOzqs9nZOdD1A3zT3Cc7hhY/6152.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_D/nOzqs9nZOdBZAD9VcCc7hiU/8df6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_D/kPWmeC9soBDLwnhVECc7hjJ/cd0a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_D/nOzqs9nZOdD1A3zT3Cc7hkH/e275.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_D/kPWmeC9soBDLwnhVECc7hfM/d4c1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 60\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 49.993254912870796, 'lon': 14.418990087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [['furnished'], []],
#     'has_panorama': 0,
#     'labels': ['Vybavený'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'elevator',
#       'furnished'],
#      ['small_shop',
#       'candy_shop',
#       'tavern',
#       'theater',
#       'vet',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'shop',
#       'restaurant',
#       'atm',
#       'school',
#       'drugstore',
#       'train',
#       'post_office',
#       'kindergarten',
#       'bus_public_transport',
#       'metro',
#       'sports',
#       'medic',
#       'tram']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 2,
#      'category_type_cb': 1,
#      'locality': 'praha-zizkov-olgy-havlove'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1337258572',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1337258572',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'SLT-Reality-Praha-Zizkov',
#       'id': 72152,
#       'name': 'SLT Reality',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_m1_A/nO6B5UBUaPvY7sxMJ.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 3 - Žižkov',
#     'has_video': False,
#     'advert_images_count': 22,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1337258572,
#     'attractive_offer': 0,
#     'price': 8594000,
#     'price_czk': {'value_raw': 8594000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_B/kcuj4damOBjwCBeiBhoB1S/6290.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_B/kcuj4damOBjwCBeiBhoB1S/6290.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-13?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1337258572'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_B/kcuj4damOBjwCBeiBhoB1S/6290.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m2_C/nEEmzB06ylFXFZj2R74/4ffa.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_B/kPUxiQtb51lBHUTWCIBjjo/cdf1.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_B/nb4N2OmYQBVme3gXBhoCd8/e889.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m2_C/nEEmzB06ylFXFZl2R7r/1f90.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m2_A/nO6B5UDp0bOaltzQY.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_B/kcuj4damOBjwCBeiBhoB1S/6290.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+kk 48\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.075446912870795, 'lon': 14.492751087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'terrace',
#       'elevator',
#       'not_furnished'],
#      ['small_shop',
#       'vet',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'sports',
#       'kindergarten',
#       'drugstore',
#       'medic',
#       'metro',
#       'atm',
#       'tram',
#       'post_office',
#       'train',
#       'shop',
#       'restaurant',
#       'school',
#       'bus_public_transport']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/626467404',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/626467404',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 626467404,
#     'attractive_offer': 0,
#     'price': 19761000,
#     'price_czk': {'value_raw': 19761000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiDhBr0YyCNDe8F/2abf.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiDhBr0YyCNDe8F/2abf.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-12?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/626467404'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiDhBr0YyCNDe8F/2abf.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnwQ71Z5CNDlQu/39d9.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYqCNDi3N/a2cf.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYpCNDkPY/5b1d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUYrCNDjwW/f6b0.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiUs1XY2CNDgv3/ce8f.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiDhBr0YyCNDe8F/2abf.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 130\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'terrace',
#       'elevator',
#       'not_furnished'],
#      ['small_shop',
#       'vet',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'post_office',
#       'train',
#       'metro',
#       'sports',
#       'bus_public_transport',
#       'school',
#       'atm',
#       'shop',
#       'medic',
#       'tram',
#       'drugstore',
#       'kindergarten',
#       'restaurant']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2387026508',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2387026508',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2387026508,
#     'attractive_offer': 0,
#     'price': 10853000,
#     'price_czk': {'value_raw': 10853000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYqCNDI4E/da1d.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYqCNDI4E/da1d.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-11?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2387026508'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYqCNDI4E/da1d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnDx7wrYqCNDNp0/d6ea.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUY2CNDMIF/1e92.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnKEQFYqCNDNB4/8927.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYhCNDMl4/02ff.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiDshGGY2CNDJYX/9fbc.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYqCNDI4E/da1d.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 69\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'personal', 'elevator', 'not_furnished'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'restaurant',
#       'school',
#       'atm',
#       'sports',
#       'tram',
#       'kindergarten',
#       'medic',
#       'post_office',
#       'drugstore',
#       'bus_public_transport',
#       'metro',
#       'shop',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 2,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2152145484',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2152145484',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2152145484,
#     'attractive_offer': 0,
#     'price': 12296000,
#     'price_czk': {'value_raw': 12296000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCsIs/0ee4.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCsIs/0ee4.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-10?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2152145484'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCsIs/0ee4.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiB7FFSYzCNCzZz/55d0.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnujDqYpCNC1JW/c322.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnujDqYoCNC1HZ/01ba.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCzAO/1714.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUY1CNCy2r/5e82.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCsIs/0ee4.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+kk 79\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'terrace',
#       'elevator',
#       'not_furnished'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'tavern',
#       'candy_shop',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'tram',
#       'kindergarten',
#       'restaurant',
#       'atm',
#       'shop',
#       'drugstore',
#       'sports',
#       'bus_public_transport',
#       'medic',
#       'post_office',
#       'school',
#       'metro',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 2,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/259465804',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/259465804',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 259465804,
#     'attractive_offer': 0,
#     'price': 9974000,
#     'price_czk': {'value_raw': 9974000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNB10x/758d.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNB10x/758d.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-9?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/259465804'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNB10x/758d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnKEQFYkCNCANc/0c31.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYnCNB7wJ/6c14.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnwQ71Z7CNB9JT/4a2b.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnujDqYnCNB8pj/4e02.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiCodW3bXCNB5rv/08f7.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNB10x/758d.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+kk 61\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'personal', 'elevator', 'not_furnished'],
#      ['small_shop',
#       'vet',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'shop',
#       'medic',
#       'bus_public_transport',
#       'atm',
#       'drugstore',
#       'tram',
#       'restaurant',
#       'kindergarten',
#       'post_office',
#       'train',
#       'school',
#       'metro',
#       'sports']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/360129100',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/360129100',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 360129100,
#     'attractive_offer': 0,
#     'price': 9836000,
#     'price_czk': {'value_raw': 9836000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYWCNA1Vu/e952.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYWCNA1Vu/e952.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-8?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/360129100'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYWCNA1Vu/e952.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluis55qYfCNA7I2/3001.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiDshGGYuCNA80x/0246.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnwQ71Z5CNA9QH/dfdc.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiUs1XYvCNA66y/9e5c.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNA63k/7cf3.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYWCNA1Vu/e952.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 56\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'personal', 'elevator', 'not_furnished'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'post_office',
#       'restaurant',
#       'shop',
#       'kindergarten',
#       'tram',
#       'drugstore',
#       'school',
#       'train',
#       'sports',
#       'bus_public_transport',
#       'medic',
#       'atm',
#       'metro']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 2,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/6758988',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/6758988',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 6758988,
#     'attractive_offer': 0,
#     'price': 8657000,
#     'price_czk': {'value_raw': 8657000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiD9J7zYuCNADUx/d9b3.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiD9J7zYuCNADUx/d9b3.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-7?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/6758988'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiD9J7zYuCNADUx/d9b3.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluis55qYvCNAMkg/10d4.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiUs1XYxCNAJb2/ec3e.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYkCNALOa/f5cd.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUYrCNAK2O/c306.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUYvCNAIyr/a5ff.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiD9J7zYuCNADUx/d9b3.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+kk 50\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'personal', 'terrace'],
#      ['small_shop',
#       'vet',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'shop',
#       'bus_public_transport',
#       'tram',
#       'atm',
#       'medic',
#       'school',
#       'metro',
#       'post_office',
#       'restaurant',
#       'drugstore',
#       'sports',
#       'train',
#       'kindergarten']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2506564172',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2506564172',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2506564172,
#     'attractive_offer': 0,
#     'price': 12107000,
#     'price_czk': {'value_raw': 12107000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluis55qYsCM9Uue/5731.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluis55qYsCM9Uue/5731.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-6?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2506564172'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluis55qYsCM9Uue/5731.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnD1IUpYhCM9omD/89d2.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiBJE31YvCM9mK7/5ef0.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnDMhdnYkCM9nlZ/cb3d.png?fl=res,400,300,3|shr,,20|jpg,90'},
# ...
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 70\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.02865191287079, 'lon': 14.414937087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'cellar',
#       'elevator',
#       'parking_lots'],
#      ['candy_shop',
#       'small_shop',
#       'movies',
#       'theater',
#       'vet',
#       'tavern',
#       'playground',
#       'natural_attraction',
#       'kindergarten',
#       'medic',
#       'metro',
#       'tram',
#       'post_office',
#       'sports',
#       'shop',
#       'train',
#       'restaurant',
#       'school',
#       'atm',
#       'bus_public_transport',
#       'drugstore']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha--na-zlichove'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2877035084',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2877035084',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'VESSAN-Praha-Nove-Mesto',
#       'id': 6086,
#       'name': 'VESSAN',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_G_I/aTAFfd.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5',
#     'has_video': False,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2877035084,
#     'attractive_offer': 0,
#     'price': 11066000,
#     'price_czk': {'value_raw': 11066000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiCodW3wjCYPPjG/2b2b.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiCodW3wjCYPPjG/2b2b.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-3?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2877035084'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiCodW3wjCYPPjG/2b2b.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/kObgaqJNMnB0yvGoACUtxpD/e6e4.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiyaoUtrCUuOi1/87e4.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0n0CUtyvd/c834.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiyaoUtqCUty5j/003a.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0nvCUtyCZ/96f7.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiCodW3wjCYPPjG/2b2b.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 66\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.02865191287079, 'lon': 14.414937087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'cellar',
#       'elevator',
#       'parking_lots'],
#      ['candy_shop',
#       'small_shop',
#       'movies',
#       'vet',
#       'theater',
#       'tavern',
#       'playground',
#       'natural_attraction',
#       'drugstore',
#       'restaurant',
#       'tram',
#       'medic',
#       'post_office',
#       'atm',
#       'train',
#       'school',
#       'bus_public_transport',
#       'metro',
#       'sports',
#       'shop',
#       'kindergarten']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha--na-zlichove'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1586500172',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1586500172',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'VESSAN-Praha-Nove-Mesto',
#       'id': 6086,
#       'name': 'VESSAN',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_G_I/aTAFfd.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5',
#     'has_video': True,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1586500172,
#     'attractive_offer': 0,
#     'price': 10627000,
#     'price_czk': {'value_raw': 10627000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiyaoU3MCYQ1Hj/d73f.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiyaoU3MCYQ1Hj/d73f.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-2?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1586500172'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiyaoU3MCYQ1Hj/d73f.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiUs1XzsCYQNE1/5140.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnujDq0RCYQRA6/10b2.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiD9J7z5sCYQNtd/c8be.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiDshGGy8CYQNyY/42b3.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiyaoU3MCYQNMP/69a9.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiyaoU3MCYQ1Hj/d73f.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 66\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.028605912870795, 'lon': 14.414910087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [['furnished'], ['post_office']],
#     'has_panorama': 0,
#     'labels': ['Vybavený', 'Pošta 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'terrace', 'brick', 'elevator', 'furnished'],
#      ['small_shop',
#       'candy_shop',
#       'theater',
#       'tavern',
#       'movies',
#       'playground',
#       'vet',
#       'sightseeing',
#       'sports',
#       'metro',
#       'post_office',
#       'train',
#       'drugstore',
#       'school',
#       'medic',
#       'atm',
#       'bus_public_transport',
#       'restaurant',
#       'shop',
#       'kindergarten',
#       'tram']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 16,
#      'category_type_cb': 1,
#      'locality': 'praha-troja-pod-havrankou'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/4182114892',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/4182114892',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 7 - Troja',
#     'has_video': False,
#     'advert_images_count': 40,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 4182114892,
#     'attractive_offer': 0,
#     'price': 47672000,
#     'price_czk': {'value_raw': 47672000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWeDwkpqokCsP08s/cc56.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWeDwkpqokCsP08s/cc56.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-1?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/4182114892'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWeDwkpqokCsP08s/cc56.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWeDwkpqoiCsP1IM/b781.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWeBsG3YXPCsP1QI/a40c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeCg8klpTCsP1dJ/1cf5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeC4jvZhiCsP1oz/ea3b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWeBteKqnACsP1v2/0f31.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWeDwkpqokCsP08s/cc56.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu atypické 219\xa0m² (Jednopodlažní)',
#     'region_tip': 0,
#     'gps': {'lat': 50.10410591287079, 'lon': 14.429566087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'cellar',
#       'elevator',
#       'not_furnished'],
#      ['theater',
#       'vet',
#       'movies',
#       'small_shop',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'sightseeing',
#       'natural_attraction',
#       'restaurant',
#       'medic',
#       'atm',
#       'kindergarten',
#       'sports',
#       'train',
#       'shop',
#       'tram',
#       'drugstore',
#       'bus_public_transport',
#       'metro',
#       'school',
#       'post_office']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 2,
#      'category_type_cb': 1,
#      'locality': 'praha-smichov-na-laurove'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/406921804',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/406921804',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'SATPO-SATPO-management-s-r-o-Praha-Smichov',
#       'id': 14817,
#       'name': 'SATPO - SATPO management, s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_D/sZfBoen.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Smíchov',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 406921804,
#     'attractive_offer': 0,
#     'price': 7641000,
#     'price_czk': {'value_raw': 7641000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_C/nPw2pRkMOeD5CP0e5CoDb9p/4d2a.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_C/nPw2pRkMOeD5CP0e5CoDb9p/4d2a.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/0?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/406921804'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_C/nPw2pRkMOeD5CP0e5CoDb9p/4d2a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_C/kb9Yg2GWeBMSGtbFCoDcAp/3d1a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_C/kb9Yg2GWe0nAucoCoDcBd/1d25.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_C/kb9Yg2GWetzV8cpCoDcCG/079b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_C/kb9Yg2GWeBHBngl3CoDcC9/1004.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_C/nPw2pRkMOeC4jvZaSCoDcD9/c3a2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_C/nPw2pRkMOeD5CP0e5CoDb9p/4d2a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+kk 41\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.048598912870794, 'lon': 14.410832087129204},
#     'has_matterport_url': False}],
#   'is_saved': {'email_notification': False,
#    'notification_advert_count': 0,
#    'stack_id': 0,
#    'push_notification': False,
#    '_links': {'self': {'href': '/cs/v2/stacks'}},
#    'removed': False,
#    'saved': False},
#   'not_precise_location_count': {'result_size_auction': 1,
#    'result_size': 1409,
#    '_links': {'self': {'profile': '/estates/count/doc',
#      'href': '/cs/v2/estates/count?category_main_cb=1&locality_region_id=10&category_type_cb=3',
#      'title': 'Estate count'}}}},
#  'filterLabels': [],
#  'title': 'Byty na prodej Praha',
#  'filter': {'category_main_cb': '1',
#   'suggested_districtId': -1,
#   'locality_region_id': '10',
#   'category_type_cb': '1',
#   'suggested_regionId': -1},
#  '_links': {'self': {'href': '/cs/v2/estates?category_main_cb=1&locality_region_id=10&category_type_cb=1&page=0'},
#   'clusters_with_bounding_box_of_first_10': {'href': '/cs/v2/clusters?category_main_cb=1&locality_region_id=10&category_type_cb=1&per_page60=&leftBottomBounding=14.3983380871|49.9932549129&page=0&rightTopBounding=14.6030640871|50.1453399129'},
#   'rss': {'href': '/api/cs/v2/estates/rss?category_main_cb=1&category_type_cb=1&locality_region_id=10&suggested_regionId=-1&suggested_districtId=-1'}},
#  'locality': 'okres Praha 10',
#  'locality_dativ': 'na Praze 10',
#  'logged_in': False,
#  'per_page': 20,
#  'category_instrumental': 'výběrem či prodejem bytu',
#  'page': 0,
#  'filterLabels2': {'something_more3_3310': 'elevator',
#   'something_more1_3120': 'cellar',
#   'something_more1_3100': 'loggia',
#   'furnished_1': 'furnished',
#   'furnished_2': 'partly_furnished',
#   'furnished_3': 'not_furnished',
#   'building_condition_9': 'after_reconstruction',
#   'something_more2_3150': 'garage',
#   'something_more2_3130': 'basin',
#   'ownership_1': 'personal',
#   'ownership_3': 'state',
#   'ownership_2': 'collective',
#   'something_more3_1820': 'easy_access',
#   'energy_efficiency_rating_search_7': 'energy_rating_g',
#   'energy_efficiency_rating_search_6': 'energy_rating_f',
#   'energy_efficiency_rating_search_5': 'energy_rating_e',
#   'energy_efficiency_rating_search_4': 'energy_rating_d',
#   'energy_efficiency_rating_search_3': 'energy_rating_c',
#   'energy_efficiency_rating_search_2': 'energy_rating_b',
#   'energy_efficiency_rating_search_1': 'energy_rating_a',
#   'something_more1_3110': 'terrace',
#   'building_condition_6': 'new_building',
#   'something_more1_3090': 'balcony',
#   'building_condition_4': 'in_construction',
#   'building_type_search_3': 'other_sigular',
#   'something_more2_3120': 'cellar',
#   'building_type_search_1': 'panel',
#   'something_more2_3140': 'parking_lots',
#   'something_more1_200222': 'garden',
#   'building_type_search_2': 'brick'}}

# %%
number = 10
text_to_complete = 'Today, I had {} apples.'.format(number)
text_to_complete2 = f'Today, I had {number} apples.'
print(text_to_complete2)
text_to_complete
# Out:
# Today, I had 10 apples.
# 'Today, I had 10 apples.'

# %%
def request_sreality(page, category_main_str, category_type_str, locality_region_id=10):
    """
    Request data from sreality.cz API
    :param page: page number
    :param category_main_str: category of the property
    :param category_type_str: type of the offer
    :param locality_region_id: region id
    :return json: json response
    """
    category_mains = {'flat':1, 'house':2, 'land':3 }
    category_types = {'sell':1, 'rent':2}
    template_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main}&category_type_cb={category_type}&locality_region_id={locality_region_id}&per_page60&page={page}'
    request_url = template_url.format(
        category_main=category_mains[category_main_str],
        category_type=category_types[category_type_str],
        locality_region_id=locality_region_id,
        page=page
    )
    # sleep for random time
    r_sleep = random.uniform(0.5, 1.2)
    time.sleep(r_sleep)
    # make request with try-except block
    try:
        r = requests.get(request_url)
    except requests.exceptions.RequestException as e:
        print(e)
        return None
    
    return r.json() # return json response

# %%
category_mains = {'flat':1, 'house':2, 'land':3 }

category_mains['flat']
# Out:
# 1

# %%
d = request_sreality(0, 'flat', 'sell', 10)
d
# Out:
# {'meta_description': '4031 realit v nabídce prodej bytů Praha. Vyberte si novou nemovitost na sreality.cz s hledáním na mapě a velkými náhledy fotografií nabízených bytů.',
#  'result_size': 4031,
#  '_embedded': {'estates': [{'labelsReleased': [['in_construction'], ['train']],
#     'has_panorama': 0,
#     'labels': ['Ve výstavbě', 'Vlak 1 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['in_construction',
#       'personal',
#       'terrace',
#       'cellar',
#       'elevator',
#       'parking_lots',
#       'garage'],
#      ['vet',
#       'small_shop',
#       'tavern',
#       'candy_shop',
#       'playground',
#       'theater',
#       'movies',
#       'atm',
#       'drugstore',
#       'medic',
#       'restaurant',
#       'kindergarten',
#       'bus_public_transport',
#       'train',
#       'sports',
#       'post_office',
#       'school',
#       'tram',
#       'metro',
#       'shop']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-uhrineves-'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/181654092',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/181654092',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Wadia-Praha-Stare-Mesto',
#       'id': 4292,
#       'name': 'Wadia',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_B/Bz8Rkq.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 10 - Uhříněves',
#     'has_video': False,
#     'advert_images_count': 7,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 181654092,
#     'attractive_offer': 0,
#     'price': 16298000,
#     'price_czk': {'value_raw': 16298000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-20?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/181654092?region_tip=3191081'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBdBZXWeBeCNvq/ee9b.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBbkNYZxBeCOFI/ae91.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBVme3a1BeCOYW/4357.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/kcuj4damOBNB0fWuBeCOqV/dc46.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBdBZXWcBeCPBj/446d.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 112\xa0m²',
#     'region_tip': 3191081,
#     'gps': {'lat': 50.021845912870795, 'lon': 14.603064087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction', 'panel', 'partly_furnished'],
#      ['post_office', 'medic']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci',
#      'Panelová',
#      'Částečně vybavený',
#      'Pošta 279 metrů pěšky',
#      'Lékař 372 metrů pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'panel',
#       'cellar',
#       'elevator',
#       'partly_furnished'],
#      ['sports',
#       'small_shop',
#       'restaurant',
#       'tavern',
#       'kindergarten',
#       'drugstore',
#       'vet',
#       'medic',
#       'school',
#       'candy_shop',
#       'post_office',
#       'shop',
#       'atm',
#       'theater',
#       'bus_public_transport',
#       'playground',
#       'tram',
#       'metro',
#       'movies',
#       'train',
#       'natural_attraction']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 3,
#      'category_type_cb': 1,
#      'locality': 'praha-chodov-mikulova'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3571479116',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3571479116',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Realog-Praha-Holesovice',
#       'id': 16689,
#       'name': 'Realog',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gQ_N/sJiyi.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 4 - Chodov',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3571479116,
#     'attractive_offer': 0,
#     'price': 5770000,
#     'price_czk': {'value_raw': 5770000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeCmZ4qlXCsyl2c/f555.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeCmZ4qlXCsyl2c/f555.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-19?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3571479116'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeCmZ4qlXCsyl2c/f555.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeCmZ4qlTCsyl9X/2a1b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWe0nAukgCsymDB/ff40.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWe0nAukrCsymFX/58d1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeDO3PenACsymJz/0f73.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWeC36sVohCsymSq/dc9f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeCmZ4qlXCsyl2c/f555.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+1\xa035\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.01731091287079, 'lon': 14.527898087129206},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['post_office', 'drugstore']],
#     'has_panorama': 0,
#     'labels': ['Pošta 472 metrů pěšky', 'Lékárna 409 metrů pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar', 'elevator'],
#      ['sports',
#       'kindergarten',
#       'small_shop',
#       'restaurant',
#       'drugstore',
#       'candy_shop',
#       'school',
#       'atm',
#       'shop',
#       'theater',
#       'vet',
#       'tavern',
#       'movies',
#       'medic',
#       'post_office',
#       'bus_public_transport',
#       'train',
#       'tram',
#       'playground',
#       'metro',
#       'natural_attraction']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-zizkov-jeseniova'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/892981836',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/892981836',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'PSN-s-r-o-Praha-Zizkov',
#       'id': 1160,
#       'name': 'PSN s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_oV_B/kObgaqJNMnB0llrZvCNlXm0/55a8.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 3 - Žižkov',
#     'has_video': False,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 892981836,
#     'attractive_offer': 0,
#     'price': 9787000,
#     'price_czk': {'value_raw': 9787000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnujDq7UCZTJfy/b584.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnujDq7UCZTJfy/b584.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-18?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/892981836'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnujDq7UCZTJfy/b584.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiBtfltxOCZTJgZ/a4ee.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnD1IUpBAKCZTJlw/0a9a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnDMhdnBDyCZTJmX/48c4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnwQ71xfCZTJnu/0e30.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnB0yvGyfCZTJpa/da41.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnujDq7UCZTJfy/b584.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 76\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.07601891287079, 'lon': 14.481808087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction', 'furnished'],
#      ['metro', 'drugstore']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci',
#      'Vybavený',
#      'Metro 4 min. pěšky',
#      'Lékárna 6 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'brick',
#       'cellar',
#       'elevator',
#       'parking_lots',
#       'garage',
#       'furnished'],
#      ['theater',
#       'small_shop',
#       'candy_shop',
#       'vet',
#       'tavern',
#       'movies',
#       'playground',
#       'sightseeing',
#       'kindergarten',
#       'medic',
#       'train',
#       'bus_public_transport',
#       'post_office',
#       'sports',
#       'school',
#       'atm',
#       'drugstore',
#       'restaurant',
#       'shop',
#       'metro',
#       'tram']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-nove-mesto-senovazne-namesti'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2011771468',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2011771468',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'ENGEL-VOLKERS-Praha-Smichov',
#       'id': 10628,
#       'name': 'ENGEL & VÖLKERS',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_y/DbiKP5.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 1 - Nové Město',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2011771468,
#     'attractive_offer': 0,
#     'price': 0,
#     'price_czk': {'value_raw': 0, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tBexr9TDB9sNJi/75a5.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tBexr9TDB9sNJi/75a5.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-17?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2011771468'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tBexr9TDB9sNJi/75a5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tB7uGZTEB9sNLh/646d.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/kQOIvbF2D103URt9B9sNNi/e612.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tDxFrxwhB9sNPo/05ea.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tDcIi9TEB9sNRt/af4a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tD3HCkTDB9sNTz/6c5a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tBexr9TDB9sNJi/75a5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 165\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.07317691287079, 'lon': 14.444686087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'terrace',
#       'cellar',
#       'elevator',
#       'garage'],
#      ['small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'playground',
#       'theater',
#       'natural_attraction',
#       'movies',
#       'sports',
#       'restaurant',
#       'shop',
#       'post_office',
#       'school',
#       'kindergarten',
#       'metro',
#       'atm',
#       'bus_public_transport',
#       'drugstore',
#       'medic',
#       'tram',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-chodov-dunovskeho'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3553169996',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3553169996',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'BOUTIQ-Real-Estate-Praha-Nove-Mesto',
#       'id': 20560,
#       'name': 'BOUTIQ Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_F_G/QFYWxx.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 4 - Chodov',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3553169996,
#     'attractive_offer': 0,
#     'price': 25212000,
#     'price_czk': {'value_raw': 25212000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeDo8QnUNClqcsD/1af1.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeDo8QnUNClqcsD/1af1.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-16?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3553169996'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeDo8QnUNClqcsD/1af1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeBHBngUNClqcvy/8f7f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeC4jvZTTClqcyK/b368.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeBHBngUDClqc3V/97a3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeDxAUcTSClqc5Q/de5a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeBteKqUFClqc6c/1f92.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeDo8QnUNClqcsD/1af1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 134\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.022070912870795, 'lon': 14.519598087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'terrace',
#       'cellar',
#       'elevator',
#       'garage'],
#      ['small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'playground',
#       'theater',
#       'natural_attraction',
#       'movies',
#       'school',
#       'medic',
#       'kindergarten',
#       'bus_public_transport',
#       'atm',
#       'restaurant',
#       'post_office',
#       'shop',
#       'tram',
#       'train',
#       'drugstore',
#       'metro',
#       'sports']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-chodov-dunovskeho'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/331944524',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/331944524',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'BOUTIQ-Real-Estate-Praha-Nove-Mesto',
#       'id': 20560,
#       'name': 'BOUTIQ Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_F_G/QFYWxx.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 4 - Chodov',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 331944524,
#     'attractive_offer': 0,
#     'price': 18120000,
#     'price_czk': {'value_raw': 18120000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeCnX76UOClqebW/c8a6.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeCnX76UOClqebW/c8a6.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-15?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/331944524'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeCnX76UOClqebW/c8a6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWetzV8UEClqedU/c826.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeBHBngUOClqefX/900b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWe0nAuUNClqehC/06da.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeDPr2CTPClqehy/ecd8.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeC4jvZTYClqenb/e3c7.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeCnX76UOClqebW/c8a6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 96\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.022070912870795, 'lon': 14.519598087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['balcony'], []],
#     'has_panorama': 0,
#     'labels': ['Balkon'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'cellar',
#       'elevator',
#       'garage'],
#      ['small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'playground',
#       'theater',
#       'movies',
#       'natural_attraction',
#       'post_office',
#       'sports',
#       'atm',
#       'school',
#       'bus_public_transport',
#       'tram',
#       'shop',
#       'medic',
#       'train',
#       'kindergarten',
#       'drugstore',
#       'restaurant',
#       'metro']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-chodov-dunovskeho'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2172322380',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2172322380',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'BOUTIQ-Real-Estate-Praha-Nove-Mesto',
#       'id': 20560,
#       'name': 'BOUTIQ Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_F_G/QFYWxx.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 4 - Chodov',
#     'has_video': False,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2172322380,
#     'attractive_offer': 0,
#     'price': 11972000,
#     'price_czk': {'value_raw': 11972000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeBQpVfTSClqYfQ/bc62.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeBQpVfTSClqYfQ/bc62.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-14?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2172322380'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeBQpVfTSClqYfQ/bc62.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeCg8klTcClqYk3/57cd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeC36sVUMClqYnk/7d21.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWetzV8UFClqYoU/10bd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeDxAUcTbClqYp7/bf99.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeBQpVfTTClqYrz/2926.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeBQpVfTSClqYfQ/bc62.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 66\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.022070912870795, 'lon': 14.519598087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction'], ['medic', 'drugstore']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci',
#      'Lékař 4 min. pěšky',
#      'Lékárna 4 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'after_reconstruction', 'brick'],
#      ['candy_shop',
#       'theater',
#       'small_shop',
#       'vet',
#       'tavern',
#       'movies',
#       'playground',
#       'sightseeing',
#       'post_office',
#       'atm',
#       'medic',
#       'sports',
#       'school',
#       'kindergarten',
#       'metro',
#       'tram',
#       'train',
#       'shop',
#       'bus_public_transport',
#       'drugstore',
#       'restaurant']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-holesovice-veletrzni'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/930267724',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/930267724',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 7 - Holešovice',
#     'has_video': True,
#     'advert_images_count': 30,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 930267724,
#     'attractive_offer': 0,
#     'price': 23074000,
#     'price_czk': {'value_raw': 23074000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1VYLJYfBsrzLX/a95c.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1VYLJYfBsrzLX/a95c.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-13?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/930267724'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1VYLJYfBsrzLX/a95c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1bMIzYfBsrzNy/8216.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1VYLJYZBsrzQH/08e9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1DN63hW7BsrzSb/29d9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/nPt0vAiT3tDo5YuWHBsrzUZ/71a0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/nPt0vAiT3tCAMohWIBsrzWc/b066.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1VYLJYfBsrzLX/a95c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 151\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.089053912870796, 'lon': 14.443483087129206},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['post_office']],
#     'has_panorama': 0,
#     'labels': ['Pošta 6 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar', 'not_furnished'],
#      ['theater',
#       'vet',
#       'small_shop',
#       'candy_shop',
#       'tavern',
#       'movies',
#       'playground',
#       'sightseeing',
#       'natural_attraction',
#       'sports',
#       'medic',
#       'shop',
#       'school',
#       'tram',
#       'train',
#       'atm',
#       'drugstore',
#       'post_office',
#       'restaurant',
#       'metro',
#       'kindergarten',
#       'bus_public_transport']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-smichov-pechackova'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2968588876',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2968588876',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'PSN-s-r-o-Praha-Zizkov',
#       'id': 1160,
#       'name': 'PSN s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_oV_B/kObgaqJNMnB0llrZvCNlXm0/55a8.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Smíchov',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2968588876,
#     'attractive_offer': 0,
#     'price': 8734000,
#     'price_czk': {'value_raw': 8734000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnB0yvGTqCcQu7U/699f.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnB0yvGTqCcQu7U/699f.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-12?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2968588876'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnB0yvGTqCcQu7U/699f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiUs1XBA3CcQu8C/5f1c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnDMhdnTrCcQu8w/1c6c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnVbj2TlCcQu9d/f8de.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnVbj2TtCcQvAQ/1921.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnujDqTrCcQvBy/d47b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnB0yvGTqCcQu7U/699f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 70\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.060809912870795, 'lon': 14.421422087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick'],
#      ['small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'theater',
#       'playground',
#       'movies',
#       'natural_attraction',
#       'post_office',
#       'medic',
#       'drugstore',
#       'bus_public_transport',
#       'atm',
#       'shop',
#       'school',
#       'train',
#       'restaurant',
#       'tram',
#       'metro',
#       'sports',
#       'kindergarten']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-malesice-u-tvrze'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2314089036',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2314089036',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'HX-reality-Praha-Stare-Mesto',
#       'id': 14953,
#       'name': 'HX reality',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_D/ZAlBqQq.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 10 - Malešice',
#     'has_video': False,
#     'advert_images_count': 9,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2314089036,
#     'attractive_offer': 0,
#     'price': 8782000,
#     'price_czk': {'value_raw': 8782000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBIuqInJB6P314/be35.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBIuqInJB6P314/be35.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-11?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2314089036'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBIuqInJB6P314/be35.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1C2jWPqjB6P33p/bf77.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBWQSrpRB6P34y/28ee.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1CgWWKrJB6P4Zf/bca3.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1bMIzofB6P4X5/ce7d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tcD8ZnAB6P4Z3/71a3.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBIuqInJB6P314/be35.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 71\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.072325912870795, 'lon': 14.523835087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['balcony'], []],
#     'has_panorama': 0,
#     'labels': ['Balkon'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'cellar',
#       'elevator',
#       'parking_lots'],
#      ['tavern',
#       'small_shop',
#       'vet',
#       'candy_shop',
#       'theater',
#       'playground',
#       'movies',
#       'sports',
#       'atm',
#       'bus_public_transport',
#       'metro',
#       'restaurant',
#       'post_office',
#       'medic',
#       'school',
#       'train',
#       'shop',
#       'kindergarten',
#       'drugstore',
#       'tram']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-praha-cakovice-belomlynska'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/547366220',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/547366220',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Sekyra-Group-Praha-Karlin',
#       'id': 3360,
#       'name': 'Sekyra Group',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_g/RYpNU.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 9 - Praha-Čakovice',
#     'has_video': False,
#     'advert_images_count': 5,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 547366220,
#     'attractive_offer': 0,
#     'price': 9104000,
#     'price_czk': {'value_raw': 9104000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0k9CUJYX7/75a5.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0k9CUJYX7/75a5.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-10?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/547366220'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0k9CUJYX7/75a5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/kObgaqJNMnzSiAnXCUJYYg/b8c8.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiyaoUqqCUJYZU/e72e.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiBJE31pFCUJYaG/abe9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/kObgaqJNMnVbj2l1CUJYaj/9559.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0k9CUJYX7/75a5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 60\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.145339912870796, 'lon': 14.539332087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction'], []],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'brick',
#       'elevator',
#       'parking_lots'],
#      ['candy_shop',
#       'small_shop',
#       'vet',
#       'theater',
#       'tavern',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'sports',
#       'restaurant',
#       'bus_public_transport',
#       'metro',
#       'shop',
#       'post_office',
#       'kindergarten',
#       'train',
#       'tram',
#       'school',
#       'drugstore',
#       'atm',
#       'medic']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-hostavice-piscita'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1202987596',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1202987596',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 9 - Hostavice',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1202987596,
#     'attractive_offer': 0,
#     'price': 18695000,
#     'price_czk': {'value_raw': 18695000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluis55qg9CQAwpw/0cac.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluis55qg9CQAwpw/0cac.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-9?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1202987596'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluis55qg9CQAwpw/0cac.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluiD9J7zfjCQAwqq/d656.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/kObgaqJNMnKEQFfdCQAwre/53f1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluiD9J7zfmCQAwsN/af96.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluiD9J7zfnCQAws9/a57b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/kObgaqJNMnKEQFfaCQAwtr/2b05.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluis55qg9CQAwpw/0cac.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 146\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.073031912870796, 'lon': 14.572681087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['metro', 'shop']],
#     'has_panorama': 0,
#     'labels': ['Metro 5 min. pěšky', 'Obchod 4 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'elevator'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'tavern',
#       'movies',
#       'candy_shop',
#       'playground',
#       'sightseeing',
#       'post_office',
#       'medic',
#       'school',
#       'metro',
#       'drugstore',
#       'kindergarten',
#       'shop',
#       'restaurant',
#       'train',
#       'atm',
#       'bus_public_transport',
#       'sports',
#       'tram']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-nove-mesto-truhlarska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/239473996',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/239473996',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'ENGEL-VOLKERS-Praha-Smichov',
#       'id': 10628,
#       'name': 'ENGEL & VÖLKERS',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_y/DbiKP5.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 1 - Nové Město',
#     'has_video': False,
#     'advert_images_count': 9,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 239473996,
#     'attractive_offer': 0,
#     'price': 16311000,
#     'price_czk': {'value_raw': 16311000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrZ5CNrEpH/a5f4.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrZ5CNrEpH/a5f4.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-8?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/239473996'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrZ5CNrEpH/a5f4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUZ7CNrEpu/1d99.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiCodW3cnCNrEqY/5970.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluis55qaICNrEq8/95b2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGZ4CNrEr0/bd22.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiBtfltaECNrEsa/f276.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrZ5CNrEpH/a5f4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 77\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.078154912870794, 'lon': 14.442881087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['collective', 'balcony'], []],
#     'has_panorama': 0,
#     'labels': ['Družstevní', 'Balkon'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'collective',
#       'balcony',
#       'brick',
#       'elevator',
#       'parking_lots',
#       'garage'],
#      ['small_shop',
#       'candy_shop',
#       'vet',
#       'tavern',
#       'theater',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'shop',
#       'restaurant',
#       'drugstore',
#       'post_office',
#       'atm',
#       'school',
#       'bus_public_transport',
#       'train',
#       'kindergarten',
#       'metro',
#       'sports',
#       'tram',
#       'medic']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-dolni-mecholupy-kardausova'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1768084044',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1768084044',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'SOUKUP-PARTNERS-s-r-o-Praha-Zabehlice',
#       'id': 4744,
#       'name': 'SOUKUP & PARTNERS s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QO_S/0C8I57.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 10 - Dolní Měcholupy',
#     'has_video': False,
#     'advert_images_count': 21,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1768084044,
#     'attractive_offer': 0,
#     'price': 3638000,
#     'price_czk': {'value_raw': 3638000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D103URqnB7iOc5/e5ed.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D103URqnB7iOc5/e5ed.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-7?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1768084044'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D103URqnB7iOc5/e5ed.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBh4bTujB7iOar/57f5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1bMIzqHB7iOg2/e867.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tt1PFrHB7iOfJ/79eb.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1CgWWKsvB7iOiq/e42b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1C1iQvuZB7iOkw/cba3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D103URqnB7iOc5/e5ed.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 121\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.05379791287079, 'lon': 14.566796087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction'], ['train']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci', 'Vlak 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'brick',
#       'cellar',
#       'parking_lots'],
#      ['small_shop',
#       'vet',
#       'candy_shop',
#       'tavern',
#       'theater',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'sports',
#       'post_office',
#       'drugstore',
#       'atm',
#       'train',
#       'tram',
#       'school',
#       'shop',
#       'medic',
#       'bus_public_transport',
#       'restaurant',
#       'kindergarten',
#       'metro']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-modrany-k-vltave'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3333608012',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
# ...
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYqCNDi3N/a2cf.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYpCNDkPY/5b1d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUYrCNDjwW/f6b0.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiUs1XY2CNDgv3/ce8f.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiDhBr0YyCNDe8F/2abf.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 130\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'terrace',
#       'elevator',
#       'not_furnished'],
#      ['small_shop',
#       'vet',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'post_office',
#       'train',
#       'metro',
#       'sports',
#       'bus_public_transport',
#       'school',
#       'atm',
#       'shop',
#       'medic',
#       'tram',
#       'drugstore',
#       'kindergarten',
#       'restaurant']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2387026508',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2387026508',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2387026508,
#     'attractive_offer': 0,
#     'price': 10853000,
#     'price_czk': {'value_raw': 10853000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYqCNDI4E/da1d.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYqCNDI4E/da1d.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-3?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2387026508'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYqCNDI4E/da1d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnDx7wrYqCNDNp0/d6ea.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUY2CNDMIF/1e92.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnKEQFYqCNDNB4/8927.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYhCNDMl4/02ff.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiDshGGY2CNDJYX/9fbc.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYqCNDI4E/da1d.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 69\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'personal', 'elevator', 'not_furnished'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'restaurant',
#       'school',
#       'atm',
#       'sports',
#       'tram',
#       'kindergarten',
#       'medic',
#       'post_office',
#       'drugstore',
#       'bus_public_transport',
#       'metro',
#       'shop',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 2,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2152145484',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2152145484',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2152145484,
#     'attractive_offer': 0,
#     'price': 12296000,
#     'price_czk': {'value_raw': 12296000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCsIs/0ee4.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCsIs/0ee4.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-2?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2152145484'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCsIs/0ee4.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiB7FFSYzCNCzZz/55d0.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnujDqYpCNC1JW/c322.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnujDqYoCNC1HZ/01ba.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCzAO/1714.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUY1CNCy2r/5e82.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCsIs/0ee4.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+kk 79\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'terrace',
#       'elevator',
#       'not_furnished'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'tavern',
#       'candy_shop',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'tram',
#       'kindergarten',
#       'restaurant',
#       'atm',
#       'shop',
#       'drugstore',
#       'sports',
#       'bus_public_transport',
#       'medic',
#       'post_office',
#       'school',
#       'metro',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 2,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/259465804',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/259465804',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 259465804,
#     'attractive_offer': 0,
#     'price': 9974000,
#     'price_czk': {'value_raw': 9974000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNB10x/758d.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNB10x/758d.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-1?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/259465804'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNB10x/758d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnKEQFYkCNCANc/0c31.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYnCNB7wJ/6c14.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnwQ71Z7CNB9JT/4a2b.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnujDqYnCNB8pj/4e02.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiCodW3bXCNB5rv/08f7.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNB10x/758d.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+kk 61\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'personal', 'elevator', 'not_furnished'],
#      ['small_shop',
#       'vet',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'shop',
#       'medic',
#       'bus_public_transport',
#       'atm',
#       'drugstore',
#       'tram',
#       'restaurant',
#       'kindergarten',
#       'post_office',
#       'train',
#       'school',
#       'metro',
#       'sports']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/360129100',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/360129100',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 360129100,
#     'attractive_offer': 0,
#     'price': 9836000,
#     'price_czk': {'value_raw': 9836000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYWCNA1Vu/e952.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYWCNA1Vu/e952.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/0?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/360129100'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYWCNA1Vu/e952.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluis55qYfCNA7I2/3001.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiDshGGYuCNA80x/0246.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnwQ71Z5CNA9QH/dfdc.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiUs1XYvCNA66y/9e5c.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNA63k/7cf3.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYWCNA1Vu/e952.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 56\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False}],
#   'is_saved': {'email_notification': False,
#    'notification_advert_count': 0,
#    'stack_id': 0,
#    'push_notification': False,
#    '_links': {'self': {'href': '/cs/v2/stacks'}},
#    'removed': False,
#    'saved': False},
#   'not_precise_location_count': {'result_size_auction': 1,
#    'result_size': 1409,
#    '_links': {'self': {'profile': '/estates/count/doc',
#      'href': '/cs/v2/estates/count?category_main_cb=1&locality_region_id=10&category_type_cb=3',
#      'title': 'Estate count'}}}},
#  'filterLabels': [],
#  'title': 'Byty na prodej Praha',
#  'filter': {'category_main_cb': '1',
#   'suggested_districtId': -1,
#   'locality_region_id': '10',
#   'category_type_cb': '1',
#   'suggested_regionId': -1},
#  '_links': {'self': {'href': '/cs/v2/estates?category_main_cb=1&locality_region_id=10&category_type_cb=1&page=0'},
#   'clusters_with_bounding_box_of_first_10': {'href': '/cs/v2/clusters?category_main_cb=1&locality_region_id=10&category_type_cb=1&per_page60=&leftBottomBounding=14.4214220871|50.0173109129&page=0&rightTopBounding=14.6030640871|50.0890539129'},
#   'rss': {'href': '/api/cs/v2/estates/rss?category_main_cb=1&category_type_cb=1&locality_region_id=10&suggested_regionId=-1&suggested_districtId=-1'}},
#  'locality': 'okres Praha 4',
#  'locality_dativ': 'na Praze 4',
#  'logged_in': False,
#  'per_page': 20,
#  'category_instrumental': 'výběrem či prodejem bytu',
#  'page': 0,
#  'filterLabels2': {'something_more3_3310': 'elevator',
#   'something_more1_3120': 'cellar',
#   'something_more1_3100': 'loggia',
#   'furnished_1': 'furnished',
#   'furnished_2': 'partly_furnished',
#   'furnished_3': 'not_furnished',
#   'building_condition_9': 'after_reconstruction',
#   'something_more2_3150': 'garage',
#   'something_more2_3130': 'basin',
#   'ownership_1': 'personal',
#   'ownership_3': 'state',
#   'ownership_2': 'collective',
#   'something_more3_1820': 'easy_access',
#   'energy_efficiency_rating_search_7': 'energy_rating_g',
#   'energy_efficiency_rating_search_6': 'energy_rating_f',
#   'energy_efficiency_rating_search_5': 'energy_rating_e',
#   'energy_efficiency_rating_search_4': 'energy_rating_d',
#   'energy_efficiency_rating_search_3': 'energy_rating_c',
#   'energy_efficiency_rating_search_2': 'energy_rating_b',
#   'energy_efficiency_rating_search_1': 'energy_rating_a',
#   'something_more1_3110': 'terrace',
#   'building_condition_6': 'new_building',
#   'something_more1_3090': 'balcony',
#   'building_condition_4': 'in_construction',
#   'building_type_search_3': 'other_sigular',
#   'something_more2_3120': 'cellar',
#   'building_type_search_1': 'panel',
#   'something_more2_3140': 'parking_lots',
#   'something_more1_200222': 'garden',
#   'building_type_search_2': 'brick'}}

# %% [markdown]
# Inspect the element `d`:

# %%
d['_embedded'].keys()
# Out:
# dict_keys(['estates', 'is_saved', 'not_precise_location_count'])

# %%
d['meta_description']
# Out:
# '4034 realit v nabídce prodej bytů Praha. Vyberte si novou nemovitost na sreality.cz s hledáním na mapě a velkými náhledy fotografií nabízených bytů.'

# %%
d['result_size']
# Out:
# 4034

# %%
d['_embedded']['estates'][0]
# Out:
# {'labelsReleased': [['in_construction'], ['train']],
#  'has_panorama': 0,
#  'labels': ['Ve výstavbě', 'Vlak 1 min. pěšky'],
#  'is_auction': False,
#  'labelsAll': [['in_construction',
#    'personal',
#    'terrace',
#    'cellar',
#    'elevator',
#    'parking_lots',
#    'garage'],
#   ['vet',
#    'small_shop',
#    'tavern',
#    'candy_shop',
#    'playground',
#    'theater',
#    'movies',
#    'atm',
#    'drugstore',
#    'medic',
#    'restaurant',
#    'kindergarten',
#    'bus_public_transport',
#    'train',
#    'sports',
#    'post_office',
#    'school',
#    'tram',
#    'metro',
#    'shop']],
#  'seo': {'category_main_cb': 1,
#   'category_sub_cb': 8,
#   'category_type_cb': 1,
#   'locality': 'praha-uhrineves-'},
#  'exclusively_at_rk': 1,
#  'category': 1,
#  'has_floor_plan': 1,
#  '_embedded': {'favourite': {'is_favourite': False,
#    '_links': {'self': {'profile': '/favourite/doc',
#      'href': '/cs/v2/favourite/181654092',
#      'title': 'Oblibene inzeraty'}}},
#   'note': {'note': '',
#    '_links': {'self': {'profile': '/note/doc',
#      'href': '/cs/v2/note/181654092',
#      'title': 'Poznamky inzeratu'}},
#    'has_note': False},
#   'company': {'url': 'Wadia-Praha-Stare-Mesto',
#    'id': 4292,
#    'name': 'Wadia',
#    'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_B/Bz8Rkq.png?fl=res,140,140,3,ffffff'}},
#  'paid_logo': 1,
#  'locality': 'Praha 10 - Uhříněves',
#  'has_video': False,
#  'advert_images_count': 7,
#  'new': False,
#  'auctionPrice': 0.0,
#  'type': 1,
#  'hash_id': 181654092,
#  'attractive_offer': 0,
#  'price': 16298000,
#  'price_czk': {'value_raw': 16298000, 'unit': '', 'name': 'Celková cena'},
#  '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#   'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#   'iterator': {'href': '/cs/v2/estate-iterator/-20?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#   'self': {'href': '/cs/v2/estates/181654092?region_tip=3191081'},
#   'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBdBZXWeBeCNvq/ee9b.png?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBbkNYZxBeCOFI/ae91.png?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBVme3a1BeCOYW/4357.png?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/kcuj4damOBNB0fWuBeCOqV/dc46.png?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBdBZXWcBeCPBj/446d.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#   'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#  'rus': False,
#  'name': 'Prodej bytu 4+kk 112\xa0m²',
#  'region_tip': 3191081,
#  'gps': {'lat': 50.021845912870795, 'lon': 14.603064087129205},
#  'has_matterport_url': False}

# %%
d['_embedded']['is_saved']
# Out:
# {'email_notification': False,
#  'notification_advert_count': 0,
#  'stack_id': 0,
#  'push_notification': False,
#  '_links': {'self': {'href': '/cs/v2/stacks'}},
#  'removed': False,
#  'saved': False}

# %%
d['_embedded']['estates'][0] # first estate - unlisted
# Out:
# {'labelsReleased': [['in_construction', 'terrace', 'cellar'], ['train']],
#  'has_panorama': 0,
#  'labels': ['Ve výstavbě', 'Terasa', 'Sklep', 'Vlak 1 min. pěšky'],
#  'is_auction': False,
#  'labelsAll': [['in_construction',
#    'personal',
#    'terrace',
#    'cellar',
#    'elevator',
#    'parking_lots',
#    'garage'],
#   ['vet',
#    'small_shop',
#    'tavern',
#    'candy_shop',
#    'playground',
#    'theater',
#    'movies',
#    'atm',
#    'drugstore',
#    'medic',
#    'restaurant',
#    'kindergarten',
#    'bus_public_transport',
#    'train',
#    'sports',
#    'post_office',
#    'school',
#    'tram',
#    'metro',
#    'shop']],
#  'seo': {'category_main_cb': 1,
#   'category_sub_cb': 8,
#   'category_type_cb': 1,
#   'locality': 'praha-uhrineves-'},
#  'exclusively_at_rk': 1,
#  'category': 1,
#  'has_floor_plan': 1,
#  '_embedded': {'favourite': {'is_favourite': False,
#    '_links': {'self': {'profile': '/favourite/doc',
#      'href': '/cs/v2/favourite/181654092',
#      'title': 'Oblibene inzeraty'}}},
#   'note': {'note': '',
#    '_links': {'self': {'profile': '/note/doc',
#      'href': '/cs/v2/note/181654092',
#      'title': 'Poznamky inzeratu'}},
#    'has_note': False},
#   'company': {'url': 'Wadia-Praha-Stare-Mesto',
#    'id': 4292,
#    'name': 'Wadia',
#    'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_B/Bz8Rkq.png?fl=res,140,140,3,ffffff'}},
#  'paid_logo': 1,
#  'locality': 'Praha 10 - Uhříněves',
#  'has_video': False,
#  'advert_images_count': 7,
#  'new': False,
#  'auctionPrice': 0.0,
#  'type': 1,
#  'hash_id': 181654092,
#  'attractive_offer': 0,
#  'price': 7367000,
#  'price_czk': {'value_raw': 7367000, 'unit': '', 'name': 'Celková cena'},
#  '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#   'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#   'iterator': {'href': '/cs/v2/estate-iterator/-20?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#   'self': {'href': '/cs/v2/estates/181654092?region_tip=3191081'},
#   'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBdBZXWeBeCNvq/ee9b.png?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBbkNYZxBeCOFI/ae91.png?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBVme3a1BeCOYW/4357.png?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/kcuj4damOBNB0fWuBeCOqV/dc46.png?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBdBZXWcBeCPBj/446d.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#   'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#  'rus': False,
#  'name': 'Prodej bytu 4+kk 51\xa0m²',
#  'region_tip': 3191081,
#  'gps': {'lat': 50.02872133971921, 'lon': 14.596188660280786},
#  'has_matterport_url': False}

# %% [markdown]
# ### 1b. Create a function converting sreality json data into pandas dataframe

# %%
len(d['_embedded']['estates']) # number of estates
# Out:
# 21

# %%
d['_embedded']['estates'][4]
# Out:
# {'labelsReleased': [[], []],
#  'has_panorama': 0,
#  'labels': [],
#  'is_auction': False,
#  'labelsAll': [['personal', 'brick'],
#   ['tavern',
#    'theater',
#    'small_shop',
#    'candy_shop',
#    'vet',
#    'movies',
#    'playground',
#    'sightseeing',
#    'drugstore',
#    'bus_public_transport',
#    'school',
#    'tram',
#    'shop',
#    'atm',
#    'restaurant',
#    'kindergarten',
#    'medic',
#    'post_office',
#    'metro',
#    'sports',
#    'train']],
#  'seo': {'category_main_cb': 1,
#   'category_sub_cb': 3,
#   'category_type_cb': 1,
#   'locality': 'praha-zizkov-sladkovskeho-namesti'},
#  'exclusively_at_rk': 1,
#  'category': 1,
#  'has_floor_plan': 1,
#  '_embedded': {'favourite': {'is_favourite': False,
#    '_links': {'self': {'profile': '/favourite/doc',
#      'href': '/cs/v2/favourite/144118348',
#      'title': 'Oblibene inzeraty'}}},
#   'note': {'note': '',
#    '_links': {'self': {'profile': '/note/doc',
#      'href': '/cs/v2/note/144118348',
#      'title': 'Poznamky inzeratu'}},
#    'has_note': False},
#   'company': {'url': 'REALITY-A-FINANCE-REAF-CZ-Praha-Zizkov',
#    'id': 19099,
#    'name': 'REALITY A FINANCE / REAF.CZ',
#    'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_F_G/8K1HOA.png?fl=res,140,140,3,ffffff'}},
#  'paid_logo': 1,
#  'locality': 'Praha 3 - Žižkov',
#  'has_video': False,
#  'advert_images_count': 16,
#  'new': False,
#  'auctionPrice': 0.0,
#  'type': 1,
#  'hash_id': 144118348,
#  'attractive_offer': 0,
#  'price': 2650000,
#  'price_czk': {'value_raw': 2650000, 'unit': '', 'name': 'Celková cena'},
#  '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kPWmeC9soBCPjYHfdClQs2F/4ee2.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#   'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kPWmeC9soBCPjYHfdClQs2F/4ee2.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#   'iterator': {'href': '/cs/v2/estate-iterator/-16?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#   'self': {'href': '/cs/v2/estates/144118348'},
#   'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kPWmeC9soBCPjYHfdClQs2F/4ee2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nOzqs9nZOdI9ozwRClQs4y/f59d.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nOzqs9nZOdBZAD9uTClQs52/d844.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kPWmeC9soBB5dBZwaClQtEt/3f9d.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nOzqs9nZOdDoRMerrClQtI4/c571.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#    {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kPWmeC9soBBWXCzrtClQtLd/362b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#   'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kPWmeC9soBCPjYHfdClQs2F/4ee2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#  'rus': False,
#  'name': 'Prodej bytu 1+1\xa015\xa0m²',
#  'region_tip': 0,
#  'gps': {'lat': 50.078284606780116, 'lon': 14.455875393219888},
#  'has_matterport_url': True}

# %%
def convert_sreality_data_to_df(sreality_data):
    return pd.DataFrame(sreality_data['_embedded']['estates'])

raw = convert_sreality_data_to_df(d)

# %%
raw.head()
# Out:
#                                       labelsReleased  has_panorama  \
# 0                       [[in_construction], [train]]             0
# 1  [[after_reconstruction, panel, partly_furnishe...             0
# 2                     [[], [post_office, drugstore]]             0
# 3  [[after_reconstruction, furnished], [metro, dr...             0
# 4                                           [[], []]             0
#
#                                               labels  is_auction  \
# 0                   [Ve výstavbě, Vlak 1 min. pěšky]       False
# 1  [Po rekonstrukci, Panelová, Částečně vybavený,...       False
# 2   [Pošta 472 metrů pěšky, Lékárna 409 metrů pěšky]       False
# 3  [Po rekonstrukci, Vybavený, Metro 4 min. pěšky...       False
# 4                                                 []       False
#
#                                            labelsAll  \
# 0  [[in_construction, personal, terrace, cellar, ...
# 1  [[personal, after_reconstruction, panel, cella...
# 2  [[personal, brick, cellar, elevator], [sports,...
# 3  [[personal, after_reconstruction, brick, cella...
# 4  [[new_building, personal, terrace, cellar, ele...
#
#                                                  seo  exclusively_at_rk  \
# 0  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 1  {'category_main_cb': 1, 'category_sub_cb': 3, ...                  0
# 2  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 3  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 4  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
#
#    category  has_floor_plan  \
# 0         1               1
# 1         1               0
# 2         1               0
# 3         1               0
# 4         1               0
#
#                                            _embedded  ...     hash_id  \
# 0  {'favourite': {'is_favourite': False, '_links'...  ...   181654092
# 1  {'favourite': {'is_favourite': False, '_links'...  ...  3571479116
# 2  {'favourite': {'is_favourite': False, '_links'...  ...   892981836
# 3  {'favourite': {'is_favourite': False, '_links'...  ...  2011771468
# 4  {'favourite': {'is_favourite': False, '_links'...  ...  3553169996
#
#   attractive_offer     price  \
# 0                0  16298000
# 1                0   5770000
# 2                0   9787000
# 3                0         0
# 4                0  25212000
#
#                                            price_czk  \
# 0  {'value_raw': 16298000, 'unit': '', 'name': 'C...
# 1  {'value_raw': 5770000, 'unit': '', 'name': 'Ce...
# 2  {'value_raw': 9787000, 'unit': '', 'name': 'Ce...
# 3  {'value_raw': 0, 'unit': '', 'name': 'Celková ...
# 4  {'value_raw': 25212000, 'unit': '', 'name': 'C...
#
#                                               _links    rus  \
# 0  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                       name  region_tip  \
# 0  Prodej bytu 4+kk 112 m²     3191081
# 1    Prodej bytu 1+1 35 m²           0
# 2   Prodej bytu 2+kk 76 m²           0
# 3  Prodej bytu 4+kk 165 m²           0
# 4  Prodej bytu 4+kk 134 m²           0
#
#                                                  gps  has_matterport_url
# 0  {'lat': 50.021845912870795, 'lon': 14.60306408...               False
# 1  {'lat': 50.01731091287079, 'lon': 14.527898087...               False
# 2  {'lat': 50.07601891287079, 'lon': 14.481808087...               False
# 3  {'lat': 50.07317691287079, 'lon': 14.444686087...               False
# 4  {'lat': 50.022070912870795, 'lon': 14.51959808...               False
#
# [5 rows x 27 columns]

# %% [markdown]
# ### 1c. link function `1b` into function `1a`

# %%
df = convert_sreality_data_to_df(request_sreality(0, 'flat', 'sell', 10))
df.head()
# Out:
#                              labelsReleased  has_panorama  \
# 0      [[in_construction, garage], [train]]             0
# 1       [[partly_furnished], [post_office]]             0
# 2                  [[partly_furnished], []]             0
# 3  [[panel, furnished], [medic, drugstore]]             0
# 4                             [[], [train]]             0
#
#                                               labels  is_auction  \
# 0            [Ve výstavbě, Garáž, Vlak 1 min. pěšky]       False
# 1            [Částečně vybavený, Pošta 6 min. pěšky]       False
# 2                                [Částečně vybavený]       False
# 3  [Panelová, Vybavený, Lékař 7 min. pěšky, Lékár...       False
# 4                                [Vlak 6 min. pěšky]       False
#
#                                            labelsAll  \
# 0  [[in_construction, personal, terrace, cellar, ...
# 1  [[personal, balcony, brick, cellar, elevator, ...
# 2  [[personal, brick, partly_furnished], [tavern,...
# 3  [[personal, panel, cellar, elevator, furnished...
# 4  [[personal, brick, cellar], [small_shop, movie...
#
#                                                  seo  exclusively_at_rk  \
# 0  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 1  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 2  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 3  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 4  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
#
#    category  has_floor_plan  \
# 0         1               1
# 1         1               1
# 2         1               0
# 3         1               0
# 4         1               0
#
#                                            _embedded  ...     hash_id  \
# 0  {'favourite': {'is_favourite': False, '_links'...  ...   181654092
# 1  {'favourite': {'is_favourite': False, '_links'...  ...   131142988
# 2  {'favourite': {'is_favourite': False, '_links'...  ...   288179532
# 3  {'favourite': {'is_favourite': False, '_links'...  ...  3775754828
# 4  {'favourite': {'is_favourite': False, '_links'...  ...  1989653068
#
#   attractive_offer     price  \
# 0                0  14518000
# 1                0  31293000
# 2                0  10057000
# 3                0   6935000
# 4                0   6583000
#
#                                            price_czk  \
# 0  {'value_raw': 14518000, 'unit': '', 'name': 'C...
# 1  {'value_raw': 31293000, 'unit': '', 'name': 'C...
# 2  {'value_raw': 10057000, 'unit': '', 'name': 'C...
# 3  {'value_raw': 6935000, 'unit': '', 'name': 'Ce...
# 4  {'value_raw': 6583000, 'unit': '', 'name': 'Ce...
#
#                                               _links    rus  \
# 0  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                   name  region_tip  \
# 0              Prodej bytu 4+kk 100 m²     3191081
# 1  Prodej bytu 3+kk 160 m² (Podkrovní)           0
# 2   Prodej bytu 3+kk 96 m² (Podkrovní)           0
# 3               Prodej bytu 2+kk 48 m²           0
# 4               Prodej bytu 2+kk 45 m²           0
#
#                                                  gps  has_matterport_url
# 0  {'lat': 50.02321621360754, 'lon': 14.601693786...               False
# 1  {'lat': 50.07438321360754, 'lon': 14.417012786...               False
# 2  {'lat': 50.05343621360754, 'lon': 14.399236786...               False
# 3  {'lat': 50.042065213607536, 'lon': 14.35449678...               False
# 4  {'lat': 50.05146021360754, 'lon': 14.458017786...               False
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (21, 27)

# %% [markdown]
# ### 1c. Combining multiple requests into single df
#
# * Function should parametrize:
#     * `start_page` and `end_page`
#     * request parameters
# * construct a list of individual request dfs
# * then feed it into `pd.concat` function

# %%
raw.shape
# Out:
# (21, 27)

# %%
request_sreality
# Out:
# <function __main__.request_sreality(page, category_main_str, category_type_str, locality_region_id=10)>

# %%
def request_multiply_sreality(start_page, end_page, category_main_str, category_type_str, locality_region_id=10):
    pages_to_request = range(start_page, end_page+1)
    list_of_dfs = []
    for page in pages_to_request:
        json_data = request_sreality(page, category_main_str, category_type_str, locality_region_id)
        if json_data is None:
            continue
        df = convert_sreality_data_to_df(json_data)
        list_of_dfs.append(df)
    
    return pd.concat(list_of_dfs)

df = request_multiply_sreality(1, 5, 'flat', 'sell', 10)
df.shape
# Out:
# (105, 27)

# %%
df.shape
# Out:
# (105, 27)

# %%
df.head()
# Out:
#                              labelsReleased  has_panorama  \
# 0      [[in_construction, garage], [train]]             0
# 1       [[partly_furnished], [post_office]]             0
# 2                  [[partly_furnished], []]             0
# 3  [[panel, furnished], [medic, drugstore]]             0
# 4                             [[], [train]]             0
#
#                                               labels  is_auction  \
# 0            [Ve výstavbě, Garáž, Vlak 1 min. pěšky]       False
# 1            [Částečně vybavený, Pošta 6 min. pěšky]       False
# 2                                [Částečně vybavený]       False
# 3  [Panelová, Vybavený, Lékař 7 min. pěšky, Lékár...       False
# 4                                [Vlak 6 min. pěšky]       False
#
#                                            labelsAll  \
# 0  [[in_construction, personal, terrace, cellar, ...
# 1  [[personal, balcony, brick, cellar, elevator, ...
# 2  [[personal, brick, partly_furnished], [tavern,...
# 3  [[personal, panel, cellar, elevator, furnished...
# 4  [[personal, brick, cellar], [small_shop, movie...
#
#                                                  seo  exclusively_at_rk  \
# 0  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  1
# 1  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 2  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  1
# 3  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 4  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
#
#    category  has_floor_plan  \
# 0         1               1
# 1         1               1
# 2         1               0
# 3         1               0
# 4         1               0
#
#                                            _embedded  ...     hash_id  \
# 0  {'favourite': {'is_favourite': False, '_links'...  ...   181654092
# 1  {'favourite': {'is_favourite': False, '_links'...  ...   131142988
# 2  {'favourite': {'is_favourite': False, '_links'...  ...   288179532
# 3  {'favourite': {'is_favourite': False, '_links'...  ...  3775754828
# 4  {'favourite': {'is_favourite': False, '_links'...  ...  1989653068
#
#   attractive_offer     price  \
# 0                0  14518000
# 1                0  31293000
# 2                0  10057000
# 3                0   6935000
# 4                0   6583000
#
#                                            price_czk  \
# 0  {'value_raw': 14518000, 'unit': '', 'name': 'C...
# 1  {'value_raw': 31293000, 'unit': '', 'name': 'C...
# 2  {'value_raw': 10057000, 'unit': '', 'name': 'C...
# 3  {'value_raw': 6935000, 'unit': '', 'name': 'Ce...
# 4  {'value_raw': 6583000, 'unit': '', 'name': 'Ce...
#
#                                               _links    rus  \
# 0  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                   name  region_tip  \
# 0              Prodej bytu 4+kk 100 m²     3191081
# 1  Prodej bytu 3+kk 160 m² (Podkrovní)           0
# 2   Prodej bytu 3+kk 96 m² (Podkrovní)           0
# 3               Prodej bytu 2+kk 48 m²           0
# 4               Prodej bytu 2+kk 45 m²           0
#
#                                                  gps  has_matterport_url
# 0  {'lat': 50.02321621360754, 'lon': 14.601693786...               False
# 1  {'lat': 50.07438321360754, 'lon': 14.417012786...               False
# 2  {'lat': 50.05343621360754, 'lon': 14.399236786...               False
# 3  {'lat': 50.042065213607536, 'lon': 14.35449678...               False
# 4  {'lat': 50.05146021360754, 'lon': 14.458017786...               False
#
# [5 rows x 27 columns]

# %%
d
# Out:
# {'meta_description': '4031 realit v nabídce prodej bytů Praha. Vyberte si novou nemovitost na sreality.cz s hledáním na mapě a velkými náhledy fotografií nabízených bytů.',
#  'result_size': 4031,
#  '_embedded': {'estates': [{'labelsReleased': [['in_construction'], ['train']],
#     'has_panorama': 0,
#     'labels': ['Ve výstavbě', 'Vlak 1 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['in_construction',
#       'personal',
#       'terrace',
#       'cellar',
#       'elevator',
#       'parking_lots',
#       'garage'],
#      ['vet',
#       'small_shop',
#       'tavern',
#       'candy_shop',
#       'playground',
#       'theater',
#       'movies',
#       'atm',
#       'drugstore',
#       'medic',
#       'restaurant',
#       'kindergarten',
#       'bus_public_transport',
#       'train',
#       'sports',
#       'post_office',
#       'school',
#       'tram',
#       'metro',
#       'shop']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-uhrineves-'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/181654092',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/181654092',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Wadia-Praha-Stare-Mesto',
#       'id': 4292,
#       'name': 'Wadia',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_B/Bz8Rkq.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 10 - Uhříněves',
#     'has_video': False,
#     'advert_images_count': 7,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 181654092,
#     'attractive_offer': 0,
#     'price': 16298000,
#     'price_czk': {'value_raw': 16298000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-20?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/181654092?region_tip=3191081'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBdBZXWeBeCNvq/ee9b.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBbkNYZxBeCOFI/ae91.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBVme3a1BeCOYW/4357.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/kcuj4damOBNB0fWuBeCOqV/dc46.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQBdBZXWcBeCPBj/446d.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m3_A/nb4N2OmYQDdw4uYVBeCL9F/15b8.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 112\xa0m²',
#     'region_tip': 3191081,
#     'gps': {'lat': 50.021845912870795, 'lon': 14.603064087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction', 'panel', 'partly_furnished'],
#      ['post_office', 'medic']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci',
#      'Panelová',
#      'Částečně vybavený',
#      'Pošta 279 metrů pěšky',
#      'Lékař 372 metrů pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'panel',
#       'cellar',
#       'elevator',
#       'partly_furnished'],
#      ['sports',
#       'small_shop',
#       'restaurant',
#       'tavern',
#       'kindergarten',
#       'drugstore',
#       'vet',
#       'medic',
#       'school',
#       'candy_shop',
#       'post_office',
#       'shop',
#       'atm',
#       'theater',
#       'bus_public_transport',
#       'playground',
#       'tram',
#       'metro',
#       'movies',
#       'train',
#       'natural_attraction']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 3,
#      'category_type_cb': 1,
#      'locality': 'praha-chodov-mikulova'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3571479116',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3571479116',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Realog-Praha-Holesovice',
#       'id': 16689,
#       'name': 'Realog',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_gQ_N/sJiyi.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 4 - Chodov',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3571479116,
#     'attractive_offer': 0,
#     'price': 5770000,
#     'price_czk': {'value_raw': 5770000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeCmZ4qlXCsyl2c/f555.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeCmZ4qlXCsyl2c/f555.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-19?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3571479116'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeCmZ4qlXCsyl2c/f555.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeCmZ4qlTCsyl9X/2a1b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWe0nAukgCsymDB/ff40.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWe0nAukrCsymFX/58d1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeDO3PenACsymJz/0f73.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/kb9Yg2GWeC36sVohCsymSq/dc9f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_D/nPw2pRkMOeCmZ4qlXCsyl2c/f555.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+1\xa035\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.01731091287079, 'lon': 14.527898087129206},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['post_office', 'drugstore']],
#     'has_panorama': 0,
#     'labels': ['Pošta 472 metrů pěšky', 'Lékárna 409 metrů pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar', 'elevator'],
#      ['sports',
#       'kindergarten',
#       'small_shop',
#       'restaurant',
#       'drugstore',
#       'candy_shop',
#       'school',
#       'atm',
#       'shop',
#       'theater',
#       'vet',
#       'tavern',
#       'movies',
#       'medic',
#       'post_office',
#       'bus_public_transport',
#       'train',
#       'tram',
#       'playground',
#       'metro',
#       'natural_attraction']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-zizkov-jeseniova'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/892981836',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/892981836',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'PSN-s-r-o-Praha-Zizkov',
#       'id': 1160,
#       'name': 'PSN s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_oV_B/kObgaqJNMnB0llrZvCNlXm0/55a8.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 3 - Žižkov',
#     'has_video': False,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 892981836,
#     'attractive_offer': 0,
#     'price': 9787000,
#     'price_czk': {'value_raw': 9787000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnujDq7UCZTJfy/b584.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnujDq7UCZTJfy/b584.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-18?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/892981836'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnujDq7UCZTJfy/b584.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiBtfltxOCZTJgZ/a4ee.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnD1IUpBAKCZTJlw/0a9a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnDMhdnBDyCZTJmX/48c4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnwQ71xfCZTJnu/0e30.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnB0yvGyfCZTJpa/da41.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnujDq7UCZTJfy/b584.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 76\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.07601891287079, 'lon': 14.481808087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction', 'furnished'],
#      ['metro', 'drugstore']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci',
#      'Vybavený',
#      'Metro 4 min. pěšky',
#      'Lékárna 6 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'brick',
#       'cellar',
#       'elevator',
#       'parking_lots',
#       'garage',
#       'furnished'],
#      ['theater',
#       'small_shop',
#       'candy_shop',
#       'vet',
#       'tavern',
#       'movies',
#       'playground',
#       'sightseeing',
#       'kindergarten',
#       'medic',
#       'train',
#       'bus_public_transport',
#       'post_office',
#       'sports',
#       'school',
#       'atm',
#       'drugstore',
#       'restaurant',
#       'shop',
#       'metro',
#       'tram']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-nove-mesto-senovazne-namesti'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2011771468',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2011771468',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'ENGEL-VOLKERS-Praha-Smichov',
#       'id': 10628,
#       'name': 'ENGEL & VÖLKERS',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_y/DbiKP5.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 1 - Nové Město',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2011771468,
#     'attractive_offer': 0,
#     'price': 0,
#     'price_czk': {'value_raw': 0, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tBexr9TDB9sNJi/75a5.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tBexr9TDB9sNJi/75a5.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-17?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2011771468'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tBexr9TDB9sNJi/75a5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tB7uGZTEB9sNLh/646d.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/kQOIvbF2D103URt9B9sNNi/e612.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tDxFrxwhB9sNPo/05ea.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tDcIi9TEB9sNRt/af4a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tD3HCkTDB9sNTz/6c5a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_A/nPt0vAiT3tBexr9TDB9sNJi/75a5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 165\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.07317691287079, 'lon': 14.444686087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'terrace',
#       'cellar',
#       'elevator',
#       'garage'],
#      ['small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'playground',
#       'theater',
#       'natural_attraction',
#       'movies',
#       'sports',
#       'restaurant',
#       'shop',
#       'post_office',
#       'school',
#       'kindergarten',
#       'metro',
#       'atm',
#       'bus_public_transport',
#       'drugstore',
#       'medic',
#       'tram',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-chodov-dunovskeho'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3553169996',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/3553169996',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'BOUTIQ-Real-Estate-Praha-Nove-Mesto',
#       'id': 20560,
#       'name': 'BOUTIQ Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_F_G/QFYWxx.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 4 - Chodov',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 3553169996,
#     'attractive_offer': 0,
#     'price': 25212000,
#     'price_czk': {'value_raw': 25212000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeDo8QnUNClqcsD/1af1.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeDo8QnUNClqcsD/1af1.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-16?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/3553169996'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeDo8QnUNClqcsD/1af1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeBHBngUNClqcvy/8f7f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeC4jvZTTClqcyK/b368.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeBHBngUDClqc3V/97a3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeDxAUcTSClqc5Q/de5a.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeBteKqUFClqc6c/1f92.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeDo8QnUNClqcsD/1af1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 134\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.022070912870795, 'lon': 14.519598087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'terrace',
#       'cellar',
#       'elevator',
#       'garage'],
#      ['small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'playground',
#       'theater',
#       'natural_attraction',
#       'movies',
#       'school',
#       'medic',
#       'kindergarten',
#       'bus_public_transport',
#       'atm',
#       'restaurant',
#       'post_office',
#       'shop',
#       'tram',
#       'train',
#       'drugstore',
#       'metro',
#       'sports']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-chodov-dunovskeho'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/331944524',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/331944524',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'BOUTIQ-Real-Estate-Praha-Nove-Mesto',
#       'id': 20560,
#       'name': 'BOUTIQ Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_F_G/QFYWxx.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 4 - Chodov',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 331944524,
#     'attractive_offer': 0,
#     'price': 18120000,
#     'price_czk': {'value_raw': 18120000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeCnX76UOClqebW/c8a6.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeCnX76UOClqebW/c8a6.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-15?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/331944524'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeCnX76UOClqebW/c8a6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWetzV8UEClqedU/c826.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeBHBngUOClqefX/900b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWe0nAuUNClqehC/06da.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeDPr2CTPClqehy/ecd8.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeC4jvZTYClqenb/e3c7.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeCnX76UOClqebW/c8a6.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 96\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.022070912870795, 'lon': 14.519598087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['balcony'], []],
#     'has_panorama': 0,
#     'labels': ['Balkon'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'cellar',
#       'elevator',
#       'garage'],
#      ['small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'playground',
#       'theater',
#       'movies',
#       'natural_attraction',
#       'post_office',
#       'sports',
#       'atm',
#       'school',
#       'bus_public_transport',
#       'tram',
#       'shop',
#       'medic',
#       'train',
#       'kindergarten',
#       'drugstore',
#       'restaurant',
#       'metro']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-chodov-dunovskeho'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2172322380',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2172322380',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'BOUTIQ-Real-Estate-Praha-Nove-Mesto',
#       'id': 20560,
#       'name': 'BOUTIQ Real Estate',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_F_G/QFYWxx.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 4 - Chodov',
#     'has_video': False,
#     'advert_images_count': 13,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2172322380,
#     'attractive_offer': 0,
#     'price': 11972000,
#     'price_czk': {'value_raw': 11972000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeBQpVfTSClqYfQ/bc62.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeBQpVfTSClqYfQ/bc62.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-14?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2172322380'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeBQpVfTSClqYfQ/bc62.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeCg8klTcClqYk3/57cd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWeC36sVUMClqYnk/7d21.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/kb9Yg2GWetzV8UFClqYoU/10bd.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeDxAUcTbClqYp7/bf99.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeBQpVfTTClqYrz/2926.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oX_B/nPw2pRkMOeBQpVfTSClqYfQ/bc62.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 66\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.022070912870795, 'lon': 14.519598087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction'], ['medic', 'drugstore']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci',
#      'Lékař 4 min. pěšky',
#      'Lékárna 4 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'after_reconstruction', 'brick'],
#      ['candy_shop',
#       'theater',
#       'small_shop',
#       'vet',
#       'tavern',
#       'movies',
#       'playground',
#       'sightseeing',
#       'post_office',
#       'atm',
#       'medic',
#       'sports',
#       'school',
#       'kindergarten',
#       'metro',
#       'tram',
#       'train',
#       'shop',
#       'bus_public_transport',
#       'drugstore',
#       'restaurant']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-holesovice-veletrzni'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/930267724',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/930267724',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 7 - Holešovice',
#     'has_video': True,
#     'advert_images_count': 30,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 930267724,
#     'attractive_offer': 0,
#     'price': 23074000,
#     'price_czk': {'value_raw': 23074000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1VYLJYfBsrzLX/a95c.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1VYLJYfBsrzLX/a95c.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-13?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/930267724'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1VYLJYfBsrzLX/a95c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1bMIzYfBsrzNy/8216.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1VYLJYZBsrzQH/08e9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1DN63hW7BsrzSb/29d9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/nPt0vAiT3tDo5YuWHBsrzUZ/71a0.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/nPt0vAiT3tCAMohWIBsrzWc/b066.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_A/kQOIvbF2D1VYLJYfBsrzLX/a95c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 151\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.089053912870796, 'lon': 14.443483087129206},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['post_office']],
#     'has_panorama': 0,
#     'labels': ['Pošta 6 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'cellar', 'not_furnished'],
#      ['theater',
#       'vet',
#       'small_shop',
#       'candy_shop',
#       'tavern',
#       'movies',
#       'playground',
#       'sightseeing',
#       'natural_attraction',
#       'sports',
#       'medic',
#       'shop',
#       'school',
#       'tram',
#       'train',
#       'atm',
#       'drugstore',
#       'post_office',
#       'restaurant',
#       'metro',
#       'kindergarten',
#       'bus_public_transport']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-smichov-pechackova'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2968588876',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2968588876',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'PSN-s-r-o-Praha-Zizkov',
#       'id': 1160,
#       'name': 'PSN s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_oV_B/kObgaqJNMnB0llrZvCNlXm0/55a8.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 5 - Smíchov',
#     'has_video': False,
#     'advert_images_count': 14,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2968588876,
#     'attractive_offer': 0,
#     'price': 8734000,
#     'price_czk': {'value_raw': 8734000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnB0yvGTqCcQu7U/699f.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnB0yvGTqCcQu7U/699f.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-12?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2968588876'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnB0yvGTqCcQu7U/699f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/nO1SBfAluiUs1XBA3CcQu8C/5f1c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnDMhdnTrCcQu8w/1c6c.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnVbj2TlCcQu9d/f8de.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnVbj2TtCcQvAQ/1921.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnujDqTrCcQvBy/d47b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_C/kObgaqJNMnB0yvGTqCcQu7U/699f.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 70\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.060809912870795, 'lon': 14.421422087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick'],
#      ['small_shop',
#       'tavern',
#       'candy_shop',
#       'vet',
#       'theater',
#       'playground',
#       'movies',
#       'natural_attraction',
#       'post_office',
#       'medic',
#       'drugstore',
#       'bus_public_transport',
#       'atm',
#       'shop',
#       'school',
#       'train',
#       'restaurant',
#       'tram',
#       'metro',
#       'sports',
#       'kindergarten']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-malesice-u-tvrze'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2314089036',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2314089036',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'HX-reality-Praha-Stare-Mesto',
#       'id': 14953,
#       'name': 'HX reality',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_H_D/ZAlBqQq.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 10 - Malešice',
#     'has_video': False,
#     'advert_images_count': 9,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2314089036,
#     'attractive_offer': 0,
#     'price': 8782000,
#     'price_czk': {'value_raw': 8782000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBIuqInJB6P314/be35.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBIuqInJB6P314/be35.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-11?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2314089036'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBIuqInJB6P314/be35.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1C2jWPqjB6P33p/bf77.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBWQSrpRB6P34y/28ee.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1CgWWKrJB6P4Zf/bca3.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1bMIzofB6P4X5/ce7d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tcD8ZnAB6P4Z3/71a3.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBIuqInJB6P314/be35.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 71\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.072325912870795, 'lon': 14.523835087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['balcony'], []],
#     'has_panorama': 0,
#     'labels': ['Balkon'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'balcony',
#       'cellar',
#       'elevator',
#       'parking_lots'],
#      ['tavern',
#       'small_shop',
#       'vet',
#       'candy_shop',
#       'theater',
#       'playground',
#       'movies',
#       'sports',
#       'atm',
#       'bus_public_transport',
#       'metro',
#       'restaurant',
#       'post_office',
#       'medic',
#       'school',
#       'train',
#       'shop',
#       'kindergarten',
#       'drugstore',
#       'tram']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-praha-cakovice-belomlynska'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/547366220',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/547366220',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'Sekyra-Group-Praha-Karlin',
#       'id': 3360,
#       'name': 'Sekyra Group',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_g/RYpNU.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 9 - Praha-Čakovice',
#     'has_video': False,
#     'advert_images_count': 5,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 547366220,
#     'attractive_offer': 0,
#     'price': 9104000,
#     'price_czk': {'value_raw': 9104000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0k9CUJYX7/75a5.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0k9CUJYX7/75a5.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-10?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/547366220'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0k9CUJYX7/75a5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/kObgaqJNMnzSiAnXCUJYYg/b8c8.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiyaoUqqCUJYZU/e72e.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiBJE31pFCUJYaG/abe9.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/kObgaqJNMnVbj2l1CUJYaj/9559.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_B/nO1SBfAluiDhBr0k9CUJYX7/75a5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 60\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.145339912870796, 'lon': 14.539332087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction'], []],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'brick',
#       'elevator',
#       'parking_lots'],
#      ['candy_shop',
#       'small_shop',
#       'vet',
#       'theater',
#       'tavern',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'sports',
#       'restaurant',
#       'bus_public_transport',
#       'metro',
#       'shop',
#       'post_office',
#       'kindergarten',
#       'train',
#       'tram',
#       'school',
#       'drugstore',
#       'atm',
#       'medic']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 8,
#      'category_type_cb': 1,
#      'locality': 'praha-hostavice-piscita'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1202987596',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1202987596',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 9 - Hostavice',
#     'has_video': False,
#     'advert_images_count': 19,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1202987596,
#     'attractive_offer': 0,
#     'price': 18695000,
#     'price_czk': {'value_raw': 18695000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluis55qg9CQAwpw/0cac.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluis55qg9CQAwpw/0cac.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-9?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1202987596'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluis55qg9CQAwpw/0cac.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluiD9J7zfjCQAwqq/d656.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/kObgaqJNMnKEQFfdCQAwre/53f1.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluiD9J7zfmCQAwsN/af96.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluiD9J7zfnCQAws9/a57b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/kObgaqJNMnKEQFfaCQAwtr/2b05.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oW_A/nO1SBfAluis55qg9CQAwpw/0cac.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 4+kk 146\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.073031912870796, 'lon': 14.572681087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], ['metro', 'shop']],
#     'has_panorama': 0,
#     'labels': ['Metro 5 min. pěšky', 'Obchod 4 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal', 'brick', 'elevator'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'tavern',
#       'movies',
#       'candy_shop',
#       'playground',
#       'sightseeing',
#       'post_office',
#       'medic',
#       'school',
#       'metro',
#       'drugstore',
#       'kindergarten',
#       'shop',
#       'restaurant',
#       'train',
#       'atm',
#       'bus_public_transport',
#       'sports',
#       'tram']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-nove-mesto-truhlarska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/239473996',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/239473996',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'ENGEL-VOLKERS-Praha-Smichov',
#       'id': 10628,
#       'name': 'ENGEL & VÖLKERS',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QI_y/DbiKP5.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 1 - Nové Město',
#     'has_video': False,
#     'advert_images_count': 9,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 239473996,
#     'attractive_offer': 0,
#     'price': 16311000,
#     'price_czk': {'value_raw': 16311000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrZ5CNrEpH/a5f4.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrZ5CNrEpH/a5f4.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-8?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/239473996'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrZ5CNrEpH/a5f4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUZ7CNrEpu/1d99.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiCodW3cnCNrEqY/5970.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluis55qaICNrEq8/95b2.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGZ4CNrEr0/bd22.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiBtfltaECNrEsa/f276.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrZ5CNrEpH/a5f4.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 77\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.078154912870794, 'lon': 14.442881087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['collective', 'balcony'], []],
#     'has_panorama': 0,
#     'labels': ['Družstevní', 'Balkon'],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'collective',
#       'balcony',
#       'brick',
#       'elevator',
#       'parking_lots',
#       'garage'],
#      ['small_shop',
#       'candy_shop',
#       'vet',
#       'tavern',
#       'theater',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'shop',
#       'restaurant',
#       'drugstore',
#       'post_office',
#       'atm',
#       'school',
#       'bus_public_transport',
#       'train',
#       'kindergarten',
#       'metro',
#       'sports',
#       'tram',
#       'medic']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 6,
#      'category_type_cb': 1,
#      'locality': 'praha-dolni-mecholupy-kardausova'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/1768084044',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/1768084044',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False},
#      'company': {'url': 'SOUKUP-PARTNERS-s-r-o-Praha-Zabehlice',
#       'id': 4744,
#       'name': 'SOUKUP & PARTNERS s.r.o.',
#       'logo_small': 'https://d48-a.sdn.cz/d_48/c_img_QO_S/0C8I57.png?fl=res,140,140,3,ffffff'}},
#     'paid_logo': 1,
#     'locality': 'Praha 10 - Dolní Měcholupy',
#     'has_video': False,
#     'advert_images_count': 21,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 1768084044,
#     'attractive_offer': 0,
#     'price': 3638000,
#     'price_czk': {'value_raw': 3638000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D103URqnB7iOc5/e5ed.jpeg?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D103URqnB7iOc5/e5ed.jpeg?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-7?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/1768084044'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D103URqnB7iOc5/e5ed.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tBh4bTujB7iOar/57f5.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1bMIzqHB7iOg2/e867.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/nPt0vAiT3tt1PFrHB7iOfJ/79eb.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1CgWWKsvB7iOiq/e42b.jpeg?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D1C1iQvuZB7iOkw/cba3.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_m4_D/kQOIvbF2D103URqnB7iOc5/e5ed.jpeg?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 121\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.05379791287079, 'lon': 14.566796087129205},
#     'has_matterport_url': False},
#    {'labelsReleased': [['after_reconstruction'], ['train']],
#     'has_panorama': 0,
#     'labels': ['Po rekonstrukci', 'Vlak 7 min. pěšky'],
#     'is_auction': False,
#     'labelsAll': [['personal',
#       'after_reconstruction',
#       'brick',
#       'cellar',
#       'parking_lots'],
#      ['small_shop',
#       'vet',
#       'candy_shop',
#       'tavern',
#       'theater',
#       'movies',
#       'playground',
#       'natural_attraction',
#       'sports',
#       'post_office',
#       'drugstore',
#       'atm',
#       'train',
#       'tram',
#       'school',
#       'shop',
#       'medic',
#       'bus_public_transport',
#       'restaurant',
#       'kindergarten',
#       'metro']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-modrany-k-vltave'},
#     'exclusively_at_rk': 1,
#     'category': 1,
#     'has_floor_plan': 0,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/3333608012',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
# ...
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYqCNDi3N/a2cf.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYpCNDkPY/5b1d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUYrCNDjwW/f6b0.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiUs1XY2CNDgv3/ce8f.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiDhBr0YyCNDe8F/2abf.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 3+kk 130\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'terrace',
#       'elevator',
#       'not_furnished'],
#      ['small_shop',
#       'vet',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'post_office',
#       'train',
#       'metro',
#       'sports',
#       'bus_public_transport',
#       'school',
#       'atm',
#       'shop',
#       'medic',
#       'tram',
#       'drugstore',
#       'kindergarten',
#       'restaurant']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2387026508',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2387026508',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2387026508,
#     'attractive_offer': 0,
#     'price': 10853000,
#     'price_czk': {'value_raw': 10853000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYqCNDI4E/da1d.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYqCNDI4E/da1d.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-3?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2387026508'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYqCNDI4E/da1d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnDx7wrYqCNDNp0/d6ea.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUY2CNDMIF/1e92.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnKEQFYqCNDNB4/8927.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYhCNDMl4/02ff.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiDshGGY2CNDJYX/9fbc.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnzSiAYqCNDI4E/da1d.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 69\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'personal', 'elevator', 'not_furnished'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'restaurant',
#       'school',
#       'atm',
#       'sports',
#       'tram',
#       'kindergarten',
#       'medic',
#       'post_office',
#       'drugstore',
#       'bus_public_transport',
#       'metro',
#       'shop',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 2,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/2152145484',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/2152145484',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 2152145484,
#     'attractive_offer': 0,
#     'price': 12296000,
#     'price_czk': {'value_raw': 12296000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCsIs/0ee4.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCsIs/0ee4.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-2?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/2152145484'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCsIs/0ee4.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiB7FFSYzCNCzZz/55d0.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnujDqYpCNC1JW/c322.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnujDqYoCNC1HZ/01ba.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCzAO/1714.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiyaoUY1CNCy2r/5e82.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnVbj2YlCNCsIs/0ee4.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+kk 79\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building',
#       'personal',
#       'terrace',
#       'elevator',
#       'not_furnished'],
#      ['small_shop',
#       'theater',
#       'vet',
#       'tavern',
#       'candy_shop',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'tram',
#       'kindergarten',
#       'restaurant',
#       'atm',
#       'shop',
#       'drugstore',
#       'sports',
#       'bus_public_transport',
#       'medic',
#       'post_office',
#       'school',
#       'metro',
#       'train']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 2,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/259465804',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/259465804',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 259465804,
#     'attractive_offer': 0,
#     'price': 9974000,
#     'price_czk': {'value_raw': 9974000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNB10x/758d.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNB10x/758d.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/-1?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/259465804'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNB10x/758d.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnKEQFYkCNCANc/0c31.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYnCNB7wJ/6c14.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnwQ71Z7CNB9JT/4a2b.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnujDqYnCNB8pj/4e02.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiCodW3bXCNB5rv/08f7.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNB10x/758d.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 1+kk 61\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False},
#    {'labelsReleased': [[], []],
#     'has_panorama': 0,
#     'labels': [],
#     'is_auction': False,
#     'labelsAll': [['new_building', 'personal', 'elevator', 'not_furnished'],
#      ['small_shop',
#       'vet',
#       'theater',
#       'candy_shop',
#       'tavern',
#       'playground',
#       'movies',
#       'sightseeing',
#       'natural_attraction',
#       'shop',
#       'medic',
#       'bus_public_transport',
#       'atm',
#       'drugstore',
#       'tram',
#       'restaurant',
#       'kindergarten',
#       'post_office',
#       'train',
#       'school',
#       'metro',
#       'sports']],
#     'seo': {'category_main_cb': 1,
#      'category_sub_cb': 4,
#      'category_type_cb': 1,
#      'locality': 'praha-kosire-starokosirska'},
#     'exclusively_at_rk': 0,
#     'category': 1,
#     'has_floor_plan': 1,
#     '_embedded': {'favourite': {'is_favourite': False,
#       '_links': {'self': {'profile': '/favourite/doc',
#         'href': '/cs/v2/favourite/360129100',
#         'title': 'Oblibene inzeraty'}}},
#      'note': {'note': '',
#       '_links': {'self': {'profile': '/note/doc',
#         'href': '/cs/v2/note/360129100',
#         'title': 'Poznamky inzeratu'}},
#       'has_note': False}},
#     'paid_logo': 0,
#     'locality': 'Praha 5 - Košíře',
#     'has_video': False,
#     'advert_images_count': 16,
#     'new': False,
#     'auctionPrice': 0.0,
#     'type': 1,
#     'hash_id': 360129100,
#     'attractive_offer': 0,
#     'price': 9836000,
#     'price_czk': {'value_raw': 9836000, 'unit': '', 'name': 'Celková cena'},
#     '_links': {'dynamicDown': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYWCNA1Vu/e952.png?fl=res,{width},{height},3|shr,,20|jpg,90'}],
#      'dynamicUp': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYWCNA1Vu/e952.png?fl=res,{width},{height},3|wrm,/watermark/sreality.png,10|shr,,20|jpg,90'}],
#      'iterator': {'href': '/cs/v2/estate-iterator/0?category_main_cb=1&suggested_regionId=-1&locality_region_id=10&suggested_districtId=-1&category_type_cb=1'},
#      'self': {'href': '/cs/v2/estates/360129100'},
#      'images': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYWCNA1Vu/e952.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluis55qYfCNA7I2/3001.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiDshGGYuCNA80x/0246.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnwQ71Z5CNA9QH/dfdc.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/nO1SBfAluiUs1XYvCNA66y/9e5c.png?fl=res,400,300,3|shr,,20|jpg,90'},
#       {'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0yvGYmCNA63k/7cf3.png?fl=res,400,300,3|shr,,20|jpg,90'}],
#      'image_middle2': [{'href': 'https://d18-a.sdn.cz/d_18/c_img_oV_C/kObgaqJNMnB0llrYWCNA1Vu/e952.png?fl=res,400,300,3|shr,,20|jpg,90'}]},
#     'rus': False,
#     'name': 'Prodej bytu 2+kk 56\xa0m²',
#     'region_tip': 0,
#     'gps': {'lat': 50.058577912870796, 'lon': 14.398338087129204},
#     'has_matterport_url': False}],
#   'is_saved': {'email_notification': False,
#    'notification_advert_count': 0,
#    'stack_id': 0,
#    'push_notification': False,
#    '_links': {'self': {'href': '/cs/v2/stacks'}},
#    'removed': False,
#    'saved': False},
#   'not_precise_location_count': {'result_size_auction': 1,
#    'result_size': 1409,
#    '_links': {'self': {'profile': '/estates/count/doc',
#      'href': '/cs/v2/estates/count?category_main_cb=1&locality_region_id=10&category_type_cb=3',
#      'title': 'Estate count'}}}},
#  'filterLabels': [],
#  'title': 'Byty na prodej Praha',
#  'filter': {'category_main_cb': '1',
#   'suggested_districtId': -1,
#   'locality_region_id': '10',
#   'category_type_cb': '1',
#   'suggested_regionId': -1},
#  '_links': {'self': {'href': '/cs/v2/estates?category_main_cb=1&locality_region_id=10&category_type_cb=1&page=0'},
#   'clusters_with_bounding_box_of_first_10': {'href': '/cs/v2/clusters?category_main_cb=1&locality_region_id=10&category_type_cb=1&per_page60=&leftBottomBounding=14.4214220871|50.0173109129&page=0&rightTopBounding=14.6030640871|50.0890539129'},
#   'rss': {'href': '/api/cs/v2/estates/rss?category_main_cb=1&category_type_cb=1&locality_region_id=10&suggested_regionId=-1&suggested_districtId=-1'}},
#  'locality': 'okres Praha 4',
#  'locality_dativ': 'na Praze 4',
#  'logged_in': False,
#  'per_page': 20,
#  'category_instrumental': 'výběrem či prodejem bytu',
#  'page': 0,
#  'filterLabels2': {'something_more3_3310': 'elevator',
#   'something_more1_3120': 'cellar',
#   'something_more1_3100': 'loggia',
#   'furnished_1': 'furnished',
#   'furnished_2': 'partly_furnished',
#   'furnished_3': 'not_furnished',
#   'building_condition_9': 'after_reconstruction',
#   'something_more2_3150': 'garage',
#   'something_more2_3130': 'basin',
#   'ownership_1': 'personal',
#   'ownership_3': 'state',
#   'ownership_2': 'collective',
#   'something_more3_1820': 'easy_access',
#   'energy_efficiency_rating_search_7': 'energy_rating_g',
#   'energy_efficiency_rating_search_6': 'energy_rating_f',
#   'energy_efficiency_rating_search_5': 'energy_rating_e',
#   'energy_efficiency_rating_search_4': 'energy_rating_d',
#   'energy_efficiency_rating_search_3': 'energy_rating_c',
#   'energy_efficiency_rating_search_2': 'energy_rating_b',
#   'energy_efficiency_rating_search_1': 'energy_rating_a',
#   'something_more1_3110': 'terrace',
#   'building_condition_6': 'new_building',
#   'something_more1_3090': 'balcony',
#   'building_condition_4': 'in_construction',
#   'building_type_search_3': 'other_sigular',
#   'something_more2_3120': 'cellar',
#   'building_type_search_1': 'panel',
#   'something_more2_3140': 'parking_lots',
#   'something_more1_200222': 'garden',
#   'building_type_search_2': 'brick'}}

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=105, step=1)

# %% [markdown]
# #### Task 2: Cleaning data
#
# __2a. Filter columns__
# * filter only columns: `['locality', 'price', 'name', 'gps','hash_id','exclusively_at_rk']`
# * use `.copy()` to avoid `SettingWithCopyWarning` later

# %%
df.columns
# Out:
# Index(['labelsReleased', 'has_panorama', 'labels', 'is_auction', 'labelsAll',
#        'seo', 'exclusively_at_rk', 'category', 'has_floor_plan', '_embedded',
#        'paid_logo', 'locality', 'has_video', 'advert_images_count', 'new',
#        'auctionPrice', 'type', 'hash_id', 'attractive_offer', 'price',
#        'price_czk', '_links', 'rus', 'name', 'region_tip', 'gps',
#        'has_matterport_url'],
#       dtype='object')

# %% [markdown]
# Copy selection into new one

# %%
df_clean = df[['locality', 'price', 'name', 'gps', 'hash_id', 'exclusively_at_rk']].copy()
df_clean
# Out:
#                   locality     price                                 name  \
# 0     Praha 10 - Uhříněves  14518000              Prodej bytu 4+kk 100 m²
# 1    Praha 1 - Malá Strana  31293000  Prodej bytu 3+kk 160 m² (Podkrovní)
# 2        Praha 5 - Smíchov  10057000   Prodej bytu 3+kk 96 m² (Podkrovní)
# 3       Praha 5 - Stodůlky   6935000               Prodej bytu 2+kk 48 m²
# 4          Praha 4 - Nusle   6583000               Prodej bytu 2+kk 45 m²
# ..                     ...       ...                                  ...
# 100      Praha 5 - Smíchov   8594000               Prodej bytu 2+kk 57 m²
# 101     Praha 9 - Vysočany   6694000               Prodej bytu 2+kk 59 m²
# 102     Praha 9 - Vysočany   5197000               Prodej bytu 1+kk 34 m²
# 103     Praha 9 - Vysočany  13356000              Prodej bytu 4+kk 137 m²
# 104     Praha 9 - Vysočany   6985000               Prodej bytu 2+kk 63 m²
#
#                                                    gps     hash_id  \
# 0    {'lat': 50.02321621360754, 'lon': 14.601693786...   181654092
# 1    {'lat': 50.07438321360754, 'lon': 14.417012786...   131142988
# 2    {'lat': 50.05343621360754, 'lon': 14.399236786...   288179532
# 3    {'lat': 50.042065213607536, 'lon': 14.35449678...  3775754828
# 4    {'lat': 50.05146021360754, 'lon': 14.458017786...  1989653068
# ..                                                 ...         ...
# 100  {'lat': 50.05944121360754, 'lon': 14.418958786...  2995417676
# 101  {'lat': 50.08976821360754, 'lon': 14.501791786...  2848944716
# 102  {'lat': 50.08976821360754, 'lon': 14.501791786...  3402592844
# 103  {'lat': 50.08976821360754, 'lon': 14.501791786...   181367372
# 104  {'lat': 50.08976821360754, 'lon': 14.501791786...  1038053964
#
#      exclusively_at_rk
# 0                    1
# 1                    0
# 2                    1
# 3                    1
# 4                    1
# ..                 ...
# 100                  0
# 101                  0
# 102                  0
# 103                  0
# 104                  0
#
# [105 rows x 6 columns]

# %% [markdown]
# ### 2b: GPS
# * Convert dictionary in `gps` column into two columns - `lat` and `lon`
# * use apply function on gps column
# * Note apply can return multiple columns

# %%
df_clean.loc[1:2, 'gps']
# Out:
# 1    {'lat': 50.07438321360754, 'lon': 14.417012786...
# 2    {'lat': 50.05343621360754, 'lon': 14.399236786...
# Name: gps, dtype: object

# %%
df_clean[['lat', 'lon']] = df_clean.gps.apply(lambda x: pd.Series({'lat': x['lat'], 'lon': x['lon']}))

# %%
df_clean.head()
# Out:
#                 locality     price                                 name  \
# 0   Praha 10 - Uhříněves  14518000              Prodej bytu 4+kk 100 m²
# 1  Praha 1 - Malá Strana  31293000  Prodej bytu 3+kk 160 m² (Podkrovní)
# 2      Praha 5 - Smíchov  10057000   Prodej bytu 3+kk 96 m² (Podkrovní)
# 3     Praha 5 - Stodůlky   6935000               Prodej bytu 2+kk 48 m²
# 4        Praha 4 - Nusle   6583000               Prodej bytu 2+kk 45 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.02321621360754, 'lon': 14.601693786...   181654092
# 1  {'lat': 50.07438321360754, 'lon': 14.417012786...   131142988
# 2  {'lat': 50.05343621360754, 'lon': 14.399236786...   288179532
# 3  {'lat': 50.042065213607536, 'lon': 14.35449678...  3775754828
# 4  {'lat': 50.05146021360754, 'lon': 14.458017786...  1989653068
#
#    exclusively_at_rk        lat        lon
# 0                  1  50.023216  14.601694
# 1                  0  50.074383  14.417013
# 2                  1  50.053436  14.399237
# 3                  1  50.042065  14.354497
# 4                  1  50.051460  14.458018

# %% [markdown]
# ### 2c. Get flat type from name
#
# * Name is always represented by string `Prodej bytu [type of flat] [Area] m^2`
# * Try picking third word in string
# * Check meaningfulness using `.value_counts()`

# %%
df_clean.name.apply(lambda x: x.split(' '))[:5]
# Out:
# 0                 [Prodej, bytu, 4+kk, 100 m²]
# 1    [Prodej, bytu, 3+kk, 160 m², (Podkrovní)]
# 2     [Prodej, bytu, 3+kk, 96 m², (Podkrovní)]
# 3                  [Prodej, bytu, 2+kk, 48 m²]
# 4                  [Prodej, bytu, 2+kk, 45 m²]
# Name: name, dtype: object

# %%
df_clean.name.apply(lambda x: x.split())[:5]
# Out:
# 0                 [Prodej, bytu, 4+kk, 100, m²]
# 1    [Prodej, bytu, 3+kk, 160, m², (Podkrovní)]
# 2     [Prodej, bytu, 3+kk, 96, m², (Podkrovní)]
# 3                  [Prodej, bytu, 2+kk, 48, m²]
# 4                  [Prodej, bytu, 2+kk, 45, m²]
# Name: name, dtype: object

# %%
df_clean['type_of_flat'] = df_clean.name.apply(lambda x: x.split(' ')[2])

# %%
df_clean['flat_type'] = df_clean.name.apply(lambda x: x.split()[2])
df_clean.head()
# Out:
#                 locality     price                                 name  \
# 0   Praha 10 - Uhříněves  14518000              Prodej bytu 4+kk 100 m²
# 1  Praha 1 - Malá Strana  31293000  Prodej bytu 3+kk 160 m² (Podkrovní)
# 2      Praha 5 - Smíchov  10057000   Prodej bytu 3+kk 96 m² (Podkrovní)
# 3     Praha 5 - Stodůlky   6935000               Prodej bytu 2+kk 48 m²
# 4        Praha 4 - Nusle   6583000               Prodej bytu 2+kk 45 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.02321621360754, 'lon': 14.601693786...   181654092
# 1  {'lat': 50.07438321360754, 'lon': 14.417012786...   131142988
# 2  {'lat': 50.05343621360754, 'lon': 14.399236786...   288179532
# 3  {'lat': 50.042065213607536, 'lon': 14.35449678...  3775754828
# 4  {'lat': 50.05146021360754, 'lon': 14.458017786...  1989653068
#
#    exclusively_at_rk        lat        lon type_of_flat flat_type
# 0                  1  50.023216  14.601694         4+kk      4+kk
# 1                  0  50.074383  14.417013         3+kk      3+kk
# 2                  1  50.053436  14.399237         3+kk      3+kk
# 3                  1  50.042065  14.354497         2+kk      2+kk
# 4                  1  50.051460  14.458018         2+kk      2+kk

# %%
df_clean['type_of_flat'].value_counts()
# Out:
# type_of_flat
# 2+kk          47
# 3+kk          23
# 1+kk          14
# 4+kk          13
# atypické       2
# 2+1 101 m²     1
# 1+1 31 m²      1
# 2+1 86 m²      1
# 5+kk           1
# 2+1 83 m²      1
# 3+1 108 m²     1
# Name: count, dtype: int64

# %%
df_clean['flat_type'].value_counts()
# Out:
# flat_type
# 2+kk        47
# 3+kk        23
# 1+kk        14
# 4+kk        13
# 2+1          3
# atypické     2
# 1+1          1
# 5+kk         1
# 3+1          1
# Name: count, dtype: int64

# %%
# regular expression to find numbers before m²
df_clean['area1'] = df_clean['name'].apply(lambda x: re.findall(r'(\d+)\s+m²', x)[0])

# %%
df_clean['area1']
# Out:
# 0      100
# 1      160
# 2       96
# 3       48
# 4       45
#       ...
# 100     57
# 101     59
# 102     34
# 103    137
# 104     63
# Name: area1, Length: 105, dtype: object

# %%
# regular expression to find characters before '+' and behind '+'
def flat_type(x:str):
    # \d+ represents one or more digit(s)
    # \s is a space character
    # \w+ is one or more word character(s)
    # * represents 0 or more
    ft = re.findall(r'(\d+)\s*\+\s*(\w+)', x)
    return ft

# %%
sample_text = 'Prodej bytu 3+kk 71 m²'
print(f"Initial text: {sample_text}")
print("Processed text:")
flat_type(sample_text)
# Out:
# Initial text: Prodej bytu 3+kk 71 m²
# Processed text:
# [('3', 'kk')]

# %%
df_clean['rooms'] = df_clean['name'].apply(flat_type)

# %%
df_clean.head()
# Out:
#                 locality     price                                 name  \
# 0   Praha 10 - Uhříněves  14518000              Prodej bytu 4+kk 100 m²
# 1  Praha 1 - Malá Strana  31293000  Prodej bytu 3+kk 160 m² (Podkrovní)
# 2      Praha 5 - Smíchov  10057000   Prodej bytu 3+kk 96 m² (Podkrovní)
# 3     Praha 5 - Stodůlky   6935000               Prodej bytu 2+kk 48 m²
# 4        Praha 4 - Nusle   6583000               Prodej bytu 2+kk 45 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.02321621360754, 'lon': 14.601693786...   181654092
# 1  {'lat': 50.07438321360754, 'lon': 14.417012786...   131142988
# 2  {'lat': 50.05343621360754, 'lon': 14.399236786...   288179532
# 3  {'lat': 50.042065213607536, 'lon': 14.35449678...  3775754828
# 4  {'lat': 50.05146021360754, 'lon': 14.458017786...  1989653068
#
#    exclusively_at_rk        lat        lon type_of_flat flat_type area1  \
# 0                  1  50.023216  14.601694         4+kk      4+kk   100
# 1                  0  50.074383  14.417013         3+kk      3+kk   160
# 2                  1  50.053436  14.399237         3+kk      3+kk    96
# 3                  1  50.042065  14.354497         2+kk      2+kk    48
# 4                  1  50.051460  14.458018         2+kk      2+kk    45
#
#        rooms
# 0  [(4, kk)]
# 1  [(3, kk)]
# 2  [(3, kk)]
# 3  [(2, kk)]
# 4  [(2, kk)]

# %% [markdown]
# ### 2d. Get the area of a flat from name
#
# * Naive: select the word before last word
# * Then try navigating using the index of `'m²'`
# * If this also fail, then you will need to use regex - `import re`

# %%
def name_to_area(nm):
    splitted = nm.split()
    m_idx = splitted.index('m²')
    return int(splitted[m_idx-1])

df_clean['area2'] = df_clean.name.apply(name_to_area)
df_clean.head()
# Out:
#                 locality     price                                 name  \
# 0   Praha 10 - Uhříněves  14518000              Prodej bytu 4+kk 100 m²
# 1  Praha 1 - Malá Strana  31293000  Prodej bytu 3+kk 160 m² (Podkrovní)
# 2      Praha 5 - Smíchov  10057000   Prodej bytu 3+kk 96 m² (Podkrovní)
# 3     Praha 5 - Stodůlky   6935000               Prodej bytu 2+kk 48 m²
# 4        Praha 4 - Nusle   6583000               Prodej bytu 2+kk 45 m²
#
#                                                  gps     hash_id  \
# 0  {'lat': 50.02321621360754, 'lon': 14.601693786...   181654092
# 1  {'lat': 50.07438321360754, 'lon': 14.417012786...   131142988
# 2  {'lat': 50.05343621360754, 'lon': 14.399236786...   288179532
# 3  {'lat': 50.042065213607536, 'lon': 14.35449678...  3775754828
# 4  {'lat': 50.05146021360754, 'lon': 14.458017786...  1989653068
#
#    exclusively_at_rk        lat        lon type_of_flat flat_type area1  \
# 0                  1  50.023216  14.601694         4+kk      4+kk   100
# 1                  0  50.074383  14.417013         3+kk      3+kk   160
# 2                  1  50.053436  14.399237         3+kk      3+kk    96
# 3                  1  50.042065  14.354497         2+kk      2+kk    48
# 4                  1  50.051460  14.458018         2+kk      2+kk    45
#
#        rooms  area2
# 0  [(4, kk)]    100
# 1  [(3, kk)]    160
# 2  [(3, kk)]     96
# 3  [(2, kk)]     48
# 4  [(2, kk)]     45

# %%
df_clean[df_clean["area1"] == df_clean["area2"]]
# Out:
# Empty DataFrame
# Columns: [locality, price, name, gps, hash_id, exclusively_at_rk, lat, lon, type_of_flat, flat_type, area1, rooms, area2]
# Index: []

# %% [markdown]
# None of the elements is equal.

# %%
type(df_clean['area1'][0]), type(df_clean['area2'][0])
# Out:
# (str, numpy.int64)

# %%
df_clean[df_clean['area1'].astype(int)==df_clean['area2']]
# Out:
#                   locality     price                                 name  \
# 0     Praha 10 - Uhříněves  14518000              Prodej bytu 4+kk 100 m²
# 1    Praha 1 - Malá Strana  31293000  Prodej bytu 3+kk 160 m² (Podkrovní)
# 2        Praha 5 - Smíchov  10057000   Prodej bytu 3+kk 96 m² (Podkrovní)
# 3       Praha 5 - Stodůlky   6935000               Prodej bytu 2+kk 48 m²
# 4          Praha 4 - Nusle   6583000               Prodej bytu 2+kk 45 m²
# ..                     ...       ...                                  ...
# 100      Praha 5 - Smíchov   8594000               Prodej bytu 2+kk 57 m²
# 101     Praha 9 - Vysočany   6694000               Prodej bytu 2+kk 59 m²
# 102     Praha 9 - Vysočany   5197000               Prodej bytu 1+kk 34 m²
# 103     Praha 9 - Vysočany  13356000              Prodej bytu 4+kk 137 m²
# 104     Praha 9 - Vysočany   6985000               Prodej bytu 2+kk 63 m²
#
#                                                    gps     hash_id  \
# 0    {'lat': 50.02321621360754, 'lon': 14.601693786...   181654092
# 1    {'lat': 50.07438321360754, 'lon': 14.417012786...   131142988
# 2    {'lat': 50.05343621360754, 'lon': 14.399236786...   288179532
# 3    {'lat': 50.042065213607536, 'lon': 14.35449678...  3775754828
# 4    {'lat': 50.05146021360754, 'lon': 14.458017786...  1989653068
# ..                                                 ...         ...
# 100  {'lat': 50.05944121360754, 'lon': 14.418958786...  2995417676
# 101  {'lat': 50.08976821360754, 'lon': 14.501791786...  2848944716
# 102  {'lat': 50.08976821360754, 'lon': 14.501791786...  3402592844
# 103  {'lat': 50.08976821360754, 'lon': 14.501791786...   181367372
# 104  {'lat': 50.08976821360754, 'lon': 14.501791786...  1038053964
#
#      exclusively_at_rk        lat        lon type_of_flat flat_type area1  \
# 0                    1  50.023216  14.601694         4+kk      4+kk   100
# 1                    0  50.074383  14.417013         3+kk      3+kk   160
# 2                    1  50.053436  14.399237         3+kk      3+kk    96
# 3                    1  50.042065  14.354497         2+kk      2+kk    48
# 4                    1  50.051460  14.458018         2+kk      2+kk    45
# ..                 ...        ...        ...          ...       ...   ...
# 100                  0  50.059441  14.418959         2+kk      2+kk    57
# 101                  0  50.089768  14.501792         2+kk      2+kk    59
# 102                  0  50.089768  14.501792         1+kk      1+kk    34
# 103                  0  50.089768  14.501792         4+kk      4+kk   137
# 104                  0  50.089768  14.501792         2+kk      2+kk    63
#
#          rooms  area2
# 0    [(4, kk)]    100
# 1    [(3, kk)]    160
# 2    [(3, kk)]     96
# 3    [(2, kk)]     48
# 4    [(2, kk)]     45
# ..         ...    ...
# 100  [(2, kk)]     57
# 101  [(2, kk)]     59
# 102  [(1, kk)]     34
# 103  [(4, kk)]    137
# 104  [(2, kk)]     63
#
# [105 rows x 13 columns]
